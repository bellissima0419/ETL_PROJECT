# %% [markdown]
# ## Shift + tab for methods info

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import colors
import datetime as dt
import numpy as np

# %%
df = pd.read_csv("CrimeData_2010-Present.csv",parse_dates=True)

# %%
df.head()
df.tail()
# Out:
#          DR Number Date Reported Date Occurred  Time Occurred  Area ID  \
# 1048570  171518209        9/3/17        9/2/17           1500       15
# 1048571  171518210        9/3/17        9/3/17           1500       15
# 1048572  171518213        9/3/17        9/3/17           1910       15
# 1048573  171518214        9/3/17        9/3/17           1300       15
# 1048574  171518215        9/3/17        9/3/17           1730       15
#
#            Area Name  Reporting District  Crime Code  \
# 1048570  N Hollywood                1501         510
# 1048571  N Hollywood                1501         420
# 1048572  N Hollywood                1504         624
# 1048573  N Hollywood                1586         745
# 1048574  N Hollywood                1591         626
#
#                                   Crime Code Description        MO Codes  \
# 1048570                                 VEHICLE - STOLEN             NaN
# ...

# %% [markdown]
# ## Check variables

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['DR Number', 'Date Reported', 'Date Occurred', 'Time Occurred',
#        'Area ID', 'Area Name', 'Reporting District', 'Crime Code',
#        'Crime Code Description', 'MO Codes', 'Victim Age', 'Victim Sex',
#        'Victim Descent', 'Premise Code', 'Premise Description',
#        'Weapon Used Code', 'Weapon Description', 'Status Code',
#        'Status Description', 'Crime Code 1', 'Crime Code 2', 'Crime Code 3',
#        'Crime Code 4', 'Address', 'Cross Street', 'Location '],
#       dtype='object')

# %%
df['Crime Code Description'].head()
# Out:
# 0    VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
# 1                            OTHER MISCELLANEOUS CRIME
# 2                                BURGLARY FROM VEHICLE
# 3    THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...
# 4    VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
# Name: Crime Code Description, dtype: object

# %%
df['Victim Age'].mean()
# Out:
# 31.16789547719524

# %%
df['Victim Age'].min()
# Out:
# -9

# %%
df['Victim Age'].max()
# Out:
# 114

# %%
plt.hist(df['Victim Age'],density=True, edgecolor="black", linewidth= 1.1)
# Out:
# (array([1.59080006e-02, 2.57383763e-03, 1.60405847e-02, 1.95200261e-02,
#         1.38247242e-02, 8.97346360e-03, 3.40237205e-03, 8.89864274e-04,
#         1.67862347e-04, 7.75345712e-08]),
#  array([ -9. ,   3.3,  15.6,  27.9,  40.2,  52.5,  64.8,  77.1,  89.4,
#         101.7, 114. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(df['Victim Age'],density=True, edgecolor="black", linewidth= 1.1)
# Out:
# (array([1.59080006e-02, 2.57383763e-03, 1.60405847e-02, 1.95200261e-02,
#         1.38247242e-02, 8.97346360e-03, 3.40237205e-03, 8.89864274e-04,
#         1.67862347e-04, 7.75345712e-08]),
#  array([ -9. ,   3.3,  15.6,  27.9,  40.2,  52.5,  64.8,  77.1,  89.4,
#         101.7, 114. ]),
#  <a list of 10 Patch objects>)

# %%
 df_cl=df[df['Victim Age'] > 0]

# %%
df_cl['Victim Age'].min()
# Out:
# 2

# %%
df['Victim Age']
# Out:
# 0           0
# 1           0
# 2          46
# 3          55
# 4          24
# 5          11
# 6          28
# 7          36
# 8          23
# 9           0
# 10          0
# 11         20
# 12          0
# 13          0
# 14          0
# 15         27
# 16         32
# 17          0
# 18          5
# 19         49
# 20         62
# 21         32
# 22          0
# 23         61
# 24         23
# 25          0
# 26         41
# 27          0
# 28          0
# 29         20
#            ..
# 1048545    34
# 1048546     0
# 1048547    63
# 1048548     0
# 1048549    42
# 1048550    47
# 1048551    44
# 1048552    60
# 1048553    53
# 1048554    40
# 1048555     0
# 1048556    25
# 1048557    33
# 1048558    61
# 1048559    33
# 1048560    22
# 1048561     0
# 1048562     0
# 1048563    17
# 1048564    23
# 1048565    43
# 1048566    48
# 1048567     0
# 1048568    55
# 1048569    19
# 1048570     0
# 1048571     0
# 1048572    27
# 1048573    51
# 1048574    29
# ...

# %%
df.loc[df['Victim Age'] > 1]
# Out:
#          DR Number Date Reported Date Occurred  Time Occurred  Area ID  \
# 2        100100508        1/8/10        1/7/10           2005        1
# 3        100100511        1/9/10        1/6/10           2100        1
# 4        100100523       1/15/10       1/15/10            245        1
# 5        100100552       1/23/10       1/23/10           1225        1
# 6        100100562       1/28/10       1/28/10           2345        1
# 7        100100575        2/1/10       1/31/10           1720        1
# 8        100100610       2/11/10       2/10/10           1800        1
# 11       100100650       2/25/10       2/25/10             30        1
# 15       100100725       3/18/10       3/18/10             15        1
# 16       100100726       3/19/10       3/19/10           1000       13
# 18       100100738       3/22/10       3/19/10           1730        1
# 19       100100740       3/25/10       3/22/10           1915        1
# ...

# %%
# Drop a row by condition
#df['Age_cl'] = 
df['Victim Age']=df.loc[df['Victim Age'] > 1]
#int(df['Age_cl'])

# %%
df['Victim Age'].head()
# Out:
# 0     0
# 1     0
# 2    46
# 3    55
# 4    24
# Name: Victim Age, dtype: int64

# %%
df['Victim Age'].min()
# Out:
# -9

# %%
 df['Victim Age'].describe()
# Out:
# count        845207.0
# unique       845207.0
# top       140509183.0
# freq              1.0
# Name: Victim Age, dtype: float64

# %%
 df['Victim Age'].
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-f594a59742ce> in <module>
# ----> 1 df['Victim Age'].summarize()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'summarize'

# %%
myhist =plt.hist(df['Victim Age'])
plt.show(myhits)

# %%
df = df.as_type({'Age_cl':int})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-d59fa8d0bdcb> in <module>
# ----> 1 df = df.as_type({'Age_cl':int})
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'as_type'

# %%
age_cl =df['Age_cl'].head()
plt.hist(df['Age_cl']).head()

# %%
df['Date Reported'].dtype
# Out:
# dtype('O')

# %%
df['Date Reported'] = df(df['Date Reported'])
df['year_reported'], df['month_reported'] = df['Date Reported'].dt.year, df['Date Reported'].dt.month
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-6a08462728c6> in <module>
# ----> 1 df['Date Reported'] = df(df['Date Reported'])
#       2 df['year_reported'], df['month_reported'] = df['Date Reported'].dt.year, df['Date Reported'].dt.month
#       3 df
#
# TypeError: 'DataFrame' object is not callable
