# %% [markdown]
# # City of Los Angeles CA. Data on crime reports since 2010
# ### Dataset for this Notebook:
# [LA CRIME SOURCE DATA](https://catalog.data.gov/dataset/crime-data-from-2010-to-present)

# %%
import pandas as pd
import numpy as np
import re
from datetime import datetime
import time
import matplotlib.pyplot as plt

import diffs_latlong
from diffs_latlong import computeNearestZip

csv_file = "Resources/Crime_Data_from_2010_to_Present.csv"

# %%
# Load data from csv file
crime_df = pd.read_csv(csv_file)

# %%
crime_df.tail(2)
# Out:
#          DR Number Date Reported Date Occurred  Time Occurred  Area ID  \
# 1972132  191005089    01/26/2019    01/01/2010           1000       10
# 1972133  191505220    01/24/2019    01/05/2010            700       15
#
#            Area Name  Reporting District  Crime Code  \
# 1972132  West Valley                1029         354
# 1972133  N Hollywood                1555         341
#
#                                     Crime Code Description   MO Codes  ...  \
# 1972132                                  THEFT OF IDENTITY  1822 0377  ...
# 1972133  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...  1202 0701  ...
#
#          Weapon Description Status Code Status Description  Crime Code 1  \
# 1972132                 NaN          IC        Invest Cont         354.0
# 1972133                 NaN          IC        Invest Cont         341.0
#
#         Crime Code 2  Crime Code 3 Crime Code 4  \
# 1972132          NaN           NaN          NaN
# 1972133          NaN           NaN          NaN
#
#                                          Address Cross Street  \
# 1972132  7000    WOODLEY                      AV          NaN
# 1972133  5000    LANKERSHIM                   BL          NaN
#
#                     Location
# 1972132  (34.1976, -118.4837)
# 1972133  (34.1611, -118.3723)
#
# [2 rows x 26 columns]

# %%
# The 'Location ' column has a blank space at the end
crime_df.columns
# Out:
# Index(['DR Number', 'Date Reported', 'Date Occurred', 'Time Occurred',
#        'Area ID', 'Area Name', 'Reporting District', 'Crime Code',
#        'Crime Code Description', 'MO Codes', 'Victim Age', 'Victim Sex',
#        'Victim Descent', 'Premise Code', 'Premise Description',
#        'Weapon Used Code', 'Weapon Description', 'Status Code',
#        'Status Description', 'Crime Code 1', 'Crime Code 2', 'Crime Code 3',
#        'Crime Code 4', 'Address', 'Cross Street', 'Location '],
#       dtype='object')

# %%
crime_df = crime_df.rename(columns={"Location ": "location"})

# %%
# Inspect the new location column
crime_df.columns[-1]
# Out:
# 'location'

# %%
crime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1972134 entries, 0 to 1972133
# Data columns (total 26 columns):
# DR Number                 int64
# Date Reported             object
# Date Occurred             object
# Time Occurred             int64
# Area ID                   int64
# Area Name                 object
# Reporting District        int64
# Crime Code                int64
# Crime Code Description    object
# MO Codes                  object
# Victim Age                int64
# Victim Sex                object
# Victim Descent            object
# Premise Code              float64
# Premise Description       object
# Weapon Used Code          float64
# Weapon Description        object
# Status Code               object
# Status Description        object
# Crime Code 1              float64
# Crime Code 2              float64
# Crime Code 3              float64
# Crime Code 4              float64
# Address                   object
# Cross Street              object
# location                  object
# dtypes: float64(6), int64(6), object(14)
# memory usage: 391.2+ MB

# %%
# Regex to extract lat and long out of the location column
# and make 2 new columns from the values.
crime_df[['lat', 'long']] = crime_df['location'].replace\
    (to_replace=["\)","\("], value="", regex=True).str.split(",", expand = True)

# %%
# Inspect the new columns
crime_df.iloc[-3:,-5:]
# Out:
#                                          Address  \
# 1972131          69TH                         ST
# 1972132  7000    WOODLEY                      AV
# 1972133  5000    LANKERSHIM                   BL
#
#                             Cross Street              location      lat  \
# 1972131  DENKER                       AV   (33.977, -118.3046)   33.977
# 1972132                              NaN  (34.1976, -118.4837)  34.1976
# 1972133                              NaN  (34.1611, -118.3723)  34.1611
#
#                long
# 1972131   -118.3046
# 1972132   -118.4837
# 1972133   -118.3723

# %%
# Convert lat and longs to numeric values: 
# Needed for the computeNearestZip function(Extract zip from lat long)
crime_df['lat'] = pd.to_numeric(crime_df['lat'])
crime_df['long'] = pd.to_numeric(crime_df['long'])

# %%
type(crime_df['lat'][0]), type(crime_df['long'][0])
# Out:
# (numpy.float64, numpy.float64)

# %% [markdown]
# ### Examining the structure of the dataframe

# %%
len(crime_df.columns)
# Out:
# 28

# %%
crime_df.shape
# Out:
# (1972134, 28)

# %%
# 15 columns that have no missing values at all
crime_df.dropna(axis=1).shape
# Out:
# (1972134, 15)

# %%
# only 19 rows out of 1967976 are without missing values
crime_df.dropna(axis=0).shape
# Out:
# (19, 28)

# %%
print(f"Total rows in age column: {crime_df['Victim Age'].count()}")
print(f"Total rows with age == 0: {crime_df[crime_df['Victim Age']==0]['Victim Age'].count()}")
print("Rows with age == 0:",\
     round(float(crime_df[crime_df['Victim Age']==0]['Victim Age']\
                  .count()/crime_df['Victim Age'].count()*100),2), '%')
# Out:
# Total rows in age column: 1972134
# Total rows with age == 0: 362180
# Rows with age == 0: 18.36 %

# %%
# Quick visual inspection of the 'Victim Age' column for the above reasons ☝🏾
data = crime_df['Victim Age'].value_counts()
names = list(data.index)
fig, axs = plt.subplots(figsize=(18, 5))
axs.bar(names, data)

plt.show()

# %%
# Ages with negative numbers exactly 9 😰
# it probalby refers to an unborn victim (pregnancy stage of victim's mother)?
crime_df[crime_df['Victim Age'] < 0].groupby('Victim Age')['Victim Age'].count()
# Out:
# Victim Age
# -9      2
# -8      1
# -7      4
# -6     10
# -5     17
# -4     23
# -3     51
# -2    102
# -1    221
# Name: Victim Age, dtype: int64

# %%
# About the huge amount of zeros in dataset:
# coud be that in data entry process the person preparing the report
# could not leave the field blank for unknown ages?:
#No missing values in this column
crime_df['Victim Age'].isnull().values.any(), crime_df['Victim Age'].isnull().values.sum()
# Out:
# (False, 0)

# %%
print(f"Total columns in dataset: {len(crime_df.columns)}")
print(f"Number of Columns with no missing values: {len(crime_df.dropna(axis=1).columns)}")
# Out:
# Total columns in dataset: 28
# Number of Columns with no missing values: 15

# %%
print(f" Only {len(crime_df.dropna(axis=0))}\
 Rows with no missing values out of {len(crime_df)} total Rows")
# Out:
#  Only 19 Rows with no missing values out of 1972134 total Rows

# %% [markdown]
# # Mapping lat long to a zip code with helper funcion imported from diffs_latlong.py

# %%
# Wrapper function needed to execute the computeNearestZip script.
def zipWrapper(myDf):
    lat = myDf['lat']
    long = myDf['long']
    return computeNearestZip(lat, long)

# %%
# Create a slice of the original dataframe to use in the project
_100k_crime_df = crime_df[:100000].copy()
_100k_crime_df.tail(2)
# Out:
#        DR Number Date Reported Date Occurred  Time Occurred  Area ID  \
# 99998  140504326    01/09/2014    01/07/2014            900        5
# 99999  140504327    01/09/2014    01/09/2014              1        5
#
#       Area Name  Reporting District  Crime Code  \
# 99998    Harbor                 581         341
# 99999    Harbor                 563         624
#
#                                   Crime Code Description        MO Codes  ...  \
# 99998  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...            0352  ...
# 99999                           BATTERY - SIMPLE ASSAULT  0416 0429 0444  ...
#
#        Status Description Crime Code 1 Crime Code 2  Crime Code 3  \
# 99998         Invest Cont        341.0          NaN           NaN
# 99999         Invest Cont        624.0          NaN           NaN
#
#       Crime Code 4                                  Address Cross Street  \
# 99998          NaN  2100    MCRAE                        DR          NaN
# 99999          NaN                                     13TH       GAFFEY
#
#                    location      lat      long
# 99998  (33.7263, -118.3208)  33.7263 -118.3208
# 99999  (33.7324, -118.2924)  33.7324 -118.2924
#
# [2 rows x 28 columns]

# %%
# Function to test the time it takes for our computeNearestzip function to run
def df_maker():
    begining = time.time()
    _100k_crime_df['zip'] = _100k_crime_df.apply(func=zipWrapper, axis=1)
    end = time.time()
    total = end-begining
    print(f"It took {total} seconds to process {len(_100k_crime_df['zip'])} Rows")
    return _100k_crime_df

# %%
df_maker()
# Out:
# It took 6132.920296907425 seconds to process 100000 Rows
#        DR Number Date Reported Date Occurred  Time Occurred  Area ID  \
# 0       11401303    09/13/2010    09/12/2010             45       14
# 1       70309629    08/09/2010    08/09/2010           1515       13
# 2      100100508    01/08/2010    01/07/2010           2005        1
# 3      100100511    01/09/2010    01/06/2010           2100        1
# 4      100100523    01/15/2010    01/15/2010            245        1
# 5      100100552    01/23/2010    01/23/2010           1225        1
# 6      100100562    01/28/2010    01/28/2010           2345        1
# 7      100100575    02/01/2010    01/31/2010           1720        1
# 8      100100610    02/11/2010    02/10/2010           1800        1
# 9      100100616    02/11/2010    02/11/2010           1515        1
# 10     100100638    02/20/2010    02/20/2010            100        1
# 11     100100650    02/25/2010    02/25/2010             30        1
# 12     100100654    02/27/2010    02/27/2010           1955        1
# 13     100100660    03/01/2010    03/01/2010            100        1
# 14     100100697    03/12/2010    03/12/2010           1520        1
# 15     100100725    03/18/2010    03/18/2010             15        1
# 16     100100726    03/19/2010    03/19/2010           1000       13
# 17     100100733    03/21/2010    03/21/2010           1000       11
# 18     100100738    03/22/2010    03/19/2010           1730        1
# 19     100100740    03/25/2010    03/22/2010           1915        1
# 20     100100744    03/23/2010    03/23/2010            230        1
# 21     100100753    03/25/2010    03/25/2010            240        1
# 22     100100764    04/01/2010    03/29/2010           2320        1
# 23     100100792    04/10/2010    04/10/2010           1710        1
# 24     100100799    04/12/2010    04/12/2010           1700        1
# 25     100100802    04/14/2010    04/14/2010           1515        1
# 26     100100803    04/14/2010    04/14/2010            915        1
# 27     100100812    04/16/2010    04/16/2010            800        1
# 28     100100826    04/17/2010    04/17/2010           1300        1
# 29     100100828    04/17/2010    04/17/2010           1900        1
# ...          ...           ...           ...            ...      ...
# 99970  140504259    01/07/2014    01/06/2014           2200        5
# 99971  140504260    01/07/2014    01/07/2014           1125        5
# 99972  140504261    01/07/2014    01/07/2014           1500        5
# 99973  140504263    01/07/2014    01/07/2014            845        5
# 99974  140504278    01/07/2014    01/07/2014           1400        5
# 99975  140504283    01/07/2014    01/07/2014           1600        5
# 99976  140504284    01/07/2014    01/07/2014           1810        5
# 99977  140504287    01/07/2014    01/07/2014           1030        5
# 99978  140504289    01/07/2014    01/07/2014           2125        5
# 99979  140504290    01/08/2014    01/07/2014           2230        5
# 99980  140504291    01/07/2014    01/05/2014           1900        5
# 99981  140504292    01/08/2014    01/07/2014           1800        5
# 99982  140504293    01/07/2014    01/07/2014           1647        5
# 99983  140504295    01/08/2014    01/08/2014            515        5
# 99984  140504297    01/07/2014    01/06/2014            715        5
# 99985  140504298    01/07/2014    01/07/2014           2130        5
# 99986  140504301    01/08/2014    01/08/2014            800        5
# 99987  140504303    01/08/2014    01/07/2014           1800        5
# 99988  140504304    01/08/2014    01/05/2014           1200        5
# 99989  140504308    01/08/2014    01/06/2014            800        5
# 99990  140504309    01/08/2014    01/07/2014           2350        5
# 99991  140504312    01/08/2014    01/08/2014            800        5
# 99992  140504315    01/08/2014    01/08/2014           1130        5
# 99993  140504316    01/08/2014    01/08/2014           1130        5
# 99994  140504320    01/08/2014    01/08/2014           2000        5
# 99995  140504322    01/08/2014    01/07/2014           2000        5
# 99996  140504323    01/08/2014    01/08/2014           2315        5
# 99997  140504325    01/08/2014    01/08/2014           1500        5
# 99998  140504326    01/09/2014    01/07/2014            900        5
# 99999  140504327    01/09/2014    01/09/2014              1        5
#
#        Area Name  Reporting District  Crime Code  \
# 0        Pacific                1485         740
# 1         Newton                1324         946
# 2        Central                 182         330
# 3        Central                 132         341
# 4        Central                 182         740
# 5        Central                 192         237
# 6        Central                 152         626
# 7        Central                 181         341
# 8        Central                 162         442
# 9        Central                 192         341
# 10       Central                 164         740
# 11       Central                 111         310
# 12       Central                 174         946
# 13       Central                 148         648
# 14       Central                 151         341
# 15       Central                 145         230
# 16        Newton                1307         624
# 17     Northeast                1171         946
# 18       Central                 195         627
# 19       Central                 142         230
# 20       Central                 101         740
# 21       Central                 171         946
# 22       Central                 176         740
# 23       Central                 135         210
# 24       Central                 111         740
# 25       Central                 155         946
# 26       Central                 161         341
# 27       Central                 152         441
# 28       Central                 124         745
# 29       Central                 111         930
# ...          ...                 ...         ...
# 99970     Harbor                 569         745
# 99971     Harbor                 551         310
# 99972     Harbor                 557         440
# 99973     Harbor                 511         930
# 99974     Harbor                 504         440
# 99975     Harbor                 587         440
# 99976     Harbor                 585         901
# 99977     Harbor                 519         440
# 99978     Harbor                 532         626
# 99979     Harbor                 518         510
# 99980     Harbor                 585         230
# 99981     Harbor                 551         510
# 99982     Harbor                 524         930
# 99983     Harbor                 562         230
# 99984     Harbor                 532         310
# 99985     Harbor                 557         330
# 99986     Harbor                 521         420
# 99987     Harbor                 511         330
# 99988     Harbor                 526         956
# 99989     Harbor                 566         354
# 99990     Harbor                 504         510
# 99991     Harbor                 564         901
# 99992     Harbor                 524         624
# 99993     Harbor                 524         624
# 99994     Harbor                 525         740
# 99995     Harbor                 509         440
# 99996     Harbor                 567         626
# 99997     Harbor                 558         310
# 99998     Harbor                 581         341
# 99999     Harbor                 563         624
#
#                                   Crime Code Description  \
# 0      VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
# 1                              OTHER MISCELLANEOUS CRIME
# 2                                  BURGLARY FROM VEHICLE
# 3      THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...
# 4      VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
# 5                         CHILD NEGLECT (SEE 300 W.I.C.)
# 6                      INTIMATE PARTNER - SIMPLE ASSAULT
# 7      THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...
# 8               SHOPLIFTING - PETTY THEFT ($950 & UNDER)
# 9      THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...
# 10     VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
# 11                                              BURGLARY
# 12                             OTHER MISCELLANEOUS CRIME
# 13                                                 ARSON
# 14     THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...
# 15        ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 16                              BATTERY - SIMPLE ASSAULT
# 17                             OTHER MISCELLANEOUS CRIME
# 18               CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT
# 19        ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 20     VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
# 21                             OTHER MISCELLANEOUS CRIME
# 22     VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
# 23                                               ROBBERY
# 24     VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
# 25                             OTHER MISCELLANEOUS CRIME
# 26     THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...
# 27                                 THEFT PLAIN - ATTEMPT
# 28              VANDALISM - MISDEAMEANOR ($399 OR UNDER)
# 29                CRIMINAL THREATS - NO WEAPON DISPLAYED
# ...                                                  ...
# 99970           VANDALISM - MISDEAMEANOR ($399 OR UNDER)
# 99971                                           BURGLARY
# 99972                 THEFT PLAIN - PETTY ($950 & UNDER)
# 99973             CRIMINAL THREATS - NO WEAPON DISPLAYED
# 99974                 THEFT PLAIN - PETTY ($950 & UNDER)
# 99975                 THEFT PLAIN - PETTY ($950 & UNDER)
# 99976                     VIOLATION OF RESTRAINING ORDER
# 99977                 THEFT PLAIN - PETTY ($950 & UNDER)
# 99978                  INTIMATE PARTNER - SIMPLE ASSAULT
# 99979                                   VEHICLE - STOLEN
# 99980     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 99981                                   VEHICLE - STOLEN
# 99982             CRIMINAL THREATS - NO WEAPON DISPLAYED
# 99983     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 99984                                           BURGLARY
# 99985                              BURGLARY FROM VEHICLE
# 99986    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
# 99987                              BURGLARY FROM VEHICLE
# 99988            LETTERS, LEWD  -  TELEPHONE CALLS, LEWD
# 99989                                  THEFT OF IDENTITY
# 99990                                   VEHICLE - STOLEN
# 99991                     VIOLATION OF RESTRAINING ORDER
# 99992                           BATTERY - SIMPLE ASSAULT
# 99993                           BATTERY - SIMPLE ASSAULT
# 99994  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
# 99995                 THEFT PLAIN - PETTY ($950 & UNDER)
# 99996                  INTIMATE PARTNER - SIMPLE ASSAULT
# 99997                                           BURGLARY
# 99998  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...
# 99999                           BATTERY - SIMPLE ASSAULT
#
#                             MO Codes  ...  Crime Code 1 Crime Code 2  \
# 0                               0329  ...         740.0          NaN
# 1                               0344  ...         946.0          NaN
# 2                               0344  ...         330.0          NaN
# 3                          0344 1402  ...         341.0        998.0
# 4                               0329  ...         740.0          NaN
# 5                               1251  ...         237.0          NaN
# 6                          0416 2000  ...         626.0          NaN
# 7                               1402  ...         341.0          NaN
# 8                          0325 1402  ...         442.0        998.0
# 9                               1212  ...         341.0          NaN
# 10                              0329  ...         740.0          NaN
# 11                         0344 1251  ...         310.0          NaN
# 12                               NaN  ...         946.0          NaN
# 13                              1501  ...         648.0          NaN
# 14                         0344 1402  ...         341.0        998.0
# 15                              0400  ...         230.0          NaN
# 16               0416 0429 0917 1804  ...         624.0          NaN
# 17                              1402  ...         946.0        998.0
# 18                         0416 0552  ...         627.0          NaN
# 19                              0416  ...         230.0          NaN
# 20                    0311 0329 0906  ...         740.0          NaN
# 21                         0906 1501  ...         946.0          NaN
# 22                              0329  ...         740.0          NaN
# 23                              0302  ...         210.0          NaN
# 24                    0329 1251 1300  ...         740.0          NaN
# 25                              0914  ...         946.0          NaN
# 26                         0344 1402  ...         341.0        998.0
# 27                              1402  ...         441.0        998.0
# 28                         0329 1402  ...         745.0        998.0
# 29               0400 0421 0432 1402  ...         930.0        998.0
# ...                              ...  ...           ...          ...
# 99970                           0311  ...         745.0          NaN
# 99971                 0344 1607 1309  ...         310.0          NaN
# 99972            0344 0325 0104 1236  ...         440.0          NaN
# 99973  0432 0421 0422 1309 0913 2000  ...         930.0          NaN
# 99974                           0325  ...         440.0          NaN
# 99975                 0344 1309 0913  ...         440.0          NaN
# 99976                      1813 1309  ...         901.0          NaN
# 99977                      0104 0344  ...         440.0          NaN
# 99978                 2000 0444 1813  ...         626.0          NaN
# 99979                            NaN  ...         510.0          NaN
# 99980            2000 0416 0334 1813  ...         230.0          NaN
# 99981                            NaN  ...         510.0          NaN
# 99982  0913 2000 1814 0432 0421 1912  ...         930.0          NaN
# 99983                 0561 0416 0408  ...         230.0          NaN
# 99984  0344 0358 1607 0321 1402 0329  ...         310.0        998.0
# 99985                 1300 0344 0329  ...         330.0          NaN
# 99986                 1300 0344 1402  ...         420.0        998.0
# 99987                      1300 0344  ...         330.0          NaN
# 99988                           0913  ...         956.0          NaN
# 99989                      0929 1822  ...         354.0          NaN
# 99990                            NaN  ...         510.0          NaN
# 99991                           0913  ...         901.0          NaN
# 99992                      0446 1271  ...         624.0          NaN
# 99993                      0400 1271  ...         624.0          NaN
# 99994            0906 1816 0311 1402  ...         740.0        998.0
# 99995                           0344  ...         440.0          NaN
# 99996       2000 1813 0444 0913 0416  ...         626.0          NaN
# 99997            0344 0358 1606 1402  ...         310.0        998.0
# 99998                           0352  ...         341.0          NaN
# 99999                 0416 0429 0444  ...         624.0          NaN
#
#       Crime Code 3  Crime Code 4                                   Address  \
# 0              NaN           NaN           SEPULVEDA                    BL
# 1              NaN           NaN   1300 E  21ST                         ST
# 2              NaN           NaN           PICO                         BL
# 3              NaN           NaN    200 S  OLIVE                        ST
# 4              NaN           NaN   1100 S  OLIVE                        ST
# 5              NaN           NaN   1300 S  FLOWER                       ST
# 6              NaN           NaN    500 S  GRAND                        AV
# 7              NaN           NaN   1100 S  FIGUEROA                     ST
# 8              NaN           NaN    700 W  7TH                          ST
# 9              NaN           NaN                                      PICO
# 10             NaN           NaN    100 W  7TH                          ST
# 11             NaN           NaN    500 N  FIGUEROA                     ST
# 12             NaN           NaN        W  7TH                          ST
# 13             NaN           NaN                                       5TH
# 14             NaN           NaN                                       7TH
# 15             NaN           NaN    400 S  MAIN                         ST
# 16             NaN           NaN    800 E  8TH                          ST
# 17             NaN           NaN                                   WAVERLY
# 18             NaN           NaN   1800 S  MAIN                         ST
# 19             NaN           NaN           4TH                          ST
# 20             NaN           NaN   1200    INNES                        AV
# 21             NaN           NaN    900    GEORGIA                      ST
# 22             NaN           NaN           SAN PEDRO                    ST
# 23             NaN           NaN    100 E  3RD                          ST
# 24             NaN           NaN                                      YALE
# 25             NaN           NaN    200 E  6TH                          ST
# 26             NaN           NaN    700 S  FIGUEROA                     ST
# 27             NaN           NaN                                       7TH
# 28             NaN           NaN                                       1ST
# 29             NaN           NaN           CESAR E CHAVEZ               BL
# ...            ...           ...                                       ...
# 99970          NaN           NaN                               00    BERTH
# 99971          NaN           NaN    400    MIRALESTE                    DR
# 99972          NaN           NaN    500 S  GAFFEY                       ST
# 99973          NaN           NaN   1500 W  257TH                        ST
# 99974          NaN           NaN   1500    FRANCISCO                    ST
# 99975          NaN           NaN   2900 S  PACIFIC                      AV
# 99976          NaN           NaN   1100 W  22ND                         ST
# 99977          NaN           NaN   1900    BLINN                        AV
# 99978          NaN           NaN   1200    MCDONALD                     AV
# 99979          NaN           NaN  24400    AVALON                       BL
# 99980          NaN           NaN    800    HAMILTON                     AV
# 99981          NaN           NaN    100 N  WESTERN                      AV
# 99982          NaN           NaN    400    KING                         AV
# 99983          NaN           NaN   1300 W  9TH                          ST
# 99984          NaN           NaN   1000    NEPTUNE                      AV
# 99985          NaN           NaN    300 S  GAFFEY                       ST
# 99986          NaN           NaN   1600    DALMATIA                     DR
# 99987          NaN           NaN   1400 W  257TH                        ST
# 99988          NaN           NaN    800    ISLAND                       AV
# 99989          NaN           NaN   1200 S  MESA                         ST
# 99990          NaN           NaN   1600 W  204TH                        ST
# 99991          NaN           NaN    200 S  BEACON                       ST
# 99992          NaN           NaN                                         L
# 99993          NaN           NaN                                         L
# 99994          NaN           NaN                                         D
# 99995          NaN           NaN   1400 W  LOMITA                       BL
# 99996          NaN           NaN   1500 S  PALOS VERDES                 ST
# 99997          NaN           NaN    200 W  SEPULVEDA                    ST
# 99998          NaN           NaN   2100    MCRAE                        DR
# 99999          NaN           NaN                                      13TH
#
#                              Cross Street              location      lat  \
# 0         MANCHESTER                   AV  (33.9599, -118.3962)  33.9599
# 1                                     NaN  (34.0224, -118.2524)  34.0224
# 2         GRAND                        AV  (34.0389, -118.2643)  34.0389
# 3                                     NaN  (34.0538, -118.2488)  34.0538
# 4                                     NaN  (34.0409, -118.2609)  34.0409
# 5                                     NaN  (34.0401, -118.2668)  34.0401
# 6                                     NaN   (34.0502, -118.254)  34.0502
# 7                                     NaN  (34.0437, -118.2652)  34.0437
# 8                                     NaN   (34.048, -118.2577)  34.0480
# 9                                   GRAND  (34.0389, -118.2643)  34.0389
# 10                                    NaN  (34.0439, -118.2514)  34.0439
# 11                                    NaN  (34.0617, -118.2469)  34.0617
# 12     S  SPRING                       ST  (34.0445, -118.2523)  34.0445
# 13        SAN PEDRO                    ST  (34.0435, -118.2427)  34.0435
# 14                               FIGUEROA  (34.0499, -118.2614)  34.0499
# 15                                    NaN  (34.0482, -118.2472)  34.0482
# 16                                    NaN  (34.0371, -118.2475)  34.0371
# 17        SUNSET                       BL  (34.0917, -118.2741)  34.0917
# 18                                    NaN  (34.0317, -118.2641)  34.0317
# 19        GRAND                        AV  (34.0516, -118.2526)  34.0516
# 20                                    NaN  (34.0717, -118.2493)  34.0717
# 21                                    NaN  (34.0475, -118.2657)  34.0475
# 22        9TH                          ST  (34.0373, -118.2503)  34.0373
# 23                                    NaN  (34.0496, -118.2458)  34.0496
# 24                                COLLEGE  (34.0672, -118.2385)  34.0672
# 25                                    NaN   (34.0446, -118.249)  34.0446
# 26                                    NaN  (34.0494, -118.2599)  34.0494
# 27                                  OLIVE  (34.0467, -118.2556)  34.0467
# 28        MAIN                         ST  (34.0522, -118.2434)  34.0522
# 29        SPRING                       ST  (34.0582, -118.2387)  34.0582
# ...                                   ...                   ...      ...
# 99970                                 NaN  (33.7257, -118.2766)  33.7257
# 99971                                 NaN  (33.7426, -118.3195)  33.7426
# 99972                                 NaN  (33.7397, -118.2923)  33.7397
# 99973                                 NaN  (33.7905, -118.3027)  33.7905
# 99974                                 NaN    (33.85, -118.3032)  33.8500
# 99975                                 NaN  (33.7179, -118.2879)  33.7179
# 99976                                 NaN  (33.7243, -118.3012)  33.7243
# 99977                                 NaN   (33.799, -118.2459)  33.7990
# 99978                                 NaN  (33.7866, -118.2715)  33.7866
# 99979                                 NaN   (33.8046, -118.264)  33.8046
# 99980                                 NaN  (33.7209, -118.2946)  33.7209
# 99981                                 NaN  (33.7434, -118.3098)  33.7434
# 99982                                 NaN   (33.7749, -118.275)  33.7749
# 99983                                 NaN  (33.7361, -118.3056)  33.7361
# 99984                                 NaN  (33.7826, -118.2691)  33.7826
# 99985                                 NaN  (33.7415, -118.2923)  33.7415
# 99986                                 NaN  (33.7643, -118.3072)  33.7643
# 99987                                 NaN  (33.7905, -118.3011)  33.7905
# 99988                                 NaN  (33.7798, -118.2665)  33.7798
# 99989                                 NaN  (33.7333, -118.2857)  33.7333
# 99990                                 NaN  (33.8457, -118.3066)  33.8457
# 99991                                 NaN  (33.7424, -118.2804)  33.7424
# 99992                          WILMINGTON  (33.7864, -118.2747)  33.7864
# 99993                          WILMINGTON  (33.7864, -118.2747)  33.7864
# 99994                             BAYVIEW  (33.7738, -118.2698)  33.7738
# 99995                                 NaN  (33.7978, -118.3011)  33.7978
# 99996                                 NaN  (33.7306, -118.2814)  33.7306
# 99997                                 NaN  (33.7451, -118.2817)  33.7451
# 99998                                 NaN  (33.7263, -118.3208)  33.7263
# 99999                              GAFFEY  (33.7324, -118.2924)  33.7324
#
#            long    zip
# 0     -118.3962  90045
# 1     -118.2524  90021
# 2     -118.2643  90015
# 3     -118.2488  90071
# 4     -118.2609  90015
# 5     -118.2668  90015
# 6     -118.2540  90071
# 7     -118.2652  90015
# 8     -118.2577  90071
# 9     -118.2643  90015
# 10    -118.2514  90014
# 11    -118.2469  90012
# 12    -118.2523  90014
# 13    -118.2427  90013
# 14    -118.2614  90017
# 15    -118.2472  90013
# 16    -118.2475  90014
# 17    -118.2741  90026
# 18    -118.2641  90015
# 19    -118.2526  90071
# 20    -118.2493  90012
# 21    -118.2657  90017
# 22    -118.2503  90014
# 23    -118.2458  90013
# 24    -118.2385  90012
# 25    -118.2490  90014
# 26    -118.2599  90071
# 27    -118.2556  90014
# 28    -118.2434  90013
# 29    -118.2387  90012
# ...         ...    ...
# 99970 -118.2766  90731
# 99971 -118.3195  90732
# 99972 -118.2923  90731
# 99973 -118.3027  90748
# 99974 -118.3032  90502
# 99975 -118.2879  90731
# 99976 -118.3012  90731
# 99977 -118.2459  90774
# 99978 -118.2715  90744
# 99979 -118.2640  90745
# 99980 -118.2946  90731
# 99981 -118.3098  90732
# 99982 -118.2750  90744
# 99983 -118.3056  90732
# 99984 -118.2691  90744
# 99985 -118.2923  90731
# 99986 -118.3072  90879
# 99987 -118.3011  90748
# 99988 -118.2665  90744
# 99989 -118.2857  90731
# 99990 -118.3066  90502
# 99991 -118.2804  90731
# 99992 -118.2747  90744
# 99993 -118.2747  90744
# 99994 -118.2698  90744
# 99995 -118.3011  90710
# 99996 -118.2814  90731
# 99997 -118.2817  90731
# 99998 -118.3208  90732
# 99999 -118.2924  90731
#
# [100000 rows x 29 columns]

# %%
_100k_crime_df.tail()
# Out:
#        DR Number Date Reported Date Occurred  Time Occurred  Area ID  \
# 99995  140504322    01/08/2014    01/07/2014           2000        5
# 99996  140504323    01/08/2014    01/08/2014           2315        5
# 99997  140504325    01/08/2014    01/08/2014           1500        5
# 99998  140504326    01/09/2014    01/07/2014            900        5
# 99999  140504327    01/09/2014    01/09/2014              1        5
#
#       Area Name  Reporting District  Crime Code  \
# 99995    Harbor                 509         440
# 99996    Harbor                 567         626
# 99997    Harbor                 558         310
# 99998    Harbor                 581         341
# 99999    Harbor                 563         624
#
#                                   Crime Code Description  \
# 99995                 THEFT PLAIN - PETTY ($950 & UNDER)
# 99996                  INTIMATE PARTNER - SIMPLE ASSAULT
# 99997                                           BURGLARY
# 99998  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...
# 99999                           BATTERY - SIMPLE ASSAULT
#
#                        MO Codes  ...  Crime Code 1 Crime Code 2 Crime Code 3  \
# 99995                      0344  ...         440.0          NaN          NaN
# 99996  2000 1813 0444 0913 0416  ...         626.0          NaN          NaN
# 99997       0344 0358 1606 1402  ...         310.0        998.0          NaN
# 99998                      0352  ...         341.0          NaN          NaN
# 99999            0416 0429 0444  ...         624.0          NaN          NaN
#
#        Crime Code 4                                  Address  Cross Street  \
# 99995           NaN  1400 W  LOMITA                       BL           NaN
# 99996           NaN  1500 S  PALOS VERDES                 ST           NaN
# 99997           NaN   200 W  SEPULVEDA                    ST           NaN
# 99998           NaN  2100    MCRAE                        DR           NaN
# 99999           NaN                                     13TH        GAFFEY
#
#                    location      lat      long    zip
# 99995  (33.7978, -118.3011)  33.7978 -118.3011  90710
# 99996  (33.7306, -118.2814)  33.7306 -118.2814  90731
# 99997  (33.7451, -118.2817)  33.7451 -118.2817  90731
# 99998  (33.7263, -118.3208)  33.7263 -118.3208  90732
# 99999  (33.7324, -118.2924)  33.7324 -118.2924  90731
#
# [5 rows x 29 columns]

# %%
_100k_crime_df['date reported formatted'] = pd.to_datetime(_100k_crime_df['Date Reported'], infer_datetime_format=True)

# %%
_100k_crime_df[['date reported formatted']].sort_values(by='date reported formatted', ascending=False).head()
# Out:
#       date reported formatted
# 64142              2019-04-26
# 64067              2019-04-23
# 64145              2019-04-22
# 64151              2019-04-22
# 64066              2019-04-22

# %%
cols = list(_100k_crime_df.columns)

# %%
cols = cols[-1:] + cols[:-1]

# %%
cols.insert(0, 'DR Number')

# %%
cols.pop(2)
# Out:
# 'DR Number'

# %%
cols
# Out:
# ['DR Number',
#  'date reported formatted',
#  'Date Reported',
#  'Date Occurred',
#  'Time Occurred',
#  'Area ID',
#  'Area Name',
#  'Reporting District',
#  'Crime Code',
#  'Crime Code Description',
#  'MO Codes',
#  'Victim Age',
#  'Victim Sex',
#  'Victim Descent',
#  'Premise Code',
#  'Premise Description',
#  'Weapon Used Code',
#  'Weapon Description',
#  'Status Code',
#  'Status Description',
#  'Crime Code 1',
#  'Crime Code 2',
#  'Crime Code 3',
#  'Crime Code 4',
#  'Address',
#  'Cross Street',
#  'location',
#  'lat',
#  'long',
#  'zip']

# %%
_100k_crime_df = _100k_crime_df[cols].copy()

# %%
_100k_crime_df.tail(2)
# Out:
#        DR Number date reported formatted Date Reported Date Occurred  \
# 99998  140504326              2014-01-09    01/09/2014    01/07/2014
# 99999  140504327              2014-01-09    01/09/2014    01/09/2014
#
#        Time Occurred  Area ID Area Name  Reporting District  Crime Code  \
# 99998            900        5    Harbor                 581         341
# 99999              1        5    Harbor                 563         624
#
#                                   Crime Code Description  ... Crime Code 1  \
# 99998  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...  ...        341.0
# 99999                           BATTERY - SIMPLE ASSAULT  ...        624.0
#
#        Crime Code 2 Crime Code 3 Crime Code 4  \
# 99998           NaN          NaN          NaN
# 99999           NaN          NaN          NaN
#
#                                        Address Cross Street  \
# 99998  2100    MCRAE                        DR          NaN
# 99999                                     13TH       GAFFEY
#
#                    location      lat      long    zip
# 99998  (33.7263, -118.3208)  33.7263 -118.3208  90732
# 99999  (33.7324, -118.2924)  33.7324 -118.2924  90731
#
# [2 rows x 30 columns]

# %%
# Quick visual inspection of the 'Victim Age' 100k rows
data = _100k_crime_df['Victim Age'].value_counts()
names = list(data.index)
fig, axs = plt.subplots(figsize=(8,5))
axs.bar(names, data)

plt.show()

# %%
# Quick visual inspection of the 'Victim Age' 1.9 mill rows
data = crime_df['Victim Age'].value_counts()
names = list(data.index)
fig, axs = plt.subplots(figsize=(8,5))
axs.bar(names, data)

plt.show()

# %% [markdown]
# # Load  (Mongo and SQL)

# %%
# Save the _1k_crime_df to a csv file
#added the amount of rows to the name of the file for easy finding
_100k_crime_df.to_csv(f"Resources/crime{_100k_crime_df['zip'].count()}.csv", index=False)

# %% [markdown]
# # mongodb

# %%
import pymongo

# %%
# Setup connection to mongodb
conn = "mongodb://localhost:27017"
client = pymongo.MongoClient(conn)

# Select database and collection to use
db = client.la_crime_100k
crime_reports = db.crime_reports

# %%
# Convert the dataframe to dictionary format for mongo
crimeData = _100k_crime_df.to_dict(orient='records')

# %%
# inspect the dictionary 
crimeData[0]
# Out:
# {'DR Number': 11401303,
#  'date reported formatted': Timestamp('2010-09-13 00:00:00'),
#  'Date Reported': '09/13/2010',
#  'Date Occurred': '09/12/2010',
#  'Time Occurred': 45,
#  'Area ID': 14,
#  'Area Name': 'Pacific',
#  'Reporting District': 1485,
#  'Crime Code': 740,
#  'Crime Code Description': 'VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)',
#  'MO Codes': '0329',
#  'Victim Age': 0,
#  'Victim Sex': 'M',
#  'Victim Descent': 'W',
#  'Premise Code': 101.0,
#  'Premise Description': 'STREET',
#  'Weapon Used Code': nan,
#  'Weapon Description': nan,
#  'Status Code': 'IC',
#  'Status Description': 'Invest Cont',
#  'Crime Code 1': 740.0,
#  'Crime Code 2': nan,
#  'Crime Code 3': nan,
#  'Crime Code 4': nan,
#  'Address': 'SEPULVEDA                    BL',
#  'Cross Street': 'MANCHESTER                   AV',
#  'location': '(33.9599, -118.3962)',
#  'lat': 33.9599,
#  'long': -118.3962,
#  'zip': '90045'}

# %% [markdown]
# ### First Collection: LA Crime Data

# %%
crime_reports.insert_many(crimeData)

# %%
# Test query the mongo db
results = crime_reports.find()
for result in results[:2]:
    print(result, '\n')
# Out:
# {'_id': ObjectId('5ce41f22be1a77b335fc0108'), 'DR Number': 11401303, 'Date Reported': '09/13/2010', 'Date Occurred': '09/12/2010', 'Time Occurred': 45, 'Area ID': 14, 'Area Name': 'Pacific', 'Reporting District': 1485, 'Crime Code': 740, 'Crime Code Description': 'VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)', 'MO Codes': '0329', 'Victim Age': 0, 'Victim Sex': 'M', 'Victim Descent': 'W', 'Premise Code': 101.0, 'Premise Description': 'STREET', 'Weapon Used Code': nan, 'Weapon Description': nan, 'Status Code': 'IC', 'Status Description': 'Invest Cont', 'Crime Code 1': 740.0, 'Crime Code 2': nan, 'Crime Code 3': nan, 'Crime Code 4': nan, 'Address': 'SEPULVEDA                    BL', 'Cross Street': 'MANCHESTER                   AV', 'location': '(33.9599, -118.3962)', 'lat': 33.9599, 'long': -118.3962, 'zip': '90045'}
#
# {'_id': ObjectId('5ce41f22be1a77b335fc0109'), 'DR Number': 70309629, 'Date Reported': '08/09/2010', 'Date Occurred': '08/09/2010', 'Time Occurred': 1515, 'Area ID': 13, 'Area Name': 'Newton', 'Reporting District': 1324, 'Crime Code': 946, 'Crime Code Description': 'OTHER MISCELLANEOUS CRIME', 'MO Codes': '0344', 'Victim Age': 0, 'Victim Sex': 'M', 'Victim Descent': 'H', 'Premise Code': 103.0, 'Premise Description': 'ALLEY', 'Weapon Used Code': nan, 'Weapon Description': nan, 'Status Code': 'IC', 'Status Description': 'Invest Cont', 'Crime Code 1': 946.0, 'Crime Code 2': nan, 'Crime Code 3': nan, 'Crime Code 4': nan, 'Address': '1300 E  21ST                         ST', 'Cross Street': nan, 'location': '(34.0224, -118.2524)', 'lat': 34.0224, 'long': -118.2524, 'zip': '90021'}

# %% [markdown]
# ## Second Collection: Census zips:

# %%
# Read in from census zips csv file
census_df = pd.read_csv('Resources/censusZips2017.csv')
census_df[:2]
# Out:
#    Zipcode  Population  Unemployment Count  Unemployment Rate
# 0      601     17599.0              2454.0          13.943974
# 1      602     39209.0              2538.0           6.473004

# %%
# Save df to dictionary for mongo uploading
censusData = census_df.to_dict(orient = 'records')

# %%
### Create the  collection to hold census data
censusZips = db.censusZips

# %%
censusZips.insert_many(censusData)

# %%
## Test query the mongodb new collection
censusResults = censusZips.find()

# %%
for result in censusResults[:2]:
    print(result, '\n')
# Out:
# {'_id': ObjectId('5ce69699a3a7e51e423ded51'), 'Zipcode': 601, 'Population': 17599.0, 'Unemployment Count': 2454.0, 'Unemployment Rate': 13.943974089436901}
#
# {'_id': ObjectId('5ce69699a3a7e51e423ded52'), 'Zipcode': 602, 'Population': 39209.0, 'Unemployment Count': 2538.0, 'Unemployment Rate': 6.473003647121835}

# %% [markdown]
# #  SQL

# %%
from sqlalchemy import create_engine

# %%
database_path = "Resources/la_crime_100k.sqlite"

# %%
engine = create_engine(f"sqlite:///{database_path}")

# %%
engine.table_names()
# Out:
# []

# %% [markdown]
# ### First Table: LA crime data

# %%
_100k_crime_df.to_sql(name='LaCrime', con=engine, if_exists='append', index=False)

# %%
engine.table_names()
# Out:
# ['LaCrime']

# %%
# Test Query the LaCrime table
pd.read_sql_query('select * from LaCrime', con=engine).tail(2)
# Out:
#        DR Number     date reported formatted Date Reported Date Occurred  \
# 99998  140504326  2014-01-09 00:00:00.000000    01/09/2014    01/07/2014
# 99999  140504327  2014-01-09 00:00:00.000000    01/09/2014    01/09/2014
#
#        Time Occurred  Area ID Area Name  Reporting District  Crime Code  \
# 99998            900        5    Harbor                 581         341
# 99999              1        5    Harbor                 563         624
#
#                                   Crime Code Description  ... Crime Code 1  \
# 99998  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...  ...        341.0
# 99999                           BATTERY - SIMPLE ASSAULT  ...        624.0
#
#        Crime Code 2 Crime Code 3 Crime Code 4  \
# 99998           NaN          NaN          NaN
# 99999           NaN          NaN          NaN
#
#                                        Address Cross Street  \
# 99998  2100    MCRAE                        DR         None
# 99999                                     13TH       GAFFEY
#
#                    location      lat      long    zip
# 99998  (33.7263, -118.3208)  33.7263 -118.3208  90732
# 99999  (33.7324, -118.2924)  33.7324 -118.2924  90731
#
# [2 rows x 30 columns]

# %% [markdown]
# ## Second Table: Census zips:

# %%
# Import data for the census table
censusData = pd.read_csv('Resources/censusZips2017.csv')

# %%
censusData[:2]
# Out:
#    Zipcode  Population  Unemployment Count  Unemployment Rate
# 0      601     17599.0              2454.0          13.943974
# 1      602     39209.0              2538.0           6.473004

# %%
# check tables
engine.table_names()
# Out:
# ['LaCrime']

# %%
# Create the new CensusZips table 
censusData.to_sql(name='CensusZips', con=engine, if_exists='append', index=False)

# %%
engine.table_names()
# Out:
# ['CensusZips', 'LaCrime']

# %% [markdown]
# ### Test Query the CensusZips table

# %%
pd.read_sql_query('select * from CensusZips', con=engine).tail()
# Out:
#        Zipcode  Population  Unemployment Count  Unemployment Rate
# 33115    99923         0.0                 0.0                NaN
# 33116    99925       901.0               124.0          13.762486
# 33117    99926      1684.0               132.0           7.838480
# 33118    99927        59.0                 0.0           0.000000
# 33119    99929      2455.0                83.0           3.380855

# %% [markdown]
# # Test Query both tables  performing a join on the zip code

# %%
query1 = '''
SELECT
    LaCrime.zip, COUNT(LaCrime.zip) AS crime_reports_count, `Unemployment Rate` AS `zip_unemployment_%`
FROM
    LaCrime JOIN CensusZips ON LaCrime.zip = CensusZips.Zipcode
GROUP BY
    LaCrime.zip ORDER by count(LaCrime.zip) DESC
'''

query2 = '''
SELECT
    LaCrime.zip, COUNT(LaCrime.zip) AS crime_reports_count, `Unemployment Rate` AS `zip_unemployment_%`
FROM
    LaCrime JOIN CensusZips ON LaCrime.zip = CensusZips.Zipcode
GROUP BY
    LaCrime.zip ORDER BY `Unemployment Rate`DESC
'''

# %%
pd.read_sql_query(query1, con=engine)
# Out:
#        zip  crime_reports_count  zip_unemployment_%
# 0    90057                 4361            4.946446
# 1    90008                 3575            5.537872
# 2    90007                 3265            5.885350
# 3    90033                 3101            3.097807
# 4    90018                 3059            5.163807
# 5    90013                 3041            6.832818
# 6    90037                 2852            4.558968
# 7    90062                 2742            4.130609
# 8    90016                 2717            4.178995
# 9    90017                 2624            3.486169
# 10   90014                 2422            5.197084
# 11   90029                 2175            5.125763
# 12   90015                 2172            4.319612
# 13   90071                 2157                 NaN
# 14   90023                 2077            4.130937
# 15   90032                 2036            5.250597
# 16   90026                 2029            4.860878
# 17   90031                 1838            4.217068
# 18   90028                 1633            7.834739
# 19   90003                 1547            5.440488
# 20   90012                 1439            2.880147
# 21   90011                 1374            3.659383
# 22   90731                 1331            4.892457
# 23   90006                 1304            5.475782
# 24   91331                 1179            4.810967
# 25   90744                 1152            3.650998
# 26   91335                 1152            3.540101
# 27   91303                 1129            3.304806
# 28   91405                 1061            5.557787
# 29   90045                 1060            3.812168
# ..     ...                  ...                 ...
# 142  90303                    3            5.341066
# 143  90804                    3            3.835923
# 144  90240                    2            2.707012
# 145  90254                    2            2.379747
# 146  90266                    2            2.591182
# 147  90403                    2            4.373284
# 148  90802                    2            4.062049
# 149  90806                    2            3.531594
# 150  91711                    2            2.769881
# 151  91744                    2            4.354924
# 152  90262                    1            4.181976
# 153  90278                    1            3.232209
# 154  90604                    1            3.258479
# 155  90640                    1            3.806631
# 156  90660                    1            3.377084
# 157  90715                    1            3.096539
# 158  90755                    1            3.661169
# 159  90807                    1            3.046766
# 160  90810                    1            4.862132
# 161  90813                    1            5.274473
# 162  91006                    1            2.722892
# 163  91016                    1            4.627139
# 164  91107                    1            2.866549
# 165  91384                    1            3.100775
# 166  91501                    1            5.437488
# 167  91702                    1            3.958600
# 168  91754                    1            2.742043
# 169  91768                    1            5.713969
# 170  93550                    1            4.165017
# 171  93551                    1            4.272006
#
# [172 rows x 3 columns]

# %%
pd.read_sql_query(query2, con=engine)
# Out:
#        zip  crime_reports_count  zip_unemployment_%
# 0    90028                 1633            7.834739
# 1    90302                   22            7.772239
# 2    91602                  388            6.888725
# 3    90013                 3041            6.832818
# 4    90068                  105            6.558962
# 5    90043                  735            6.531153
# 6    90021                  762            6.396453
# 7    90047                  573            6.042358
# 8    91403                  426            6.009645
# 9    90007                 3265            5.885350
# 10   90301                   27            5.863852
# 11   90056                  131            5.839780
# 12   91768                    1            5.713969
# 13   91604                  369            5.701325
# 14   91607                  501            5.675047
# 15   91405                 1061            5.557787
# 16   90008                 3575            5.537872
# 17   91203                   15            5.502675
# 18   90006                 1304            5.475782
# 19   90003                 1547            5.440488
# 20   91501                    1            5.437488
# 21   90303                    3            5.341066
# 22   90059                  125            5.332517
# 23   90063                  651            5.329001
# 24   90813                    1            5.274473
# 25   90032                 2036            5.250597
# 26   91205                   44            5.219385
# 27   90404                   86            5.202338
# 28   90014                 2422            5.197084
# 29   90027                  375            5.180200
# ..     ...                  ...                 ...
# 142  90715                    1            3.096539
# 143  91030                   80            3.068620
# 144  90807                    1            3.046766
# 145  91342                  383            2.997598
# 146  90049                  266            2.994885
# 147  91356                  569            2.942727
# 148  90212                   53            2.922693
# 149  90012                 1439            2.880147
# 150  91107                    1            2.866549
# 151  91711                    2            2.769881
# 152  91754                    1            2.742043
# 153  91006                    1            2.722892
# 154  90240                    2            2.707012
# 155  91326                  294            2.660037
# 156  91105                    9            2.603511
# 157  91040                  280            2.602230
# 158  90266                    2            2.591182
# 159  90210                   28            2.453038
# 160  90254                    2            2.379747
# 161  91803                    8            2.355908
# 162  91324                  660            2.335471
# 163  90232                  343            2.267070
# 164  91214                   10            2.107063
# 165  90077                   94            2.081468
# 166  90064                  475            2.003307
# 167  90272                  196            1.849348
# 168  91436                  234            1.453292
# 169  90067                  242            1.342282
# 170  90071                 2157                 NaN
# 171  91608                  153                 NaN
#
# [172 rows x 3 columns]

# %% [markdown]
# ## Row 149 zip code 90012
#
# [90012 stats @ unitedstateszipcodes.org](https://www.unitedstateszipcodes.org/90012/)

# %% [markdown]
# -------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------

# %% [markdown]
# ## TESTING LINES 👇🏾

# %% [markdown]
# #### FALIED TEST TO THE ZIP EXTRACTION FUNCTION @ BOTTOM

# %%
# 😾
small_df = crime_df[:10]
small_df

small_df['zip'] = small_df.apply(computeNearestZip(small_df['lat'],small_df['long']), axis=1)
