# %%
import requests
import json
import pandas as pd
from credentials import APIKey
import time

# %%
MY_API_KEY = APIKey
HEADERS = {'Authorization': 'bearer %s' % MY_API_KEY}

# %%
# us_cannabis_url = "https://api.yelp.com/v3/businesses/search"
base_url = "https://api.yelp.com/v3/businesses/search"

# %%
atl_PARAMETERS = {'location': 'Atlanta ga united states',
                  'limit': 50,
                  'radius': 40000
                 }

# %%
atl_response = requests.get(url = base_url,
                        params = atl_PARAMETERS,
                        headers = HEADERS)

# %%
response_url = atl_response.url
print(f"{response_url}")
# Out:
# https://api.yelp.com/v3/businesses/search?location=Atlanta+ga+united+states&limit=50&radius=40000

# %%
atl_json_response = atl_response.json()

# %%
print(type(atl_json_response['total']))
print(len(atl_json_response['businesses']))
atl_json_response.keys()
print(f"atl_response['total']: {atl_json_response['total']}")
# Out:
# <class 'int'>
# 50
# atl_response['total']: 3700

# %%
atl_biz_count = atl_json_response['total']
atl_biz_count
# Out:
# 3700

# %%
# atl_json_response['businesses'][0]

# %%
# [val['title'] for val in   atl_json_response['businesses'][0]['categories']]
', '.join([val['title'] for val in atl_json_response['businesses'][0]['categories']])
# Out:
# 'Asian Fusion, Southern, Seafood'

# %%
if atl_biz_count > 1000:
    atl_biz_count = 1000

# %%
atl_biz_count
bins = []
temp_urls = []
response_url
# Out:
# 'https://api.yelp.com/v3/businesses/search?location=Atlanta+ga+united+states&limit=50&radius=40000'

# %%
for i in range(50, atl_biz_count, 50):
    bins.append(i)
    
print(bins)
# Out:
# [50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700, 750, 800, 850, 900, 950]

# %%
for i in range(len(bins)):
    temp_urls.append(response_url + "&offset=" + f"{str(bins[i])}")

# %%
print(temp_urls[-1])
# Out:
# https://api.yelp.com/v3/businesses/search?location=Atlanta+ga+united+states&limit=50&radius=40000&offset=950

# %%
atl_biz_df = pd.DataFrame()

# %%
atl_biz_df['id'] = ''
atl_biz_df['alias'] = ''
atl_biz_df['name'] = ''
atl_biz_df['categories'] = ''
atl_biz_df['review_count'] = ''
atl_biz_df['rating'] = ''
atl_biz_df['lat'] = ''
atl_biz_df['long'] = ''
# us_cannabis['transactions'] = ''
atl_biz_df['address'] = ''
atl_biz_df['city'] = ''
atl_biz_df['zip_code'] = ''
atl_biz_df['country'] = ''
atl_biz_df['state'] = ''
atl_biz_df['phone'] = ''

# %%
# ', '.join([val['title'] for val in atl_json_response['businesses'][-1]['categories']])
# atl_biz_df.set_value(0, "categories", ', '.join([val['title'] for val in atl_json_response['businesses'][0]['categories']]) )

# %%
atl_json_response['businesses'][0]

# %%
atl_json_response['businesses'][0]
# Out:
# {'id': 'U-i6cq-yFRVJC4pIKSLX9Q',
#  'alias': 'poor-calvins-atlanta-15',
#  'name': "Poor Calvin's",
#  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hd7Ith2Gm3QnrQqOzI_JvA/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/poor-calvins-atlanta-15?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#  'review_count': 2732,
#  'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#   {'alias': 'southern', 'title': 'Southern'},
#   {'alias': 'seafood', 'title': 'Seafood'}],
#  'rating': 4.5,
#  'coordinates': {'latitude': 33.7684, 'longitude': -84.38226},
#  'transactions': ['delivery', 'pickup'],
#  'price': '$$',
#  'location': {'address1': '510 Piedmont Ave NE',
#   'address2': None,
#   'address3': '',
#   'city': 'Atlanta',
#   'zip_code': '30308',
#   'country': 'US',
#   'state': 'GA',
#   'display_address': ['510 Piedmont Ave NE', 'Atlanta, GA 30308']},
#  'phone': '+14042544051',
#  'display_phone': '(404) 254-4051',
#  'distance': 5038.783352167851}

# %%
index_ = 0
i = 0
j = 0

try:
    for i in range(len(temp_urls[:3])):
        temp_response = requests.get(url = temp_urls[i], headers = HEADERS)
        temp_response_json = temp_response.json()
        print(f"data retrieval begins: first biz: {temp_response_json['businesses']['name']}")
        time.sleep(2)

        for j in range(len(temp_response_json['businesses'])):
            atl_biz_df.set_value(index_, "id", temp_response_json['businesses'][j]['id'])
            atl_biz_df.set_value(index_, "alias", temp_response_json['businesses'][j]['alias'])

            atl_biz_df.set_value(index_, "name", temp_response_json['businesses'][j]['name'])
            atl_biz_df.set_value(index_, "categories", ', '.join([val['title'] for val in temp_response_json['businesses'][j]['categories']]) )        

            atl_biz_df.set_value(index_, "review_count", temp_response_json['businesses'][j]['review_count'])
            atl_biz_df.set_value(index_, "rating", temp_response_json['businesses'][j]['rating'])

            atl_biz_df.set_value(index_, "lat", temp_response_json['businesses'][j]['coordinates']['latitude'])
            atl_biz_df.set_value(index_, "long", temp_response_json['businesses'][j]['coordinates']['longitude'])

            atl_biz_df.set_value(index_, "address", ' '.join(temp_response_json['businesses'][j]['location']['display_address']))

            atl_biz_df.set_value(index_, "city", temp_response_json['businesses'][j]['location']['city'])
            atl_biz_df.set_value(index_, "zip_code", temp_response_json['businesses'][j]['location']['zip_code'])
            atl_biz_df.set_value(index_, "country", temp_response_json['businesses'][j]['location']['country'])
            atl_biz_df.set_value(index_, "state", temp_response_json['businesses'][j]['location']['state'])

            atl_biz_df.set_value(i, "phone", temp_response_json['businesses'][j]['phone'])

            index_ += 1
except:
    print("Something went WRONG")

            time.sleep(4)

# %%
print(temp_urls[0])
temp_urls[:3]
# Out:
# https://api.yelp.com/v3/businesses/search?location=Atlanta+ga+united+states&limit=50&radius=40000&offset=50
# ['https://api.yelp.com/v3/businesses/search?location=Atlanta+ga+united+states&limit=50&radius=40000&offset=50',
#  'https://api.yelp.com/v3/businesses/search?location=Atlanta+ga+united+states&limit=50&radius=40000&offset=100',
#  'https://api.yelp.com/v3/businesses/search?location=Atlanta+ga+united+states&limit=50&radius=40000&offset=150']

# %%
atl_biz_df

# %%
cannabis_data_50 = response.json()

print(type(cannabis_data_50['total']))
print(len(cannabis_data_50['businesses']))

# %%
biz_count = cannabis_data_50['total']
biz_count
# Out:
# 72

# %%
cannabis_data_51 = cannabis_data

# %%
len(cannabis_data_51['businesses'])
# Out:
# 22

# %%
print(cannabis_data_50.keys())
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
print(cannabis_data_50['region'])
# Out:
# {'center': {'longitude': -122.43644714355469, 'latitude': 37.76089938976322}}

# %%
len(cannabis_data_50['businesses'])
cannabis_data_50['businesses'][0]['categories'][0]['alias']
cannabis_data_50['businesses'][0]
# Out:
# {'id': 'mOanZdaJQu4pBKAJShtHrA',
#  'alias': 'foggy-daze-delivery-service-san-francisco',
#  'name': 'Foggy Daze Delivery Service',
#  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/CH_qJYCo-iNkwzjbKALX_Q/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/foggy-daze-delivery-service-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#  'review_count': 108,
#  'categories': [{'alias': 'cannabis_clinics', 'title': 'Cannabis Clinics'}],
#  'rating': 5.0,
#  'coordinates': {'latitude': 37.76468, 'longitude': -122.43193},
#  'transactions': [],
#  'location': {'address1': '2261 Market St',
#   'address2': 'Ste 289',
#   'address3': '',
#   'city': 'San Francisco',
#   'zip_code': '94114',
#   'country': 'US',
#   'state': 'CA',
#   'display_address': ['2261 Market St', 'Ste 289', 'San Francisco, CA 94114']},
#  'phone': '+14152007451',
#  'display_phone': '(415) 200-7451',
#  'distance': 580.7917633416723}

# %%
cannabis_data_50.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
us_cannabis['id'] = ''
us_cannabis['alias'] = ''
us_cannabis['name'] = ''
us_cannabis['category'] = ''
us_cannabis['review_count'] = ''
us_cannabis['rating'] = ''
us_cannabis['lat'] = ''
us_cannabis['long'] = ''
# us_cannabis['transactions'] = ''
us_cannabis['address'] = ''
us_cannabis['city'] = ''
us_cannabis['zip_code'] = ''
us_cannabis['country'] = ''
us_cannabis['state'] = ''
us_cannabis['phone'] = ''

# %%
cannabis_world_df = pd.DataFrame();
us_cannabis_df = pd.DataFrame();

# %%
# sentence = ['this','is','a','sentence']
# '-'.join(sentence)
# 'this-is-a-sentence'

' '.join(cannabis_data_50['businesses'][0]['location']['display_address'])
# Out:
# '2261 Market St Ste 289 San Francisco, CA 94114'

# %%
for i in range(len(cannabis_data_50['businesses'])):
    us_cannabis_df.set_value(i, "id", cannabis_data_50['businesses'][i]['id'])
    us_cannabis_df.set_value(i, "alias", cannabis_data_50['businesses'][i]['alias'])
    
    us_cannabis_df.set_value(i, "name", cannabis_data_50['businesses'][i]['name'])
    us_cannabis_df.set_value(i, "category", cannabis_data_50['businesses'][i]['categories'][0]['alias'])
    us_cannabis_df.set_value(i, "review_count", cannabis_data_50['businesses'][i]['review_count'])
    us_cannabis_df.set_value(i, "rating", cannabis_data_50['businesses'][i]['rating'])

    us_cannabis_df.set_value(i, "lat", cannabis_data_50['businesses'][i]['coordinates']['latitude'])
    us_cannabis_df.set_value(i, "long", cannabis_data_50['businesses'][i]['coordinates']['longitude'])
    
    us_cannabis_df.set_value(i, "address", ' '.join(cannabis_data_50['businesses'][i]['location']['display_address']))
    
    us_cannabis_df.set_value(i, "city", cannabis_data_50['businesses'][i]['location']['city'])
    us_cannabis_df.set_value(i, "zip_code", cannabis_data_50['businesses'][i]['location']['zip_code'])
    us_cannabis_df.set_value(i, "country", cannabis_data_50['businesses'][i]['location']['country'])
    us_cannabis_df.set_value(i, "state", cannabis_data_50['businesses'][i]['location']['state'])
    
    us_cannabis_df.set_value(i, "phone", cannabis_data_50['businesses'][i]['phone'])
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   """
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   import sys
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # This is added back by InteractiveShellApp.init_path()
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   from ipykernel import kernelapp as app
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   app.launch_new_instance()
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
us_cannabis_df.head()
# Out:
#                        id                                      alias  \
# 0  mOanZdaJQu4pBKAJShtHrA  foggy-daze-delivery-service-san-francisco
# 1  PyH7DhskVlQ7N26EV-zzOA               purple-star-md-san-francisco
# 2  dMcSHwulNkMXnDkda5yVtw     barbary-coast-dispensary-san-francisco
# 3  KXbrOaeEzfl4FiytHO8N_Q              buzz-delivery-san-francisco-3
# 4  9nN-N3mI_bl6xefu0dmAZg      the-apothecarium-castro-san-francisco
#
#                           name          category  review_count  rating  \
# 0  Foggy Daze Delivery Service  cannabis_clinics         108.0     5.0
# 1              Purple Star, MD  cannabis_clinics         242.0     4.5
# 2     Barbary Coast Dispensary  cannabis_clinics         334.0     4.0
# 3                Buzz Delivery  cannabis_clinics          74.0     5.0
# 4    The Apothecarium - Castro  cannabis_clinics         293.0     4.0
#
#          lat        long                                         address  \
# 0  37.764680 -122.431930  2261 Market St Ste 289 San Francisco, CA 94114
# 1  37.756726 -122.418916         2520 Mission St San Francisco, CA 94110
# 2  37.782050 -122.407850          952 Mission St San Francisco, CA 94103
# 3  37.780773 -122.464218                         San Francisco, CA 94118
# 4  37.768354 -122.427565          2029 Market St San Francisco, CA 94114
#
#             city zip_code country state         phone
# 0  San Francisco    94114      US    CA  +14152007451
# 1  San Francisco    94110      US    CA  +14155501515
# 2  San Francisco    94103      US    CA  +14152434400
# 3  San Francisco    94118      US    CA  +14158555990
# 4  San Francisco    94114      US    CA  +14155002620

# %%
# print the response
print(json.dumps(cannabis_data, indent = 3))
# Out:
# {
#    "businesses": [
#       {
#          "id": "RrIduU6-SUNCanTEVF-hIQ",
#          "alias": "marco-polo-italian-ice-cream-san-francisco",
#          "name": "Marco Polo Italian Ice Cream",
#          "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/qZMP6QSGXd9-Vyq_hix2Fg/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/marco-polo-italian-ice-cream-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 1401,
#          "categories": [
#             {
#                "alias": "icecream",
#                "title": "Ice Cream & Frozen Yogurt"
#             },
#             {
#                "alias": "gelato",
#                "title": "Gelato"
#             },
#             {
#                "alias": "desserts",
#                "title": "Desserts"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 37.7426223,
#             "longitude": -122.481885
#          },
#          "transactions": [],
#          "price": "$",
#          "location": {
#             "address1": "1447 Taraval St",
#             "address2": "",
#             "address3": "",
#             "city": "San Francisco",
#             "zip_code": "94116",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "1447 Taraval St",
#                "San Francisco, CA 94116"
#             ]
#          },
#          "phone": "+14157312833",
#          "display_phone": "(415) 731-2833",
#          "distance": 4480.698934510479
#       },
#       {
#          "id": "1U9_ZNruMLf4EL0pMoxb_w",
#          "alias": "arsicault-bakery-san-francisco",
#          "name": "Arsicault Bakery",
#          "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/IPRgi4dgceBOgZWU28tPpA/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/arsicault-bakery-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 998,
#          "categories": [
#             {
#                "alias": "bakeries",
#                "title": "Bakeries"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 37.783429,
#             "longitude": -122.459307
#          },
#          "transactions": [],
#          "price": "$$",
#          "location": {
#             "address1": "397 Arguello Blvd",
#             "address2": null,
#             "address3": "",
#             "city": "San Francisco",
#             "zip_code": "94118",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "397 Arguello Blvd",
#                "San Francisco, CA 94118"
#             ]
#          },
#          "phone": "+14157509460",
#          "display_phone": "(415) 750-9460",
#          "distance": 3211.384136637487
#       },
#       {
#          "id": "UTVDbZv-qiHU06sDkoel3g",
#          "alias": "chez-maman-east-san-francisco",
#          "name": "Chez Maman East",
#          "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/gccHe5ofFMpNyh8vmS0VSw/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/chez-maman-east-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 2011,
#          "categories": [
#             {
#                "alias": "french",
#                "title": "French"
#             },
#             {
#                "alias": "burgers",
#                "title": "Burgers"
#             },
#             {
#                "alias": "creperies",
#                "title": "Creperies"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 37.7624388911845,
#             "longitude": -122.396692272318
#          },
#          "transactions": [
#             "delivery",
#             "pickup"
#          ],
#          "price": "$$",
#          "location": {
#             "address1": "1401 18th St",
#             "address2": "",
#             "address3": "",
#             "city": "San Francisco",
#             "zip_code": "94107",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "1401 18th St",
#                "San Francisco, CA 94107"
#             ]
#          },
#          "phone": "+14156559542",
#          "display_phone": "(415) 655-9542",
#          "distance": 3498.909842201317
#       },
#       {
#          "id": "A0AziPST4T6k-V3neWFRNA",
#          "alias": "plow-san-francisco",
#          "name": "Plow",
#          "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/KE7h62IAS2rhoE0V6FMknA/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/plow-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 2433,
#          "categories": [
#             {
#                "alias": "breakfast_brunch",
#                "title": "Breakfast & Brunch"
#             },
#             {
#                "alias": "newamerican",
#                "title": "American (New)"
#             }
#          ],
#          "rating": 4.0,
#          "coordinates": {
#             "latitude": 37.762537673684,
#             "longitude": -122.39535099572
#          },
#          "transactions": [],
#          "price": "$$",
#          "location": {
#             "address1": "1299 18th St",
#             "address2": "",
#             "address3": "",
#             "city": "San Francisco",
#             "zip_code": "94107",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "1299 18th St",
#                "San Francisco, CA 94107"
#             ]
#          },
#          "phone": "+14158217569",
#          "display_phone": "(415) 821-7569",
#          "distance": 3617.214576272711
#       },
#       {
#          "id": "_2EHMIdoYeWgsuAiWydjYQ",
#          "alias": "mission-beach-cafe-san-francisco-4",
#          "name": "Mission Beach Cafe",
#          "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/1KBDxxk4ubNk1t_1PlHJ8w/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/mission-beach-cafe-san-francisco-4?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 2681,
#          "categories": [
#             {
#                "alias": "coffee",
#                "title": "Coffee & Tea"
#             },
#             {
#                "alias": "newamerican",
#                "title": "American (New)"
#             },
#             {
#                "alias": "breakfast_brunch",
#                "title": "Breakfast & Brunch"
#             }
#          ],
#          "rating": 4.0,
#          "coordinates": {
#             "latitude": 37.768133,
#             "longitude": -122.424713
#          },
#          "transactions": [],
#          "price": "$$",
#          "location": {
#             "address1": "198 Guerrero St",
#             "address2": "",
#             "address3": "",
#             "city": "San Francisco",
#             "zip_code": "94103",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "198 Guerrero St",
#                "San Francisco, CA 94103"
#             ]
#          },
#          "phone": "+14158610198",
#          "display_phone": "(415) 861-0198",
#          "distance": 1308.011230207369
#       },
#       {
#          "id": "IJk76B-pTta_klpAZcpQdA",
#          "alias": "lous-cafe-san-francisco",
#          "name": "Lou's Cafe",
#          "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/UgwBr0vhX6fSNT_ILMeJvg/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/lous-cafe-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 1437,
#          "categories": [
#             {
#                "alias": "coffee",
#                "title": "Coffee & Tea"
#             },
#             {
#                "alias": "sandwiches",
#                "title": "Sandwiches"
#             },
#             {
#                "alias": "salad",
#                "title": "Salad"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 37.78045,
#             "longitude": -122.473308
#          },
#          "transactions": [
#             "delivery",
#             "pickup"
#          ],
#          "price": "$$",
#          "location": {
#             "address1": "5017 Geary Blvd",
#             "address2": "",
#             "address3": "",
#             "city": "San Francisco",
#             "zip_code": "94118",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "5017 Geary Blvd",
#                "San Francisco, CA 94118"
#             ]
#          },
#          "phone": "+14153794429",
#          "display_phone": "(415) 379-4429",
#          "distance": 3901.6725691148918
#       },
#       {
#          "id": "r7RwvYMwxDuK3u26fHbYDA",
#          "alias": "lim\u00f3n-rotisserie-san-francisco-3",
#          "name": "Lim\u00f3n Rotisserie",
#          "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/wvbMWakjpf0c-0QeucFl9Q/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/lim%C3%B3n-rotisserie-san-francisco-3?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 3078,
#          "categories": [
#             {
#                "alias": "peruvian",
#                "title": "Peruvian"
#             },
#             {
#                "alias": "tapasmallplates",
#                "title": "Tapas/Small Plates"
#             }
#          ],
#          "rating": 4.0,
#          "coordinates": {
#             "latitude": 37.7570666079255,
#             "longitude": -122.416596234642
#          },
#          "transactions": [
#             "pickup"
#          ],
#          "price": "$$",
#          "location": {
#             "address1": "1001 S Van Ness Ave",
#             "address2": "",
#             "address3": "",
#             "city": "San Francisco",
#             "zip_code": "94110",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "1001 S Van Ness Ave",
#                "San Francisco, CA 94110"
#             ]
#          },
#          "phone": "+14158212134",
#          "display_phone": "(415) 821-2134",
#          "distance": 1796.3791030607001
#       },
#       {
#          "id": "EFefgQdk_19WxQXvVtwEog",
#          "alias": "blue-bottle-coffee-san-francisco-8",
#          "name": "Blue Bottle Coffee",
#          "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/pJsxoTxQRX7Ec9fSfVBeMQ/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/blue-bottle-coffee-san-francisco-8?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 1663,
#          "categories": [
#             {
#                "alias": "coffee",
#                "title": "Coffee & Tea"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 37.77638,
#             "longitude": -122.423211
#          },
#          "transactions": [],
#          "price": "$$",
#          "location": {
#             "address1": "315 Linden St",
#             "address2": "",
#             "address3": "",
#             "city": "San Francisco",
#             "zip_code": "94102",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "315 Linden St",
#                "San Francisco, CA 94102"
#             ]
#          },
#          "phone": "+15106533394",
#          "display_phone": "(510) 653-3394",
#          "distance": 2077.661076831945
#       },
#       {
#          "id": "_EncdQezAzcShATMFXL0dA",
#          "alias": "tropisueno-san-francisco-8",
#          "name": "Tropisueno",
#          "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/hUZgDmue1VRfvIXai6I0wg/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/tropisueno-san-francisco-8?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 4162,
#          "categories": [
#             {
#                "alias": "cocktailbars",
#                "title": "Cocktail Bars"
#             },
#             {
#                "alias": "tacos",
#                "title": "Tacos"
#             }
#          ],
#          "rating": 4.0,
#          "coordinates": {
#             "latitude": 37.7853008468227,
#             "longitude": -122.403918653727
#          },
#          "transactions": [
#             "restaurant_reservation"
#          ],
#          "price": "$$",
#          "location": {
#             "address1": "75 Yerba Buena Ln",
#             "address2": "",
#             "address3": "",
#             "city": "San Francisco",
#             "zip_code": "94103",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "75 Yerba Buena Ln",
#                "San Francisco, CA 94103"
#             ]
#          },
#          "phone": "+14152430299",
#          "display_phone": "(415) 243-0299",
#          "distance": 3941.5902762189608
#       },
#       {
#          "id": "353bun0151fMbR3ut2d-nw",
#          "alias": "absinthe-brasserie-and-bar-san-francisco-2",
#          "name": "Absinthe Brasserie & Bar",
#          "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/AE80i8mNAmawM9R3SJcelg/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/absinthe-brasserie-and-bar-san-francisco-2?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 3211,
#          "categories": [
#             {
#                "alias": "french",
#                "title": "French"
#             },
#             {
#                "alias": "breakfast_brunch",
#                "title": "Breakfast & Brunch"
#             },
#             {
#                "alias": "bars",
#                "title": "Bars"
#             }
#          ],
#          "rating": 4.0,
#          "coordinates": {
#             "latitude": 37.77714,
#             "longitude": -122.42268
#          },
#          "transactions": [],
#          "price": "$$$",
#          "location": {
#             "address1": "398 Hayes St",
#             "address2": "",
#             "address3": "",
#             "city": "San Francisco",
#             "zip_code": "94102",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "398 Hayes St",
#                "San Francisco, CA 94102"
#             ]
#          },
#          "phone": "+14155511590",
#          "display_phone": "(415) 551-1590",
#          "distance": 2159.633139010338
#       },
#       {
#          "id": "-fqw8aDcx1Sgjs-4u__Aiw",
#          "alias": "fort-funston-san-francisco-3",
#          "name": "Fort Funston",
#          "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/nLxaNAC0Wkg2ggn818ifwA/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/fort-funston-san-francisco-3?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 948,
#          "categories": [
#             {
#                "alias": "parks",
#                "title": "Parks"
#             }
#          ],
#          "rating": 5.0,
#          "coordinates": {
#             "latitude": 37.714154842179,
#             "longitude": -122.500342737514
#          },
#          "transactions": [],
#          "location": {
#             "address1": "Skyline Blvd",
#             "address2": "",
#             "address3": "",
#             "city": "San Francisco",
#             "zip_code": "94132",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "Skyline Blvd",
#                "San Francisco, CA 94132"
#             ]
#          },
#          "phone": "+14155614323",
#          "display_phone": "(415) 561-4323",
#          "distance": 7654.163307316438
#       },
#       {
#          "id": "u39mZEYojBiNic3lqKhPNw",
#          "alias": "tacorea-san-francisco",
#          "name": "Tacorea",
#          "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/xJUH-UAXBuIEub6HbxPKFQ/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/tacorea-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 1448,
#          "categories": [
#             {
#                "alias": "mexican",
#                "title": "Mexican"
#             },
#             {
#                "alias": "korean",
#                "title": "Korean"
#             },
#             {
#                "alias": "latin",
#                "title": "Latin American"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 37.7897794,
#             "longitude": -122.410717
#          },
#          "transactions": [],
#          "price": "$",
#          "location": {
#             "address1": "809 Bush St",
#             "address2": "",
#             "address3": null,
#             "city": "San Francisco",
#             "zip_code": "94108",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "809 Bush St",
#                "San Francisco, CA 94108"
#             ]
#          },
#          "phone": "",
#          "display_phone": "",
#          "distance": 3930.8433222931662
#       },
#       {
#          "id": "yniMfk_yS1sk9dxPLDVchg",
#          "alias": "lands-end-trail-san-francisco",
#          "name": "Lands End Trail",
#          "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/R-_wdo0Zj1TewBwNsrFlgw/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/lands-end-trail-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 802,
#          "categories": [
#             {
#                "alias": "hiking",
#                "title": "Hiking"
#             }
#          ],
#          "rating": 5.0,
#          "coordinates": {
#             "latitude": 37.780077,
#             "longitude": -122.510029
#          },
#          "transactions": [],
#          "location": {
#             "address1": "680 Point Lobos Ave",
#             "address2": "",
#             "address3": "Golden Gate National Recreation Area",
#             "city": "San Francisco",
#             "zip_code": "94121",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "680 Point Lobos Ave",
#                "Golden Gate National Recreation Area",
#                "San Francisco, CA 94121"
#             ]
#          },
#          "phone": "",
#          "display_phone": "",
#          "distance": 6810.049102490965
#       },
#       {
#          "id": "CYttYTEiQuhSfo3SEh79fA",
#          "alias": "shizen-vegan-sushi-bar-and-izakaya-san-francisco",
#          "name": "Shizen Vegan Sushi Bar & Izakaya",
#          "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/ose-rlo_a7c6pybjIxjHbA/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/shizen-vegan-sushi-bar-and-izakaya-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 1361,
#          "categories": [
#             {
#                "alias": "sushi",
#                "title": "Sushi Bars"
#             },
#             {
#                "alias": "vegan",
#                "title": "Vegan"
#             },
#             {
#                "alias": "izakaya",
#                "title": "Izakaya"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 37.768314,
#             "longitude": -122.421642
#          },
#          "transactions": [
#             "restaurant_reservation"
#          ],
#          "price": "$$",
#          "location": {
#             "address1": "370 14th St",
#             "address2": "",
#             "address3": "",
#             "city": "San Francisco",
#             "zip_code": "94103",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "370 14th St",
#                "San Francisco, CA 94103"
#             ]
#          },
#          "phone": "+14156785767",
#          "display_phone": "(415) 678-5767",
#          "distance": 1540.5965160298517
#       },
#       {
#          "id": "vVN_oVe6jvr4PCmXg_m9CA",
#          "alias": "hollywood-cafe-san-francisco",
#          "name": "Hollywood Cafe",
#          "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/76uAEQSOn6nnSK0nPctmyA/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/hollywood-cafe-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 1982,
#          "categories": [
#             {
#                "alias": "breakfast_brunch",
#                "title": "Breakfast & Brunch"
#             },
#             {
#                "alias": "cafes",
#                "title": "Cafes"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 37.8065799,
#             "longitude": -122.41584
#          },
#          "transactions": [
#             "delivery",
#             "pickup"
#          ],
#          "price": "$$",
#          "location": {
#             "address1": "530 North Point St",
#             "address2": "",
#             "address3": "",
#             "city": "San Francisco",
#             "zip_code": "94133",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "530 North Point St",
#                "San Francisco, CA 94133"
#             ]
#          },
#          "phone": "+14155633779",
#          "display_phone": "(415) 563-3779",
#          "distance": 5380.06766521831
#       },
#       {
#          "id": "wEpiKz--Z2b1q_FSCCNiow",
#          "alias": "lolinda-san-francisco",
#          "name": "Lolinda",
#          "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/M8J3ehcOIRRI8ys1Q0hxtw/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/lolinda-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 1852,
#          "categories": [
#             {
#                "alias": "steak",
#                "title": "Steakhouses"
#             },
#             {
#                "alias": "tapasmallplates",
#                "title": "Tapas/Small Plates"
#             },
#             {
#                "alias": "latin",
#                "title": "Latin American"
#             }
#          ],
#          "rating": 4.0,
#          "coordinates": {
#             "latitude": 37.7566414790839,
#             "longitude": -122.41907298565
#          },
#          "transactions": [],
#          "price": "$$$",
#          "location": {
#             "address1": "2518 Mission St",
#             "address2": "",
#             "address3": "",
#             "city": "San Francisco",
#             "zip_code": "94110",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "2518 Mission St",
#                "San Francisco, CA 94110"
#             ]
#          },
#          "phone": "+14155506970",
#          "display_phone": "(415) 550-6970",
#          "distance": 1599.0638996264636
#       },
#       {
#          "id": "ykvr3ib1gHQHI4tznSn8iA",
#          "alias": "wayfare-tavern-san-francisco-2",
#          "name": "Wayfare Tavern",
#          "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/Dj4UcH5T821FI7n7VEL-vA/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/wayfare-tavern-san-francisco-2?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 3759,
#          "categories": [
#             {
#                "alias": "tradamerican",
#                "title": "American (Traditional)"
#             }
#          ],
#          "rating": 4.0,
#          "coordinates": {
#             "latitude": 37.7939484886016,
#             "longitude": -122.402307987213
#          },
#          "transactions": [],
#          "price": "$$$",
#          "location": {
#             "address1": "558 Sacramento St",
#             "address2": "",
#             "address3": "",
#             "city": "San Francisco",
#             "zip_code": "94111",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "558 Sacramento St",
#                "San Francisco, CA 94111"
#             ]
#          },
#          "phone": "+14157729060",
#          "display_phone": "(415) 772-9060",
#          "distance": 4744.189084845839
#       },
#       {
#          "id": "9yM20-7fj4LMrOO30nqkBw",
#          "alias": "l-ardoise-bistro-san-francisco",
#          "name": "L\u2019Ardoise Bistro",
#          "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/VJDYOLw03bUGeBLb14BRGA/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/l-ardoise-bistro-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 1228,
#          "categories": [
#             {
#                "alias": "french",
#                "title": "French"
#             },
#             {
#                "alias": "wine_bars",
#                "title": "Wine Bars"
#             },
#             {
#                "alias": "desserts",
#                "title": "Desserts"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 37.7665241,
#             "longitude": -122.4331385
#          },
#          "transactions": [],
#          "price": "$$$",
#          "location": {
#             "address1": "151 Noe St",
#             "address2": "",
#             "address3": "",
#             "city": "San Francisco",
#             "zip_code": "94114",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "151 Noe St",
#                "San Francisco, CA 94114"
#             ]
#          },
#          "phone": "+14154372600",
#          "display_phone": "(415) 437-2600",
#          "distance": 700.3831983058177
#       },
#       {
#          "id": "lNbKeOfCMTNkoihZHqrbrg",
#          "alias": "blue-bottle-coffee-san-francisco-21",
#          "name": "Blue Bottle Coffee",
#          "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/mjMHObH17E2NykWJufuVSg/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/blue-bottle-coffee-san-francisco-21?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 2186,
#          "categories": [
#             {
#                "alias": "coffee",
#                "title": "Coffee & Tea"
#             }
#          ],
#          "rating": 4.0,
#          "coordinates": {
#             "latitude": 37.7824664727379,
#             "longitude": -122.407753326389
#          },
#          "transactions": [],
#          "price": "$$",
#          "location": {
#             "address1": "66 Mint St",
#             "address2": "",
#             "address3": "",
#             "city": "San Francisco",
#             "zip_code": "94103",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "66 Mint St",
#                "San Francisco, CA 94103"
#             ]
#          },
#          "phone": "+15106533394",
#          "display_phone": "(510) 653-3394",
#          "distance": 3480.1988579855497
#       },
#       {
#          "id": "1hMD7RQogPDWpE-p3LKjXA",
#          "alias": "lol\u00f3-san-francisco-4",
#          "name": "Lol\u00f3",
#          "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/-_hqewRYasro3NpC-v4Fug/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/lol%C3%B3-san-francisco-4?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 2025,
#          "categories": [
#             {
#                "alias": "tapasmallplates",
#                "title": "Tapas/Small Plates"
#             }
#          ],
#          "rating": 4.0,
#          "coordinates": {
#             "latitude": 37.7573462,
#             "longitude": -122.4214034
#          },
#          "transactions": [
#             "restaurant_reservation"
#          ],
#          "price": "$$",
#          "location": {
#             "address1": "974 Valencia St",
#             "address2": "",
#             "address3": "",
#             "city": "San Francisco",
#             "zip_code": "94110",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "974 Valencia St",
#                "San Francisco, CA 94110"
#             ]
#          },
#          "phone": "+14156435656",
#          "display_phone": "(415) 643-5656",
#          "distance": 1380.24804973913
#       },
#       {
#          "id": "YzA3ocJ0XvsTuD18qr2ctg",
#          "alias": "mr-and-mrs-miscellaneous-san-francisco",
#          "name": "Mr. and Mrs. Miscellaneous",
#          "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/oVaADVRdwn8q21CaFWfFWA/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/mr-and-mrs-miscellaneous-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 1406,
#          "categories": [
#             {
#                "alias": "icecream",
#                "title": "Ice Cream & Frozen Yogurt"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 37.7578152,
#             "longitude": -122.3880343
#          },
#          "transactions": [],
#          "price": "$",
#          "location": {
#             "address1": "699 22nd St",
#             "address2": "",
#             "address3": "",
#             "city": "San Francisco",
#             "zip_code": "94107",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "699 22nd St",
#                "San Francisco, CA 94107"
#             ]
#          },
#          "phone": "+14159700750",
#          "display_phone": "(415) 970-0750",
#          "distance": 4261.606719975425
#       },
#       {
#          "id": "9lX1QuC6GBj7WyKImHkRRw",
#          "alias": "mr-holmes-bakehouse-san-francisco",
#          "name": "Mr Holmes Bakehouse",
#          "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/O6PqDV4OM4PJ1xr4-dK5bQ/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/mr-holmes-bakehouse-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 2321,
#          "categories": [
#             {
#                "alias": "bakeries",
#                "title": "Bakeries"
#             }
#          ],
#          "rating": 4.0,
#          "coordinates": {
#             "latitude": 37.7875909362522,
#             "longitude": -122.418352626264
#          },
#          "transactions": [],
#          "price": "$$",
#          "location": {
#             "address1": "1042 Larkin St",
#             "address2": "",
#             "address3": "",
#             "city": "San Francisco",
#             "zip_code": "94109",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "1042 Larkin St",
#                "San Francisco, CA 94109"
#             ]
#          },
#          "phone": "+14158297700",
#          "display_phone": "(415) 829-7700",
#          "distance": 3367.1999359858455
#       },
#       {
#          "id": "jqEpBbf_qNfWuz_GBkwCjw",
#          "alias": "scomas-restaurant-san-francisco-3",
#          "name": "Scoma's Restaurant",
#          "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/5ZqAdIz1IhUDlmK6qP3WvA/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/scomas-restaurant-san-francisco-3?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 3477,
#          "categories": [
#             {
#                "alias": "seafood",
#                "title": "Seafood"
#             },
#             {
#                "alias": "italian",
#                "title": "Italian"
#             },
#             {
#                "alias": "lounges",
#                "title": "Lounges"
#             }
#          ],
#          "rating": 4.0,
#          "coordinates": {
#             "latitude": 37.808944,
#             "longitude": -122.418462
#          },
#          "transactions": [
#             "restaurant_reservation"
#          ],
#          "price": "$$$",
#          "location": {
#             "address1": "1965 Al Scoma Way",
#             "address2": "",
#             "address3": "",
#             "city": "San Francisco",
#             "zip_code": "94133",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "1965 Al Scoma Way",
#                "San Francisco, CA 94133"
#             ]
#          },
#          "phone": "+14157714383",
#          "display_phone": "(415) 771-4383",
#          "distance": 5571.204721217614
#       },
#       {
#          "id": "hWE2CDphzZ3nXlwv3Uk6Og",
#          "alias": "philz-coffee-san-francisco-3",
#          "name": "Philz Coffee",
#          "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/cK3WII_tsobxGzfYtOhzLw/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/philz-coffee-san-francisco-3?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 1382,
#          "categories": [
#             {
#                "alias": "coffee",
#                "title": "Coffee & Tea"
#             },
#             {
#                "alias": "sandwiches",
#                "title": "Sandwiches"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 37.7756640166767,
#             "longitude": -122.39345180371
#          },
#          "transactions": [],
#          "price": "$",
#          "location": {
#             "address1": "201 Berry St",
#             "address2": "",
#             "address3": "",
#             "city": "San Francisco",
#             "zip_code": "94158",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "201 Berry St",
#                "San Francisco, CA 94158"
#             ]
#          },
#          "phone": "+14158759943",
#          "display_phone": "(415) 875-9943",
#          "distance": 4120.4371805947885
#       },
#       {
#          "id": "-sg6DqQNGyTMt0MHoY7diQ",
#          "alias": "good-mong-kok-bakery-san-francisco",
#          "name": "Good Mong Kok Bakery",
#          "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/eYQS3PcMtY63dzHEnab76w/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/good-mong-kok-bakery-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 2386,
#          "categories": [
#             {
#                "alias": "bakeries",
#                "title": "Bakeries"
#             },
#             {
#                "alias": "dimsum",
#                "title": "Dim Sum"
#             },
#             {
#                "alias": "cantonese",
#                "title": "Cantonese"
#             }
#          ],
#          "rating": 4.0,
#          "coordinates": {
#             "latitude": 37.7954584839809,
#             "longitude": -122.408358365012
#          },
#          "transactions": [],
#          "price": "$",
#          "location": {
#             "address1": "1039 Stockton St",
#             "address2": "",
#             "address3": "",
#             "city": "San Francisco",
#             "zip_code": "94108",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "1039 Stockton St",
#                "San Francisco, CA 94108"
#             ]
#          },
#          "phone": "+14153972688",
#          "display_phone": "(415) 397-2688",
#          "distance": 4567.4100400050365
#       },
#       {
#          "id": "u3mX2Hkc0XoCgPxG6xRFkg",
#          "alias": "palace-of-fine-arts-san-francisco",
#          "name": "Palace Of Fine Arts",
#          "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/947-VoWzgNCFq0GLN7t3JA/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/palace-of-fine-arts-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 938,
#          "categories": [
#             {
#                "alias": "landmarks",
#                "title": "Landmarks & Historical Buildings"
#             },
#             {
#                "alias": "venues",
#                "title": "Venues & Event Spaces"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 37.8041385,
#             "longitude": -122.448286
#          },
#          "transactions": [],
#          "location": {
#             "address1": "3601 Lyon St",
#             "address2": "",
#             "address3": "",
#             "city": "San Francisco",
#             "zip_code": "94123",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "3601 Lyon St",
#                "San Francisco, CA 94123"
#             ]
#          },
#          "phone": "+14158861929",
#          "display_phone": "(415) 886-1929",
#          "distance": 4903.449589709836
#       },
#       {
#          "id": "dMlsQsPU8Y_oiPYC5hHi2A",
#          "alias": "frances-san-francisco",
#          "name": "Frances",
#          "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/mJRJodU9-9H4Hs_-p6qj8g/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/frances-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 1482,
#          "categories": [
#             {
#                "alias": "newamerican",
#                "title": "American (New)"
#             },
#             {
#                "alias": "desserts",
#                "title": "Desserts"
#             },
#             {
#                "alias": "wine_bars",
#                "title": "Wine Bars"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 37.7627220154927,
#             "longitude": -122.432276324008
#          },
#          "transactions": [],
#          "price": "$$$",
#          "location": {
#             "address1": "3870 17th St",
#             "address2": "",
#             "address3": "",
#             "city": "San Francisco",
#             "zip_code": "94114",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "3870 17th St",
#                "San Francisco, CA 94114"
#             ]
#          },
#          "phone": "+14156213870",
#          "display_phone": "(415) 621-3870",
#          "distance": 418.92755012100224
#       },
#       {
#          "id": "TRBP1G1l8vZkjgfqdx96Cw",
#          "alias": "pearls-deluxe-burgers-san-francisco-3",
#          "name": "Pearl's Deluxe Burgers",
#          "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/cy5OSNHa3_v0hblszvvNsg/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/pearls-deluxe-burgers-san-francisco-3?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 2114,
#          "categories": [
#             {
#                "alias": "burgers",
#                "title": "Burgers"
#             }
#          ],
#          "rating": 4.0,
#          "coordinates": {
#             "latitude": 37.787823,
#             "longitude": -122.413699
#          },
#          "transactions": [
#             "delivery",
#             "pickup"
#          ],
#          "price": "$$",
#          "location": {
#             "address1": "708 Post St",
#             "address2": null,
#             "address3": "",
#             "city": "San Francisco",
#             "zip_code": "94109",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "708 Post St",
#                "San Francisco, CA 94109"
#             ]
#          },
#          "phone": "+14154096120",
#          "display_phone": "(415) 409-6120",
#          "distance": 3600.016248589769
#       },
#       {
#          "id": "8oT00ympYI-mQ8KEetQ63g",
#          "alias": "zanzes-cheesecake-san-francisco",
#          "name": "Zanze's Cheesecake",
#          "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/jgXpu50kzaqMRX7kpijebg/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/zanzes-cheesecake-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 927,
#          "categories": [
#             {
#                "alias": "bakeries",
#                "title": "Bakeries"
#             },
#             {
#                "alias": "desserts",
#                "title": "Desserts"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 37.72994,
#             "longitude": -122.46984
#          },
#          "transactions": [],
#          "price": "$$",
#          "location": {
#             "address1": "2405 Ocean Ave",
#             "address2": "",
#             "address3": "",
#             "city": "San Francisco",
#             "zip_code": "94127",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "2405 Ocean Ave",
#                "San Francisco, CA 94127"
#             ]
#          },
#          "phone": "+14153342264",
#          "display_phone": "(415) 334-2264",
#          "distance": 4520.814797058772
#       },
#       {
#          "id": "b-ylC7pGKuh4yw6l1Q1k9g",
#          "alias": "golden-bear-trading-company-san-francisco-3",
#          "name": "Golden Bear Trading Company",
#          "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/VNlHGfsecS8-3XmUwC0yRw/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/golden-bear-trading-company-san-francisco-3?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 1095,
#          "categories": [
#             {
#                "alias": "grocery",
#                "title": "Grocery"
#             },
#             {
#                "alias": "coffee",
#                "title": "Coffee & Tea"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 37.7621609,
#             "longitude": -122.463128
#          },
#          "transactions": [],
#          "price": "$$",
#          "location": {
#             "address1": "1401 6th Ave",
#             "address2": "",
#             "address3": "",
#             "city": "San Francisco",
#             "zip_code": "94122",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "1401 6th Ave",
#                "San Francisco, CA 94122"
#             ]
#          },
#          "phone": "+14156645574",
#          "display_phone": "(415) 664-5574",
#          "distance": 2349.6619116858715
#       },
#       {
#          "id": "MKqtBlDciknkwW0q_Xa-Ow",
#          "alias": "crissy-field-san-francisco-4",
#          "name": "Crissy Field",
#          "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/B6BWyqQv2MTxEg9DWzwabw/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/crissy-field-san-francisco-4?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 761,
#          "categories": [
#             {
#                "alias": "parks",
#                "title": "Parks"
#             },
#             {
#                "alias": "beaches",
#                "title": "Beaches"
#             },
#             {
#                "alias": "hiking",
#                "title": "Hiking"
#             }
#          ],
#          "rating": 5.0,
#          "coordinates": {
#             "latitude": 37.8036602516771,
#             "longitude": -122.458308262209
#          },
#          "transactions": [],
#          "location": {
#             "address1": "603 Mason St",
#             "address2": "",
#             "address3": null,
#             "city": "San Francisco",
#             "zip_code": "94129",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "603 Mason St",
#                "San Francisco, CA 94129"
#             ]
#          },
#          "phone": "+14155614323",
#          "display_phone": "(415) 561-4323",
#          "distance": 5066.40314090049
#       },
#       {
#          "id": "g9LSMqUK5dkUcmpgTnU-dQ",
#          "alias": "rosamunde-sausage-grill-haight-st-san-francisco",
#          "name": "Rosamunde Sausage Grill - Haight St",
#          "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/8nYealEvJMPDkKfWfBfFrA/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/rosamunde-sausage-grill-haight-st-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 1597,
#          "categories": [
#             {
#                "alias": "hotdog",
#                "title": "Hot Dogs"
#             },
#             {
#                "alias": "german",
#                "title": "German"
#             },
#             {
#                "alias": "beerbar",
#                "title": "Beer Bar"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 37.77183,
#             "longitude": -122.43114
#          },
#          "transactions": [],
#          "price": "$",
#          "location": {
#             "address1": "545 Haight St",
#             "address2": "",
#             "address3": "",
#             "city": "San Francisco",
#             "zip_code": "94117",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "545 Haight St",
#                "San Francisco, CA 94117"
#             ]
#          },
#          "phone": "+14154376851",
#          "display_phone": "(415) 437-6851",
#          "distance": 1303.0856542519482
#       },
#       {
#          "id": "aud84H-NpMx3opWPtLX-vg",
#          "alias": "bourbon-and-branch-san-francisco",
#          "name": "Bourbon & Branch",
#          "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/8dFylWj1_w25JPR_MMxrQA/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/bourbon-and-branch-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 3012,
#          "categories": [
#             {
#                "alias": "cocktailbars",
#                "title": "Cocktail Bars"
#             },
#             {
#                "alias": "venues",
#                "title": "Venues & Event Spaces"
#             },
#             {
#                "alias": "speakeasies",
#                "title": "Speakeasies"
#             }
#          ],
#          "rating": 4.0,
#          "coordinates": {
#             "latitude": 37.78592,
#             "longitude": -122.41336
#          },
# ...
#          "review_count": 1884,
#          "categories": [
#             {
#                "alias": "thai",
#                "title": "Thai"
#             },
#             {
#                "alias": "comfortfood",
#                "title": "Comfort Food"
#             }
#          ],
#          "rating": 4.0,
#          "coordinates": {
#             "latitude": 37.7602179,
#             "longitude": -122.4110749
#          },
#          "transactions": [
#             "delivery",
#             "restaurant_reservation",
#             "pickup"
#          ],
#          "price": "$$",
#          "location": {
#             "address1": "710 Florida St",
#             "address2": "",
#             "address3": "",
#             "city": "San Francisco",
#             "zip_code": "94110",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "710 Florida St",
#                "San Francisco, CA 94110"
#             ]
#          },
#          "phone": "+14158142920",
#          "display_phone": "(415) 814-2920",
#          "distance": 2228.504131085978
#       },
#       {
#          "id": "2hGIxgprREdBieylltWaRQ",
#          "alias": "limoncello-san-francisco",
#          "name": "Limoncello",
#          "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/GNMz7gMIMgmBZr4WAYUQsw/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/limoncello-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 672,
#          "categories": [
#             {
#                "alias": "sandwiches",
#                "title": "Sandwiches"
#             },
#             {
#                "alias": "delis",
#                "title": "Delis"
#             },
#             {
#                "alias": "beer_and_wine",
#                "title": "Beer, Wine & Spirits"
#             }
#          ],
#          "rating": 5.0,
#          "coordinates": {
#             "latitude": 37.7873184067081,
#             "longitude": -122.423591369312
#          },
#          "transactions": [
#             "delivery",
#             "pickup"
#          ],
#          "price": "$$",
#          "location": {
#             "address1": "1400 Sutter St",
#             "address2": "",
#             "address3": null,
#             "city": "San Francisco",
#             "zip_code": "94109",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "1400 Sutter St",
#                "San Francisco, CA 94109"
#             ]
#          },
#          "phone": "+14156386361",
#          "display_phone": "(415) 638-6361",
#          "distance": 3147.4667741360263
#       },
#       {
#          "id": "bai6umLcCNy9cXql0Js2RQ",
#          "alias": "pizzeria-delfina-mission-san-francisco",
#          "name": "Pizzeria Delfina - Mission",
#          "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/mXfuUNiaoGaeg7ra4IgcJQ/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/pizzeria-delfina-mission-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 2259,
#          "categories": [
#             {
#                "alias": "pizza",
#                "title": "Pizza"
#             },
#             {
#                "alias": "italian",
#                "title": "Italian"
#             },
#             {
#                "alias": "bars",
#                "title": "Bars"
#             }
#          ],
#          "rating": 4.0,
#          "coordinates": {
#             "latitude": 37.7614143,
#             "longitude": -122.4242316
#          },
#          "transactions": [],
#          "price": "$$",
#          "location": {
#             "address1": "3611 18th St",
#             "address2": null,
#             "address3": "",
#             "city": "San Francisco",
#             "zip_code": "94110",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "3611 18th St",
#                "San Francisco, CA 94110"
#             ]
#          },
#          "phone": "+14154376800",
#          "display_phone": "(415) 437-6800",
#          "distance": 1075.3609253950508
#       },
#       {
#          "id": "mMiOVbGovegeBg-6YyqDxA",
#          "alias": "smitten-ice-cream-san-francisco-3",
#          "name": "Smitten Ice Cream",
#          "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/Neb7wO6LeYDGkL6mSr5IBw/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/smitten-ice-cream-san-francisco-3?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 2378,
#          "categories": [
#             {
#                "alias": "icecream",
#                "title": "Ice Cream & Frozen Yogurt"
#             }
#          ],
#          "rating": 4.0,
#          "coordinates": {
#             "latitude": 37.7763565191203,
#             "longitude": -122.424203597963
#          },
#          "transactions": [],
#          "price": "$",
#          "location": {
#             "address1": "432 Octavia St",
#             "address2": "Ste 1A",
#             "address3": "",
#             "city": "San Francisco",
#             "zip_code": "94102",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "432 Octavia St",
#                "Ste 1A",
#                "San Francisco, CA 94102"
#             ]
#          },
#          "phone": "+14158631518",
#          "display_phone": "(415) 863-1518",
#          "distance": 2027.878609897694
#       },
#       {
#          "id": "eSixRz7xcwtFdeh9hN5TyQ",
#          "alias": "la-folie-san-francisco",
#          "name": "La Folie",
#          "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/oTmg1Cj8pstDTFZQR1XUNA/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/la-folie-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 1430,
#          "categories": [
#             {
#                "alias": "french",
#                "title": "French"
#             },
#             {
#                "alias": "wine_bars",
#                "title": "Wine Bars"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 37.798136,
#             "longitude": -122.422036
#          },
#          "transactions": [],
#          "price": "$$$$",
#          "location": {
#             "address1": "2316 Polk St",
#             "address2": "",
#             "address3": "",
#             "city": "San Francisco",
#             "zip_code": "94109",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "2316 Polk St",
#                "San Francisco, CA 94109"
#             ]
#          },
#          "phone": "+14157765577",
#          "display_phone": "(415) 776-5577",
#          "distance": 4329.894303195132
#       },
#       {
#          "id": "0100LAmvjZPFjEPswwrDBQ",
#          "alias": "benkyodo-co-san-francisco",
#          "name": "Benkyodo Co",
#          "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/kwrgCQmDlR5HPOiyQXiGPw/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/benkyodo-co-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 943,
#          "categories": [
#             {
#                "alias": "bakeries",
#                "title": "Bakeries"
#             },
#             {
#                "alias": "candy",
#                "title": "Candy Stores"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 37.786366,
#             "longitude": -122.43011
#          },
#          "transactions": [],
#          "price": "$",
#          "location": {
#             "address1": "1747 Buchanan St",
#             "address2": "",
#             "address3": "",
#             "city": "San Francisco",
#             "zip_code": "94115",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "1747 Buchanan St",
#                "San Francisco, CA 94115"
#             ]
#          },
#          "phone": "+14159221244",
#          "display_phone": "(415) 922-1244",
#          "distance": 2886.0127525579087
#       },
#       {
#          "id": "zjlwTVZOyCU8OzzUPEavQQ",
#          "alias": "super-duper-burgers-san-francisco-3",
#          "name": "Super Duper Burgers",
#          "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/cIH_FO2pXX0fXir4LGebxQ/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/super-duper-burgers-san-francisco-3?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 2668,
#          "categories": [
#             {
#                "alias": "burgers",
#                "title": "Burgers"
#             },
#             {
#                "alias": "tradamerican",
#                "title": "American (Traditional)"
#             }
#          ],
#          "rating": 4.0,
#          "coordinates": {
#             "latitude": 37.7868540659939,
#             "longitude": -122.403968274593
#          },
#          "transactions": [],
#          "price": "$$",
#          "location": {
#             "address1": "721 Market St",
#             "address2": "",
#             "address3": "",
#             "city": "San Francisco",
#             "zip_code": "94103",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "721 Market St",
#                "San Francisco, CA 94103"
#             ]
#          },
#          "phone": "+14155383437",
#          "display_phone": "(415) 538-3437",
#          "distance": 4059.323199309667
#       },
#       {
#          "id": "Tttm1r5Dw1sRMCfc3EQWPw",
#          "alias": "boulevard-san-francisco",
#          "name": "Boulevard",
#          "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/PrNMuBxtmrwfksK_uFvsSg/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/boulevard-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 2609,
#          "categories": [
#             {
#                "alias": "newamerican",
#                "title": "American (New)"
#             }
#          ],
#          "rating": 4.0,
#          "coordinates": {
#             "latitude": 37.79337,
#             "longitude": -122.39274
#          },
#          "transactions": [],
#          "price": "$$$",
#          "location": {
#             "address1": "1 Mission St",
#             "address2": "",
#             "address3": "",
#             "city": "San Francisco",
#             "zip_code": "94105",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "1 Mission St",
#                "San Francisco, CA 94105"
#             ]
#          },
#          "phone": "+14155436084",
#          "display_phone": "(415) 543-6084",
#          "distance": 5266.6718544234
#       },
#       {
#          "id": "F6SOy6-3tP4i-ipACZUS0g",
#          "alias": "\u00e8-tutto-qua-san-francisco-2",
#          "name": "\u00c8 Tutto Qua",
#          "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/lzjPKe_-LOoLcPgN8lGZ2A/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/%C3%A8-tutto-qua-san-francisco-2?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 2083,
#          "categories": [
#             {
#                "alias": "italian",
#                "title": "Italian"
#             },
#             {
#                "alias": "seafood",
#                "title": "Seafood"
#             },
#             {
#                "alias": "pizza",
#                "title": "Pizza"
#             }
#          ],
#          "rating": 4.0,
#          "coordinates": {
#             "latitude": 37.7977599,
#             "longitude": -122.40625
#          },
#          "transactions": [],
#          "price": "$$",
#          "location": {
#             "address1": "270 Columbus Ave",
#             "address2": "",
#             "address3": "",
#             "city": "San Francisco",
#             "zip_code": "94133",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "270 Columbus Ave",
#                "San Francisco, CA 94133"
#             ]
#          },
#          "phone": "+14159891002",
#          "display_phone": "(415) 989-1002",
#          "distance": 4881.415079536526
#       },
#       {
#          "id": "Qbr2JG96K6d31NqqAUxf9g",
#          "alias": "la-mar-cebicher\u00eda-peruana-san-francisco-4",
#          "name": "La Mar Cebicher\u00eda Peruana",
#          "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/2gAijMp_chiTNQJaVc_1IQ/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/la-mar-cebicher%C3%ADa-peruana-san-francisco-4?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 3535,
#          "categories": [
#             {
#                "alias": "seafood",
#                "title": "Seafood"
#             },
#             {
#                "alias": "peruvian",
#                "title": "Peruvian"
#             }
#          ],
#          "rating": 4.0,
#          "coordinates": {
#             "latitude": 37.7974182368553,
#             "longitude": -122.395129846558
#          },
#          "transactions": [],
#          "price": "$$$",
#          "location": {
#             "address1": "Pier 1 1/2 The Embarcadero",
#             "address2": "",
#             "address3": "",
#             "city": "San Francisco",
#             "zip_code": "94111",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "Pier 1 1/2 The Embarcadero",
#                "San Francisco, CA 94111"
#             ]
#          },
#          "phone": "+14153978880",
#          "display_phone": "(415) 397-8880",
#          "distance": 5447.477112361181
#       },
#       {
#          "id": "kOYj2sGMZnyC1lU-_Uw5fA",
#          "alias": "cha-cha-cha-san-francisco-4",
#          "name": "Cha Cha Cha",
#          "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/PhQlJyK4_SCoRs4P7-6vzQ/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/cha-cha-cha-san-francisco-4?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg",
#          "review_count": 3159,
#          "categories": [
#             {
#                "alias": "caribbean",
#                "title": "Caribbean"
#             },
#             {
#                "alias": "cuban",
#                "title": "Cuban"
#             },
#             {
#                "alias": "tapas",
#                "title": "Tapas Bars"
#             }
#          ],
#          "rating": 4.0,
#          "coordinates": {
#             "latitude": 37.7691434,
#             "longitude": -122.4520399
#          },
#          "transactions": [
#             "delivery"
#          ],
#          "price": "$$",
#          "location": {
#             "address1": "1801 Haight St",
#             "address2": "",
#             "address3": "",
#             "city": "San Francisco",
#             "zip_code": "94117",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "1801 Haight St",
#                "San Francisco, CA 94117"
#             ]
#          },
#          "phone": "+14153867670",
#          "display_phone": "(415) 386-7670",
#          "distance": 1648.936701704209
#       }
#    ],
#    "total": 6700,
#    "region": {
#       "center": {
#          "longitude": -122.43644714355469,
#          "latitude": 37.76089938976322
#       }
#    }
# }

# %%
print(cannabis_data.keys())
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
len(cannabis_data['region'])
# Out:
# 1

# %%
cannabis_data['region']
# Out:
# {'center': {'longitude': -122.43644714355469, 'latitude': 37.76089938976322}}

# %%
cannabis_data['businesses']
# Out:
# [{'id': 'RrIduU6-SUNCanTEVF-hIQ',
#   'alias': 'marco-polo-italian-ice-cream-san-francisco',
#   'name': 'Marco Polo Italian Ice Cream',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qZMP6QSGXd9-Vyq_hix2Fg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/marco-polo-italian-ice-cream-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 1401,
#   'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'},
#    {'alias': 'gelato', 'title': 'Gelato'},
#    {'alias': 'desserts', 'title': 'Desserts'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.7426223, 'longitude': -122.481885},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '1447 Taraval St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94116',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1447 Taraval St', 'San Francisco, CA 94116']},
#   'phone': '+14157312833',
#   'display_phone': '(415) 731-2833',
#   'distance': 4480.698934510479},
#  {'id': '1U9_ZNruMLf4EL0pMoxb_w',
#   'alias': 'arsicault-bakery-san-francisco',
#   'name': 'Arsicault Bakery',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IPRgi4dgceBOgZWU28tPpA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/arsicault-bakery-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 998,
#   'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.783429, 'longitude': -122.459307},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '397 Arguello Blvd',
#    'address2': None,
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94118',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['397 Arguello Blvd', 'San Francisco, CA 94118']},
#   'phone': '+14157509460',
#   'display_phone': '(415) 750-9460',
#   'distance': 3211.384136637487},
#  {'id': 'UTVDbZv-qiHU06sDkoel3g',
#   'alias': 'chez-maman-east-san-francisco',
#   'name': 'Chez Maman East',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gccHe5ofFMpNyh8vmS0VSw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chez-maman-east-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 2011,
#   'categories': [{'alias': 'french', 'title': 'French'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'creperies', 'title': 'Creperies'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.7624388911845,
#    'longitude': -122.396692272318},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1401 18th St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94107',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1401 18th St', 'San Francisco, CA 94107']},
#   'phone': '+14156559542',
#   'display_phone': '(415) 655-9542',
#   'distance': 3498.909842201317},
#  {'id': 'A0AziPST4T6k-V3neWFRNA',
#   'alias': 'plow-san-francisco',
#   'name': 'Plow',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KE7h62IAS2rhoE0V6FMknA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/plow-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 2433,
#   'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.762537673684, 'longitude': -122.39535099572},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1299 18th St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94107',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1299 18th St', 'San Francisco, CA 94107']},
#   'phone': '+14158217569',
#   'display_phone': '(415) 821-7569',
#   'distance': 3617.214576272711},
#  {'id': '_2EHMIdoYeWgsuAiWydjYQ',
#   'alias': 'mission-beach-cafe-san-francisco-4',
#   'name': 'Mission Beach Cafe',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1KBDxxk4ubNk1t_1PlHJ8w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mission-beach-cafe-san-francisco-4?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 2681,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.768133, 'longitude': -122.424713},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '198 Guerrero St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94103',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['198 Guerrero St', 'San Francisco, CA 94103']},
#   'phone': '+14158610198',
#   'display_phone': '(415) 861-0198',
#   'distance': 1308.011230207369},
#  {'id': 'IJk76B-pTta_klpAZcpQdA',
#   'alias': 'lous-cafe-san-francisco',
#   'name': "Lou's Cafe",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UgwBr0vhX6fSNT_ILMeJvg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lous-cafe-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 1437,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'salad', 'title': 'Salad'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.78045, 'longitude': -122.473308},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '5017 Geary Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94118',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['5017 Geary Blvd', 'San Francisco, CA 94118']},
#   'phone': '+14153794429',
#   'display_phone': '(415) 379-4429',
#   'distance': 3901.6725691148918},
#  {'id': 'r7RwvYMwxDuK3u26fHbYDA',
#   'alias': 'limón-rotisserie-san-francisco-3',
#   'name': 'Limón Rotisserie',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wvbMWakjpf0c-0QeucFl9Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lim%C3%B3n-rotisserie-san-francisco-3?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 3078,
#   'categories': [{'alias': 'peruvian', 'title': 'Peruvian'},
#    {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.7570666079255,
#    'longitude': -122.416596234642},
#   'transactions': ['pickup'],
#   'price': '$$',
#   'location': {'address1': '1001 S Van Ness Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94110',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1001 S Van Ness Ave', 'San Francisco, CA 94110']},
#   'phone': '+14158212134',
#   'display_phone': '(415) 821-2134',
#   'distance': 1796.3791030607001},
#  {'id': 'EFefgQdk_19WxQXvVtwEog',
#   'alias': 'blue-bottle-coffee-san-francisco-8',
#   'name': 'Blue Bottle Coffee',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pJsxoTxQRX7Ec9fSfVBeMQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/blue-bottle-coffee-san-francisco-8?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 1663,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.77638, 'longitude': -122.423211},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '315 Linden St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94102',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['315 Linden St', 'San Francisco, CA 94102']},
#   'phone': '+15106533394',
#   'display_phone': '(510) 653-3394',
#   'distance': 2077.661076831945},
#  {'id': '_EncdQezAzcShATMFXL0dA',
#   'alias': 'tropisueno-san-francisco-8',
#   'name': 'Tropisueno',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hUZgDmue1VRfvIXai6I0wg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tropisueno-san-francisco-8?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 4162,
#   'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'tacos', 'title': 'Tacos'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.7853008468227,
#    'longitude': -122.403918653727},
#   'transactions': ['restaurant_reservation'],
#   'price': '$$',
#   'location': {'address1': '75 Yerba Buena Ln',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94103',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['75 Yerba Buena Ln', 'San Francisco, CA 94103']},
#   'phone': '+14152430299',
#   'display_phone': '(415) 243-0299',
#   'distance': 3941.5902762189608},
#  {'id': '353bun0151fMbR3ut2d-nw',
#   'alias': 'absinthe-brasserie-and-bar-san-francisco-2',
#   'name': 'Absinthe Brasserie & Bar',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AE80i8mNAmawM9R3SJcelg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/absinthe-brasserie-and-bar-san-francisco-2?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 3211,
#   'categories': [{'alias': 'french', 'title': 'French'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.77714, 'longitude': -122.42268},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '398 Hayes St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94102',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['398 Hayes St', 'San Francisco, CA 94102']},
#   'phone': '+14155511590',
#   'display_phone': '(415) 551-1590',
#   'distance': 2159.633139010338},
#  {'id': '-fqw8aDcx1Sgjs-4u__Aiw',
#   'alias': 'fort-funston-san-francisco-3',
#   'name': 'Fort Funston',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nLxaNAC0Wkg2ggn818ifwA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/fort-funston-san-francisco-3?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 948,
#   'categories': [{'alias': 'parks', 'title': 'Parks'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 37.714154842179, 'longitude': -122.500342737514},
#   'transactions': [],
#   'location': {'address1': 'Skyline Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94132',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['Skyline Blvd', 'San Francisco, CA 94132']},
#   'phone': '+14155614323',
#   'display_phone': '(415) 561-4323',
#   'distance': 7654.163307316438},
#  {'id': 'u39mZEYojBiNic3lqKhPNw',
#   'alias': 'tacorea-san-francisco',
#   'name': 'Tacorea',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xJUH-UAXBuIEub6HbxPKFQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tacorea-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 1448,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#    {'alias': 'korean', 'title': 'Korean'},
#    {'alias': 'latin', 'title': 'Latin American'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.7897794, 'longitude': -122.410717},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '809 Bush St',
#    'address2': '',
#    'address3': None,
#    'city': 'San Francisco',
#    'zip_code': '94108',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['809 Bush St', 'San Francisco, CA 94108']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 3930.8433222931662},
#  {'id': 'yniMfk_yS1sk9dxPLDVchg',
#   'alias': 'lands-end-trail-san-francisco',
#   'name': 'Lands End Trail',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/R-_wdo0Zj1TewBwNsrFlgw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lands-end-trail-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 802,
#   'categories': [{'alias': 'hiking', 'title': 'Hiking'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 37.780077, 'longitude': -122.510029},
#   'transactions': [],
#   'location': {'address1': '680 Point Lobos Ave',
#    'address2': '',
#    'address3': 'Golden Gate National Recreation Area',
#    'city': 'San Francisco',
#    'zip_code': '94121',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['680 Point Lobos Ave',
#     'Golden Gate National Recreation Area',
#     'San Francisco, CA 94121']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 6810.049102490965},
#  {'id': 'CYttYTEiQuhSfo3SEh79fA',
#   'alias': 'shizen-vegan-sushi-bar-and-izakaya-san-francisco',
#   'name': 'Shizen Vegan Sushi Bar & Izakaya',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ose-rlo_a7c6pybjIxjHbA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/shizen-vegan-sushi-bar-and-izakaya-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 1361,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'vegan', 'title': 'Vegan'},
#    {'alias': 'izakaya', 'title': 'Izakaya'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.768314, 'longitude': -122.421642},
#   'transactions': ['restaurant_reservation'],
#   'price': '$$',
#   'location': {'address1': '370 14th St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94103',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['370 14th St', 'San Francisco, CA 94103']},
#   'phone': '+14156785767',
#   'display_phone': '(415) 678-5767',
#   'distance': 1540.5965160298517},
#  {'id': 'vVN_oVe6jvr4PCmXg_m9CA',
#   'alias': 'hollywood-cafe-san-francisco',
#   'name': 'Hollywood Cafe',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/76uAEQSOn6nnSK0nPctmyA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hollywood-cafe-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 1982,
#   'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'cafes', 'title': 'Cafes'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.8065799, 'longitude': -122.41584},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '530 North Point St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94133',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['530 North Point St', 'San Francisco, CA 94133']},
#   'phone': '+14155633779',
#   'display_phone': '(415) 563-3779',
#   'distance': 5380.06766521831},
#  {'id': 'wEpiKz--Z2b1q_FSCCNiow',
#   'alias': 'lolinda-san-francisco',
#   'name': 'Lolinda',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/M8J3ehcOIRRI8ys1Q0hxtw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lolinda-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 1852,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#    {'alias': 'latin', 'title': 'Latin American'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.7566414790839, 'longitude': -122.41907298565},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '2518 Mission St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94110',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['2518 Mission St', 'San Francisco, CA 94110']},
#   'phone': '+14155506970',
#   'display_phone': '(415) 550-6970',
#   'distance': 1599.0638996264636},
#  {'id': 'ykvr3ib1gHQHI4tznSn8iA',
#   'alias': 'wayfare-tavern-san-francisco-2',
#   'name': 'Wayfare Tavern',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Dj4UcH5T821FI7n7VEL-vA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/wayfare-tavern-san-francisco-2?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 3759,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.7939484886016,
#    'longitude': -122.402307987213},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '558 Sacramento St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94111',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['558 Sacramento St', 'San Francisco, CA 94111']},
#   'phone': '+14157729060',
#   'display_phone': '(415) 772-9060',
#   'distance': 4744.189084845839},
#  {'id': '9yM20-7fj4LMrOO30nqkBw',
#   'alias': 'l-ardoise-bistro-san-francisco',
#   'name': 'L’Ardoise Bistro',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VJDYOLw03bUGeBLb14BRGA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/l-ardoise-bistro-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 1228,
#   'categories': [{'alias': 'french', 'title': 'French'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'},
#    {'alias': 'desserts', 'title': 'Desserts'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.7665241, 'longitude': -122.4331385},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '151 Noe St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94114',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['151 Noe St', 'San Francisco, CA 94114']},
#   'phone': '+14154372600',
#   'display_phone': '(415) 437-2600',
#   'distance': 700.3831983058177},
#  {'id': 'lNbKeOfCMTNkoihZHqrbrg',
#   'alias': 'blue-bottle-coffee-san-francisco-21',
#   'name': 'Blue Bottle Coffee',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mjMHObH17E2NykWJufuVSg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/blue-bottle-coffee-san-francisco-21?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 2186,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.7824664727379,
#    'longitude': -122.407753326389},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '66 Mint St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94103',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['66 Mint St', 'San Francisco, CA 94103']},
#   'phone': '+15106533394',
#   'display_phone': '(510) 653-3394',
#   'distance': 3480.1988579855497},
#  {'id': '1hMD7RQogPDWpE-p3LKjXA',
#   'alias': 'loló-san-francisco-4',
#   'name': 'Loló',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-_hqewRYasro3NpC-v4Fug/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lol%C3%B3-san-francisco-4?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 2025,
#   'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.7573462, 'longitude': -122.4214034},
#   'transactions': ['restaurant_reservation'],
#   'price': '$$',
#   'location': {'address1': '974 Valencia St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94110',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['974 Valencia St', 'San Francisco, CA 94110']},
#   'phone': '+14156435656',
#   'display_phone': '(415) 643-5656',
#   'distance': 1380.24804973913},
#  {'id': 'YzA3ocJ0XvsTuD18qr2ctg',
#   'alias': 'mr-and-mrs-miscellaneous-san-francisco',
#   'name': 'Mr. and Mrs. Miscellaneous',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/oVaADVRdwn8q21CaFWfFWA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mr-and-mrs-miscellaneous-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 1406,
#   'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.7578152, 'longitude': -122.3880343},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '699 22nd St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94107',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['699 22nd St', 'San Francisco, CA 94107']},
#   'phone': '+14159700750',
#   'display_phone': '(415) 970-0750',
#   'distance': 4261.606719975425},
#  {'id': '9lX1QuC6GBj7WyKImHkRRw',
#   'alias': 'mr-holmes-bakehouse-san-francisco',
#   'name': 'Mr Holmes Bakehouse',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/O6PqDV4OM4PJ1xr4-dK5bQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mr-holmes-bakehouse-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 2321,
#   'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.7875909362522,
#    'longitude': -122.418352626264},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1042 Larkin St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94109',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1042 Larkin St', 'San Francisco, CA 94109']},
#   'phone': '+14158297700',
#   'display_phone': '(415) 829-7700',
#   'distance': 3367.1999359858455},
#  {'id': 'jqEpBbf_qNfWuz_GBkwCjw',
#   'alias': 'scomas-restaurant-san-francisco-3',
#   'name': "Scoma's Restaurant",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/5ZqAdIz1IhUDlmK6qP3WvA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/scomas-restaurant-san-francisco-3?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 3477,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'lounges', 'title': 'Lounges'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.808944, 'longitude': -122.418462},
#   'transactions': ['restaurant_reservation'],
#   'price': '$$$',
#   'location': {'address1': '1965 Al Scoma Way',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94133',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1965 Al Scoma Way', 'San Francisco, CA 94133']},
#   'phone': '+14157714383',
#   'display_phone': '(415) 771-4383',
#   'distance': 5571.204721217614},
#  {'id': 'hWE2CDphzZ3nXlwv3Uk6Og',
#   'alias': 'philz-coffee-san-francisco-3',
#   'name': 'Philz Coffee',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/cK3WII_tsobxGzfYtOhzLw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/philz-coffee-san-francisco-3?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 1382,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.7756640166767, 'longitude': -122.39345180371},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '201 Berry St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94158',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['201 Berry St', 'San Francisco, CA 94158']},
#   'phone': '+14158759943',
#   'display_phone': '(415) 875-9943',
#   'distance': 4120.4371805947885},
#  {'id': '-sg6DqQNGyTMt0MHoY7diQ',
#   'alias': 'good-mong-kok-bakery-san-francisco',
#   'name': 'Good Mong Kok Bakery',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eYQS3PcMtY63dzHEnab76w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/good-mong-kok-bakery-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 2386,
#   'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#    {'alias': 'dimsum', 'title': 'Dim Sum'},
#    {'alias': 'cantonese', 'title': 'Cantonese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.7954584839809,
#    'longitude': -122.408358365012},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '1039 Stockton St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94108',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1039 Stockton St', 'San Francisco, CA 94108']},
#   'phone': '+14153972688',
#   'display_phone': '(415) 397-2688',
#   'distance': 4567.4100400050365},
#  {'id': 'u3mX2Hkc0XoCgPxG6xRFkg',
#   'alias': 'palace-of-fine-arts-san-francisco',
#   'name': 'Palace Of Fine Arts',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/947-VoWzgNCFq0GLN7t3JA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/palace-of-fine-arts-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 938,
#   'categories': [{'alias': 'landmarks',
#     'title': 'Landmarks & Historical Buildings'},
#    {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.8041385, 'longitude': -122.448286},
#   'transactions': [],
#   'location': {'address1': '3601 Lyon St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94123',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['3601 Lyon St', 'San Francisco, CA 94123']},
#   'phone': '+14158861929',
#   'display_phone': '(415) 886-1929',
#   'distance': 4903.449589709836},
#  {'id': 'dMlsQsPU8Y_oiPYC5hHi2A',
#   'alias': 'frances-san-francisco',
#   'name': 'Frances',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mJRJodU9-9H4Hs_-p6qj8g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/frances-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 1482,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'desserts', 'title': 'Desserts'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.7627220154927,
#    'longitude': -122.432276324008},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '3870 17th St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94114',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['3870 17th St', 'San Francisco, CA 94114']},
#   'phone': '+14156213870',
#   'display_phone': '(415) 621-3870',
#   'distance': 418.92755012100224},
#  {'id': 'TRBP1G1l8vZkjgfqdx96Cw',
#   'alias': 'pearls-deluxe-burgers-san-francisco-3',
#   'name': "Pearl's Deluxe Burgers",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cy5OSNHa3_v0hblszvvNsg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pearls-deluxe-burgers-san-francisco-3?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 2114,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.787823, 'longitude': -122.413699},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '708 Post St',
#    'address2': None,
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94109',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['708 Post St', 'San Francisco, CA 94109']},
#   'phone': '+14154096120',
#   'display_phone': '(415) 409-6120',
#   'distance': 3600.016248589769},
#  {'id': '8oT00ympYI-mQ8KEetQ63g',
#   'alias': 'zanzes-cheesecake-san-francisco',
#   'name': "Zanze's Cheesecake",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jgXpu50kzaqMRX7kpijebg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/zanzes-cheesecake-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 927,
#   'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#    {'alias': 'desserts', 'title': 'Desserts'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.72994, 'longitude': -122.46984},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '2405 Ocean Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94127',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['2405 Ocean Ave', 'San Francisco, CA 94127']},
#   'phone': '+14153342264',
#   'display_phone': '(415) 334-2264',
#   'distance': 4520.814797058772},
#  {'id': 'b-ylC7pGKuh4yw6l1Q1k9g',
#   'alias': 'golden-bear-trading-company-san-francisco-3',
#   'name': 'Golden Bear Trading Company',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VNlHGfsecS8-3XmUwC0yRw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/golden-bear-trading-company-san-francisco-3?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 1095,
#   'categories': [{'alias': 'grocery', 'title': 'Grocery'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.7621609, 'longitude': -122.463128},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1401 6th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94122',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1401 6th Ave', 'San Francisco, CA 94122']},
#   'phone': '+14156645574',
#   'display_phone': '(415) 664-5574',
#   'distance': 2349.6619116858715},
#  {'id': 'MKqtBlDciknkwW0q_Xa-Ow',
#   'alias': 'crissy-field-san-francisco-4',
#   'name': 'Crissy Field',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/B6BWyqQv2MTxEg9DWzwabw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/crissy-field-san-francisco-4?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 761,
#   'categories': [{'alias': 'parks', 'title': 'Parks'},
#    {'alias': 'beaches', 'title': 'Beaches'},
#    {'alias': 'hiking', 'title': 'Hiking'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 37.8036602516771,
#    'longitude': -122.458308262209},
#   'transactions': [],
#   'location': {'address1': '603 Mason St',
#    'address2': '',
#    'address3': None,
#    'city': 'San Francisco',
#    'zip_code': '94129',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['603 Mason St', 'San Francisco, CA 94129']},
#   'phone': '+14155614323',
#   'display_phone': '(415) 561-4323',
#   'distance': 5066.40314090049},
#  {'id': 'g9LSMqUK5dkUcmpgTnU-dQ',
#   'alias': 'rosamunde-sausage-grill-haight-st-san-francisco',
#   'name': 'Rosamunde Sausage Grill - Haight St',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8nYealEvJMPDkKfWfBfFrA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rosamunde-sausage-grill-haight-st-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 1597,
#   'categories': [{'alias': 'hotdog', 'title': 'Hot Dogs'},
#    {'alias': 'german', 'title': 'German'},
#    {'alias': 'beerbar', 'title': 'Beer Bar'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.77183, 'longitude': -122.43114},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '545 Haight St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94117',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['545 Haight St', 'San Francisco, CA 94117']},
#   'phone': '+14154376851',
#   'display_phone': '(415) 437-6851',
#   'distance': 1303.0856542519482},
#  {'id': 'aud84H-NpMx3opWPtLX-vg',
#   'alias': 'bourbon-and-branch-san-francisco',
#   'name': 'Bourbon & Branch',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8dFylWj1_w25JPR_MMxrQA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bourbon-and-branch-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 3012,
#   'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#    {'alias': 'speakeasies', 'title': 'Speakeasies'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.78592, 'longitude': -122.41336},
#   'transactions': ['restaurant_reservation'],
#   'price': '$$$',
#   'location': {'address1': '501 Jones St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94102',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['501 Jones St', 'San Francisco, CA 94102']},
#   'phone': '+14153461735',
#   'display_phone': '(415) 346-1735',
#   'distance': 3453.0238262024345},
#  {'id': '83dXgt2nG98JJG2F7ai8AQ',
#   'alias': 'genki-crepes-and-mini-mart-san-francisco',
#   'name': 'Genki Crepes & Mini-Mart',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/khuio_qluLLXfrzWGVaMrg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/genki-crepes-and-mini-mart-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 2173,
#   'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#    {'alias': 'creperies', 'title': 'Creperies'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.78326, 'longitude': -122.46283},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '330 Clement St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94118',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['330 Clement St', 'San Francisco, CA 94118']},
#   'phone': '+14153796414',
#   'display_phone': '(415) 379-6414',
#   'distance': 3399.476139422393},
#  {'id': 'c0WpyZFR3EoEBKcoY2LZ3Q',
#   'alias': 'marlowe-san-francisco-2',
#   'name': 'Marlowe',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wcnVYOjwK254JZod_2pXgQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/marlowe-san-francisco-2?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 2633,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'brasseries', 'title': 'Brasseries'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.7783200510611,
#    'longitude': -122.396771288052},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '500 Brannan St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94107',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['500 Brannan St', 'San Francisco, CA 94107']},
#   'phone': '+14157771413',
#   'display_phone': '(415) 777-1413',
#   'distance': 3989.2680242711845},
#  {'id': 'OvBC83vOK6vRw175vHiArg',
#   'alias': 'garden-creamery-san-francisco-3',
#   'name': 'Garden Creamery',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rYA9n55z3cNEvKD8yJ0JjQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/garden-creamery-san-francisco-3?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 702,
#   'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.7587301270631,
#    'longitude': -122.420380041003},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '3566 20th St',
#    'address2': '',
#    'address3': None,
#    'city': 'San Francisco',
#    'zip_code': '94110',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['3566 20th St', 'San Francisco, CA 94110']},
#   'phone': '+18082246626',
#   'display_phone': '(808) 224-6626',
#   'distance': 1432.8899065178587},
#  {'id': '8skVQNkVBv90iiPtFeSpzw',
#   'alias': 'zero-zero-san-francisco',
#   'name': 'Zero Zero',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JB5XNOgdQHocE4nI9DHWkA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/zero-zero-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 3187,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.78163, 'longitude': -122.40204},
#   'transactions': ['restaurant_reservation', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '826 Folsom St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94107',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['826 Folsom St', 'San Francisco, CA 94107']},
#   'phone': '+14153488800',
#   'display_phone': '(415) 348-8800',
#   'distance': 3800.206476277323},
#  {'id': 'CTE5lnXUYp4xidmh35knNg',
#   'alias': 'bar-crudo-san-francisco',
#   'name': 'Bar Crudo',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pOj4e4ep3v3oz5vPrz3cOA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bar-crudo-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 1809,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'raw_food', 'title': 'Live/Raw Food'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.7756673618778,
#    'longitude': -122.438271045685},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '655 Divisadero St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94117',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['655 Divisadero St', 'San Francisco, CA 94117']},
#   'phone': '+14154090679',
#   'display_phone': '(415) 409-0679',
#   'distance': 1649.9290902692737},
#  {'id': '6PzyzeiWjJ0fPpuKZffn9g',
#   'alias': 'california-academy-of-sciences-san-francisco',
#   'name': 'California Academy of Sciences',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/blwcttV-1kjBw0xfwKtgfA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/california-academy-of-sciences-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 3026,
#   'categories': [{'alias': 'museums', 'title': 'Museums'},
#    {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#    {'alias': 'aquariums', 'title': 'Aquariums'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.769816, 'longitude': -122.466041},
#   'transactions': [],
#   'location': {'address1': '55 Music Concourse Dr',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94118',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['55 Music Concourse Dr', 'San Francisco, CA 94118']},
#   'phone': '+14153798000',
#   'display_phone': '(415) 379-8000',
#   'distance': 2783.9096499193447},
#  {'id': '8kck3-K4zYKTJbJko0JlXQ',
#   'alias': 'farmhouse-kitchen-thai-cuisine-san-francisco',
#   'name': 'Farmhouse Kitchen Thai Cuisine',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AC0JE-nnMd-Ai3SlA7IPfg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/farmhouse-kitchen-thai-cuisine-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 1884,
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.7602179, 'longitude': -122.4110749},
#   'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '710 Florida St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94110',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['710 Florida St', 'San Francisco, CA 94110']},
#   'phone': '+14158142920',
#   'display_phone': '(415) 814-2920',
#   'distance': 2228.504131085978},
#  {'id': '2hGIxgprREdBieylltWaRQ',
#   'alias': 'limoncello-san-francisco',
#   'name': 'Limoncello',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GNMz7gMIMgmBZr4WAYUQsw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/limoncello-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 672,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'delis', 'title': 'Delis'},
#    {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 37.7873184067081,
#    'longitude': -122.423591369312},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1400 Sutter St',
#    'address2': '',
#    'address3': None,
#    'city': 'San Francisco',
#    'zip_code': '94109',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1400 Sutter St', 'San Francisco, CA 94109']},
#   'phone': '+14156386361',
#   'display_phone': '(415) 638-6361',
#   'distance': 3147.4667741360263},
#  {'id': 'bai6umLcCNy9cXql0Js2RQ',
#   'alias': 'pizzeria-delfina-mission-san-francisco',
#   'name': 'Pizzeria Delfina - Mission',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mXfuUNiaoGaeg7ra4IgcJQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pizzeria-delfina-mission-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 2259,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.7614143, 'longitude': -122.4242316},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '3611 18th St',
#    'address2': None,
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94110',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['3611 18th St', 'San Francisco, CA 94110']},
#   'phone': '+14154376800',
#   'display_phone': '(415) 437-6800',
#   'distance': 1075.3609253950508},
#  {'id': 'mMiOVbGovegeBg-6YyqDxA',
#   'alias': 'smitten-ice-cream-san-francisco-3',
#   'name': 'Smitten Ice Cream',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Neb7wO6LeYDGkL6mSr5IBw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/smitten-ice-cream-san-francisco-3?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 2378,
#   'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.7763565191203,
#    'longitude': -122.424203597963},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '432 Octavia St',
#    'address2': 'Ste 1A',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94102',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['432 Octavia St', 'Ste 1A', 'San Francisco, CA 94102']},
#   'phone': '+14158631518',
#   'display_phone': '(415) 863-1518',
#   'distance': 2027.878609897694},
#  {'id': 'eSixRz7xcwtFdeh9hN5TyQ',
#   'alias': 'la-folie-san-francisco',
#   'name': 'La Folie',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/oTmg1Cj8pstDTFZQR1XUNA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/la-folie-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 1430,
#   'categories': [{'alias': 'french', 'title': 'French'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.798136, 'longitude': -122.422036},
#   'transactions': [],
#   'price': '$$$$',
#   'location': {'address1': '2316 Polk St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94109',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['2316 Polk St', 'San Francisco, CA 94109']},
#   'phone': '+14157765577',
#   'display_phone': '(415) 776-5577',
#   'distance': 4329.894303195132},
#  {'id': '0100LAmvjZPFjEPswwrDBQ',
#   'alias': 'benkyodo-co-san-francisco',
#   'name': 'Benkyodo Co',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kwrgCQmDlR5HPOiyQXiGPw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/benkyodo-co-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 943,
#   'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#    {'alias': 'candy', 'title': 'Candy Stores'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.786366, 'longitude': -122.43011},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '1747 Buchanan St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94115',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1747 Buchanan St', 'San Francisco, CA 94115']},
#   'phone': '+14159221244',
#   'display_phone': '(415) 922-1244',
#   'distance': 2886.0127525579087},
#  {'id': 'zjlwTVZOyCU8OzzUPEavQQ',
#   'alias': 'super-duper-burgers-san-francisco-3',
#   'name': 'Super Duper Burgers',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cIH_FO2pXX0fXir4LGebxQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/super-duper-burgers-san-francisco-3?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 2668,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.7868540659939,
#    'longitude': -122.403968274593},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '721 Market St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94103',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['721 Market St', 'San Francisco, CA 94103']},
#   'phone': '+14155383437',
#   'display_phone': '(415) 538-3437',
#   'distance': 4059.323199309667},
#  {'id': 'Tttm1r5Dw1sRMCfc3EQWPw',
#   'alias': 'boulevard-san-francisco',
#   'name': 'Boulevard',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/PrNMuBxtmrwfksK_uFvsSg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/boulevard-san-francisco?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 2609,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.79337, 'longitude': -122.39274},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '1 Mission St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94105',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1 Mission St', 'San Francisco, CA 94105']},
#   'phone': '+14155436084',
#   'display_phone': '(415) 543-6084',
#   'distance': 5266.6718544234},
#  {'id': 'F6SOy6-3tP4i-ipACZUS0g',
#   'alias': 'è-tutto-qua-san-francisco-2',
#   'name': 'È Tutto Qua',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lzjPKe_-LOoLcPgN8lGZ2A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/%C3%A8-tutto-qua-san-francisco-2?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 2083,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.7977599, 'longitude': -122.40625},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '270 Columbus Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94133',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['270 Columbus Ave', 'San Francisco, CA 94133']},
#   'phone': '+14159891002',
#   'display_phone': '(415) 989-1002',
#   'distance': 4881.415079536526},
#  {'id': 'Qbr2JG96K6d31NqqAUxf9g',
#   'alias': 'la-mar-cebichería-peruana-san-francisco-4',
#   'name': 'La Mar Cebichería Peruana',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2gAijMp_chiTNQJaVc_1IQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/la-mar-cebicher%C3%ADa-peruana-san-francisco-4?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 3535,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'peruvian', 'title': 'Peruvian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.7974182368553,
#    'longitude': -122.395129846558},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': 'Pier 1 1/2 The Embarcadero',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94111',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['Pier 1 1/2 The Embarcadero',
#     'San Francisco, CA 94111']},
#   'phone': '+14153978880',
#   'display_phone': '(415) 397-8880',
#   'distance': 5447.477112361181},
#  {'id': 'kOYj2sGMZnyC1lU-_Uw5fA',
#   'alias': 'cha-cha-cha-san-francisco-4',
#   'name': 'Cha Cha Cha',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PhQlJyK4_SCoRs4P7-6vzQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/cha-cha-cha-san-francisco-4?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#   'review_count': 3159,
#   'categories': [{'alias': 'caribbean', 'title': 'Caribbean'},
#    {'alias': 'cuban', 'title': 'Cuban'},
#    {'alias': 'tapas', 'title': 'Tapas Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.7691434, 'longitude': -122.4520399},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1801 Haight St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94117',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1801 Haight St', 'San Francisco, CA 94117']},
#   'phone': '+14153867670',
#   'display_phone': '(415) 386-7670',
#   'distance': 1648.936701704209}]

# %%
len(cannabis_data['businesses'])
# Out:
# 50
