# %% [markdown]
# # YELP API Data on businesses: City of Los Angeles CA
# --------------------------------------------

# %% [markdown]
# ## ETL PROCES REPORT
# --------------------------------------------
# ### E: PULLING DATA FROM YELP'S API:
#
# * Step 1: Get an API KEY  from yelp
# * Investigate what kind of data to retrieve. In our case: General business profiles in the City of LA California
# * The API returns only 50 results max per call
# * Perform a test pull to look at the result and it's json structure to design the data frame
#
# ### T: PREPROCESSING THE JSON RESPONSE FROM THE API:
# --------------------------------------------
#
# * Declare/Initialize the variables/columns that will hold the downloaded data
# * We build a dataset of 1000 resutls by making multiple calls dynamically and saving data into a dataframe on the fly
# * Data processing consisted in extracting data from the json response and formatting it to create tabular data for the df
# * The Transforming process included string manipulation regex and python scripting.
#
# ### L: LOADING TO SQL AND MONGODB:
# --------------------------------------------
# * This was the most straightforward step accomplished with no issues
# * We simplify this proces by using sqlite instead of mysql or postgress
# * We also saved csv files of the data before we loaded it into the database systems.

# %%
import requests
import json
import pandas as pd
from credentials import APIKey
import time

# %%
MY_API_KEY = APIKey
HEADERS = {'Authorization': 'bearer %s' % MY_API_KEY}

# %%
base_url = "https://api.yelp.com/v3/businesses/search"

# %%
search_location = 'los angeles ca united states'

# %%
PARAMETERS = {'location': search_location,
                  'limit': 50,
                  'radius': 40000,
                 }

# %%
response = requests.get(url = base_url,
                        params = PARAMETERS,
                        headers = HEADERS)

# %%
responseDict = {}

# %%
response_url = response.url
print(f"{response_url}")
print(f"type(response_url): {type(response_url)}")
# Out:
# https://api.yelp.com/v3/businesses/search?location=los+angeles+ca+united+states&limit=50&radius=40000
# type(response_url): <class 'str'>

# %%
json_response = response.json()

# %%
response.text
# Out:
# '{"businesses": [{"id": "TkFEKhsCixPWlShULKvMdQ", "alias": "bottega-louie-los-angeles", "name": "Bottega Louie", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/rAImnKvUNcNY8i6qEDWrZA/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/bottega-louie-los-angeles?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg", "review_count": 16243, "categories": [{"alias": "italian", "title": "Italian"}, {"alias": "bakeries", "title": "Bakeries"}, {"alias": "breakfast_brunch", "title": "Breakfast & Brunch"}], "rating": 4.0, "coordinates": {"latitude": 34.0469300995766, "longitude": -118.256601457672}, "transactions": [], "price": "$$", "location": {"address1": "700 S Grand Ave", "address2": null, "address3": "", "city": "Los Angeles", "zip_code": "90017", "country": "US", "state": "CA", "display_address": ["700 S Grand Ave", "Los Angeles, CA 90017"]}, "phone": "+12138021470", "display_phone": "(213) 802-1470", "distance": 6186.4405384986385}, {"id": "7O1ORGY36A-2aIENyaJWPg", "alias": "howlin-rays-los-angeles-3", "name": "Howlin\' Ray\'s", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/rNGExwKSIv4sth2Uqe25HA/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/howlin-rays-los-angeles-3?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg", "review_count": 5037, "categories": [{"alias": "southern", "title": "Southern"}, {"alias": "chickenshop", "title": "Chicken Shop"}, {"alias": "tradamerican", "title": "American (Traditional)"}], "rating": 4.5, "coordinates": {"latitude": 34.0614861063899, "longitude": -118.239554800093}, "transactions": [], "price": "$$", "location": {"address1": "727 N Broadway", "address2": "Ste 128", "address3": "", "city": "Los Angeles", "zip_code": "90012", "country": "US", "state": "CA", "display_address": ["727 N Broadway", "Ste 128", "Los Angeles, CA 90012"]}, "phone": "+12139358399", "display_phone": "(213) 935-8399", "distance": 7537.625406583131}, {"id": "KQBGm5G8IDkE8LeNY45mbA", "alias": "wurstk\\u00fcche-los-angeles-2", "name": "Wurstk\\u00fcche", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/gWIbvLDR1Y6yfTGTzXp_lw/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/wurstk%C3%BCche-los-angeles-2?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg", "review_count": 8058, "categories": [{"alias": "hotdog", "title": "Hot Dogs"}, {"alias": "german", "title": "German"}, {"alias": "gastropubs", "title": "Gastropubs"}], "rating": 4.0, "coordinates": {"latitude": 34.0456047058105, "longitude": -118.236061096191}, "transactions": ["pickup", "delivery"], "price": "$$", "location": {"address1": "800 E 3rd St", "address2": "", "address3": "", "city": "Los Angeles", "zip_code": "90013", "country": "US", "state": "CA", "display_address": ["800 E 3rd St", "Los Angeles, CA 90013"]}, "phone": "+12136874444", "display_phone": "(213) 687-4444", "distance": 8058.966046339442}, {"id": "iSZpZgVnASwEmlq0DORY2A", "alias": "daikokuya-little-tokyo-los-angeles", "name": "Daikokuya Little Tokyo", "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/GG71SxFbzBd9-SRMRtB1EQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/daikokuya-little-tokyo-los-angeles?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg", "review_count": 8122, "categories": [{"alias": "ramen", "title": "Ramen"}, {"alias": "noodles", "title": "Noodles"}], "rating": 4.0, "coordinates": {"latitude": 34.05008090944, "longitude": -118.2401804513}, "transactions": [], "price": "$$", "location": {"address1": "327 E 1st St", "address2": "", "address3": "", "city": "Los Angeles", "zip_code": "90012", "country": "US", "state": "CA", "display_address": ["327 E 1st St", "Los Angeles, CA 90012"]}, "phone": "+ ...

# %%
type(response.text)

# %%
json_response.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
responseDict[response_url] = response.text

# %%
# responseDict

# %%
print(type(json_response['total']))
print(len(json_response['businesses']))
print(f"atl_json_response.keys(): {json_response.keys()}")
print(f"atl_response['total']: {json_response['total']}")
# Out:
# <class 'int'>
# 50
# atl_json_response.keys(): dict_keys(['businesses', 'total', 'region'])
# atl_response['total']: 11000

# %%
biz_count = json_response['total']
biz_count
# Out:
# 11000

# %%
# [val['title'] for val in   atl_json_response['businesses'][0]['categories']]
', '.join([val['title'] for val in json_response['businesses'][0]['categories']])
# Out:
# 'Italian, Bakeries, Breakfast & Brunch'

# %%
if biz_count > 1000:
    biz_count = 1000

# %%
biz_count
# Out:
# 1000

# %%
print(biz_count)
bins = []
temp_urls = []
response_url
# Out:
# 1000
# 'https://api.yelp.com/v3/businesses/search?location=los+angeles+ca+united+states&limit=50&radius=40000'

# %%
for i in range(50, biz_count, 50):
    bins.append(i)
    
print(bins)
# Out:
# [50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700, 750, 800, 850, 900, 950]

# %%
for i in range(len(bins)):
    temp_urls.append(response_url + "&offset=" + f"{str(bins[i])}")

# %%
print(temp_urls[0],'\n', temp_urls[-1])
# Out:
# https://api.yelp.com/v3/businesses/search?location=los+angeles+ca+united+states&limit=50&radius=40000&offset=50
#  https://api.yelp.com/v3/businesses/search?location=los+angeles+ca+united+states&limit=50&radius=40000&offset=950

# %%
biz_df = pd.DataFrame()

# %%
biz_df['id'] = ''
biz_df['alias'] = ''
biz_df['name'] = ''
biz_df['categories'] = ''
biz_df['review_count'] = ''
biz_df['rating'] = ''
biz_df['lat'] = ''
biz_df['long'] = ''
# biz_df['transactions'] = ''
biz_df['address'] = ''
biz_df['city'] = ''
biz_df['zip_code'] = ''
biz_df['country'] = ''
biz_df['state'] = ''
biz_df['phone'] = ''

# %%
json_response['businesses'][-1]
# Out:
# {'id': 'sYn3SNQP-j2t2XSwjlCbRg',
#  'alias': 'montys-good-burger-los-angeles',
#  'name': "Monty's Good Burger",
#  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qoVy9kU9SLr8dsJNuIweWA/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/montys-good-burger-los-angeles?adjust_creative=rCpoZ5I2XhS-AiKMOroCkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rCpoZ5I2XhS-AiKMOroCkg',
#  'review_count': 1193,
#  'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#   {'alias': 'vegan', 'title': 'Vegan'}],
#  'rating': 4.5,
#  'coordinates': {'latitude': 34.06469, 'longitude': -118.30876},
#  'transactions': ['pickup', 'delivery'],
#  'price': '$$',
#  'location': {'address1': '516 S Western Ave',
#   'address2': '',
#   'address3': None,
#   'city': 'Los Angeles',
#   'zip_code': '90020',
#   'country': 'US',
#   'state': 'CA',
#   'display_address': ['516 S Western Ave', 'Los Angeles, CA 90020']},
#  'phone': '+12139150257',
#  'display_phone': '(213) 915-0257',
#  'distance': 1206.4348071176648}

# %%
# testing joining all the categories into one string
', '.join([val['title'] for val in json_response['businesses'][0]['categories']])
# Out:
# 'Italian, Bakeries, Breakfast & Brunch'

# %%
# index_ = 0
for i in range(len(temp_urls)):
    print(temp_urls[i])
# Out:
# https://api.yelp.com/v3/businesses/search?location=los+angeles+ca+united+states&limit=50&radius=40000&offset=50
# https://api.yelp.com/v3/businesses/search?location=los+angeles+ca+united+states&limit=50&radius=40000&offset=100
# https://api.yelp.com/v3/businesses/search?location=los+angeles+ca+united+states&limit=50&radius=40000&offset=150
# https://api.yelp.com/v3/businesses/search?location=los+angeles+ca+united+states&limit=50&radius=40000&offset=200
# https://api.yelp.com/v3/businesses/search?location=los+angeles+ca+united+states&limit=50&radius=40000&offset=250
# https://api.yelp.com/v3/businesses/search?location=los+angeles+ca+united+states&limit=50&radius=40000&offset=300
# https://api.yelp.com/v3/businesses/search?location=los+angeles+ca+united+states&limit=50&radius=40000&offset=350
# https://api.yelp.com/v3/businesses/search?location=los+angeles+ca+united+states&limit=50&radius=40000&offset=400
# https://api.yelp.com/v3/businesses/search?location=los+angeles+ca+united+states&limit=50&radius=40000&offset=450
# https://api.yelp.com/v3/businesses/search?location=los+angeles+ca+united+states&limit=50&radius=40000&offset=500
# https://api.yelp.com/v3/businesses/search?location=los+angeles+ca+united+states&limit=50&radius=40000&offset=550
# https://api.yelp.com/v3/businesses/search?location=los+angeles+ca+united+states&limit=50&radius=40000&offset=600
# https://api.yelp.com/v3/businesses/search?location=los+angeles+ca+united+states&limit=50&radius=40000&offset=650
# https://api.yelp.com/v3/businesses/search?location=los+angeles+ca+united+states&limit=50&radius=40000&offset=700
# https://api.yelp.com/v3/businesses/search?location=los+angeles+ca+united+states&limit=50&radius=40000&offset=750
# https://api.yelp.com/v3/businesses/search?location=los+angeles+ca+united+states&limit=50&radius=40000&offset=800
# https://api.yelp.com/v3/businesses/search?location=los+angeles+ca+united+states&limit=50&radius=40000&offset=850
# https://api.yelp.com/v3/businesses/search?location=los+angeles+ca+united+states&limit=50&radius=40000&offset=900
# https://api.yelp.com/v3/businesses/search?location=los+angeles+ca+united+states&limit=50&radius=40000&offset=950

# %%
index_ = 0

# %%
# responseDict[response_url] = response.text

try:
    for j in range(len(json_response['businesses'])):
        print("=======================================================")
        print(f"Injecting DataFrame with first set of 50 results")
        print(f"biz index: {index_}: {json_response['businesses'][j]['name']}")
        print("=======================================================")
        
#         detail = temp_response_json['businesses'][j]
        
        biz_df.set_value(index_, "id", json_response['businesses'][j]['id'])
        biz_df.set_value(index_, "alias", json_response['businesses'][j]['alias'])

        biz_df.set_value(index_, "name", json_response['businesses'][j]['name'])
        biz_df.set_value(index_, "categories", ', '.join([val['title'] for val in json_response['businesses'][j]['categories']]) )        

        biz_df.set_value(index_, "review_count", json_response['businesses'][j]['review_count'])
        biz_df.set_value(index_, "rating", json_response['businesses'][j]['rating'])

        biz_df.set_value(index_, "lat", json_response['businesses'][j]['coordinates']['latitude'])
        biz_df.set_value(index_, "long", json_response['businesses'][j]['coordinates']['longitude'])

        biz_df.set_value(index_, "address", ' '.join(json_response['businesses'][j]['location']['display_address']))
        biz_df.set_value(index_, "city", json_response['businesses'][j]['location']['city'])

        biz_df.set_value(index_, "zip_code", json_response['businesses'][j]['location']['zip_code'])
        biz_df.set_value(index_, "country", json_response['businesses'][j]['location']['country'])

        biz_df.set_value(index_, "state", json_response['businesses'][j]['location']['state'])
        biz_df.set_value(index_, "phone", json_response['businesses'][j]['phone'])

        index_ += 1
except:
    print("Something went WRONG 😫😓")
# Out:
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 0: Bottega Louie
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 1: Howlin' Ray's
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 2: Wurstküche
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 3: Daikokuya Little Tokyo
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 4: The Morrison
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 5: Bestia
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 6: Kang Ho-dong Baekjeong
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 7: République
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 8: Langer's
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 9: Blu Jam Café
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 10: Slurpin' Ramen Bar
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 11: Providence
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 12: Marugame Monzo
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 13: Genwa Korean BBQ
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 14: Hae Jang Chon Korean BBQ Restaurant
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 15: Salt & Straw
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 16: Perch
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 17: Milk
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 18: Masa of Echo Park
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 19: Eggslut
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 20: Sushi Gen
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 21: Yup Dduk La
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 22: SK Donuts & Croissant
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 23: Scoops
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 24: KazuNori  | The Original Hand Roll Bar
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 25: EMC Seafood & Raw Bar
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 26: Philippe the Original
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 27: Urth Caffé- Downtown LA
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 28: Magal BBQ
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 29: BCD Tofu House
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 30: Silverlake Ramen
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 31: Animal
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 32: Han Bat Sul Lung Tang
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 33: Tea Master Matcha Cafe & Green Tea Shop
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 34: Pizzeria Mozza
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 35: Soowon Galbi KBBQ Restaurant
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 36: Joe's Falafel
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 37: Maccheroni Republic
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 38: Quarters Korean BBQ
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 39: Guisados
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 40: Alcove Café & Bakery
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 41: Dave's Hot Chicken
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 42: Sushi by H
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 43: Guisados
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 44: Dirt Dog
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 45: Pine & Crane
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 46: Papa Cristo's
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 47: Los Angeles County Museum of Art
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 48: Milk Jar Cookies
# =======================================================
# =======================================================
# Injecting DataFrame with first set of 50 results
# biz index: 49: Monty's Good Burger
# =======================================================
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if sys.path[0] == '':
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   from ipykernel import kernelapp as app
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   app.launch_new_instance()
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:19: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:21: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:22: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:25: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:28: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
biz_df.head()
# Out:
#                        id                               alias  \
# 0  TkFEKhsCixPWlShULKvMdQ           bottega-louie-los-angeles
# 1  7O1ORGY36A-2aIENyaJWPg           howlin-rays-los-angeles-3
# 2  KQBGm5G8IDkE8LeNY45mbA            wurstküche-los-angeles-2
# 3  iSZpZgVnASwEmlq0DORY2A  daikokuya-little-tokyo-los-angeles
# 4  DJek3FUewBzMc0gS-Gms9w            the-morrison-los-angeles
#
#                      name                                      categories  \
# 0           Bottega Louie           Italian, Bakeries, Breakfast & Brunch
# 1           Howlin' Ray's  Southern, Chicken Shop, American (Traditional)
# 2              Wurstküche                    Hot Dogs, German, Gastropubs
# 3  Daikokuya Little Tokyo                                  Ramen, Noodles
# 4            The Morrison                       Gastropubs, Burgers, Bars
#
#   review_count rating      lat     long  \
# 0        16243      4  34.0469 -118.257
# 1         5037    4.5  34.0615  -118.24
# 2         8058      4  34.0456 -118.236
# 3         8122      4  34.0501  -118.24
# 4         4072    4.5  34.1238 -118.269
#
#                                         address         city zip_code country  \
# 0         700 S Grand Ave Los Angeles, CA 90017  Los Angeles    90017      US
# 1  727 N Broadway Ste 128 Los Angeles, CA 90012  Los Angeles    90012      US
# 2            800 E 3rd St Los Angeles, CA 90013  Los Angeles    90013      US
# 3            327 E 1st St Los Angeles, CA 90012  Los Angeles    90012      US
# 4     3179 Los Feliz Blvd Los Angeles, CA 90039  Los Angeles    90039      US
#
#   state         phone
# 0    CA  +12138021470
# 1    CA  +12139358399
# 2    CA  +12136874444
# 3    CA  +12136261680
# 4    CA  +13236671839

# %%
# responseDict[response_url] = response.text

i = 0
j = 0

try:
    for i in range(len(temp_urls)):
        temp_response = requests.get(url = temp_urls[i], headers = HEADERS)
        
        print("=======================================================")
        print(f"temp_response: {temp_response}")
        
        temp_response_json = temp_response.json()
        
        temp_response_string = temp_response.text
        
        responseDict[temp_response.url] = temp_response_string
        

        print("=======================================================")
        print(f"OUTTER LOOP BEGGINS: URL: {temp_response.url}" )

        for j in range(len(temp_response_json['businesses'])):
            print("=======================================================")
            detail = temp_response_json['businesses'][j]
            print(f"inner loop (building df): biz index: {index_}: {temp_response_json['businesses'][j]['name']}")
                  
            biz_df.set_value(index_, "id", json_response['businesses'][j]['id'])
            biz_df.set_value(index_, "alias", json_response['businesses'][j]['alias'])

            biz_df.set_value(index_, "name", json_response['businesses'][j]['name'])
            biz_df.set_value(index_, "categories", ', '.join([val['title'] for val in json_response['businesses'][j]['categories']]) )        

            biz_df.set_value(index_, "review_count", json_response['businesses'][j]['review_count'])
            biz_df.set_value(index_, "rating", json_response['businesses'][j]['rating'])

            biz_df.set_value(index_, "lat", json_response['businesses'][j]['coordinates']['latitude'])
            biz_df.set_value(index_, "long", json_response['businesses'][j]['coordinates']['longitude'])

            biz_df.set_value(index_, "address", ' '.join(json_response['businesses'][j]['location']['display_address']))
            biz_df.set_value(index_, "city", json_response['businesses'][j]['location']['city'])

            biz_df.set_value(index_, "zip_code", json_response['businesses'][j]['location']['zip_code'])
            biz_df.set_value(index_, "country", json_response['businesses'][j]['location']['country'])

            biz_df.set_value(index_, "state", json_response['businesses'][j]['location']['state'])
            biz_df.set_value(index_, "phone", json_response['businesses'][j]['phone'])
            

            index_ += 1
              
        time.sleep(3)

except:
    print("Something went WRONG 😰")

print(f"Database ready: records entered:{index_}")
# Out:
# =======================================================
# temp_response: <Response [200]>
# =======================================================
# OUTTER LOOP BEGGINS: URL: https://api.yelp.com/v3/businesses/search?location=los+angeles+ca+united+states&limit=50&radius=40000&offset=50
# =======================================================
# inner loop (building df): biz index: 50: Eight Korean BBQ
# =======================================================
# inner loop (building df): biz index: 51: M Grill
# =======================================================
# inner loop (building df): biz index: 52: Leo's Tacos Truck
# =======================================================
# inner loop (building df): biz index: 53: The Pie Hole
# =======================================================
# inner loop (building df): biz index: 54: Tatsu Ramen
# =======================================================
# inner loop (building df): biz index: 55: The Broad
# =======================================================
# inner loop (building df): biz index: 56: El Chato Taco Truck
# =======================================================
# inner loop (building df): biz index: 57: SomiSomi
# =======================================================
# inner loop (building df): biz index: 58: Road To Seoul
# =======================================================
# inner loop (building df): biz index: 59: Angelini Osteria
# =======================================================
# inner loop (building df): biz index: 60: Anarkali Indian Restaurant
# =======================================================
# inner loop (building df): biz index: 61: India's Restaurant
# =======================================================
# inner loop (building df): biz index: 62: Bäco Mercat
# =======================================================
# inner loop (building df): biz index: 63: Ave 26 Taco Stand
# =======================================================
# inner loop (building df): biz index: 64: Ssam Korean BBQ
# =======================================================
# inner loop (building df): biz index: 65: Dino's Chicken and Burgers
# =======================================================
# inner loop (building df): biz index: 66: Grand Central Market
# =======================================================
# inner loop (building df): biz index: 67: Hangari Bajirak Kalguksu
# =======================================================
# inner loop (building df): biz index: 68: Hoy-Ka Thai Restaurant
# =======================================================
# inner loop (building df): biz index: 69: Father's Office
# =======================================================
# inner loop (building df): biz index: 70: Yuko Kitchen
# =======================================================
# inner loop (building df): biz index: 71: Cafe Dulce
# =======================================================
# inner loop (building df): biz index: 72: SUGARFISH by sushi nozawa
# =======================================================
# inner loop (building df): biz index: 73: Guisados DTLA
# =======================================================
# inner loop (building df): biz index: 74: Bulgogi Hut
# =======================================================
# inner loop (building df): biz index: 75: Mario's Peruvian & Seafood
# =======================================================
# inner loop (building df): biz index: 76: A Food Affair
# =======================================================
# inner loop (building df): biz index: 77: Roscoe's House of Chicken & Waffles
# =======================================================
# inner loop (building df): biz index: 78: Osteria Mozza
# =======================================================
# inner loop (building df): biz index: 79: Bao Dim Sum House
# =======================================================
# inner loop (building df): biz index: 80: California Donuts
# =======================================================
# inner loop (building df): biz index: 81: Shin-Sen-Gumi Hakata Ramen - Little Tokyo
# =======================================================
# inner loop (building df): biz index: 82: Pasta Sisters
# =======================================================
# inner loop (building df): biz index: 83: DeSano Pizza Bakery
# =======================================================
# inner loop (building df): biz index: 84: The Boiling Crab
# =======================================================
# inner loop (building df): biz index: 85: Ham Ji Park
# =======================================================
# inner loop (building df): biz index: 86: Pink's Hot Dogs
# =======================================================
# inner loop (building df): biz index: 87: The Little Door
# =======================================================
# inner loop (building df): biz index: 88: Chef Kang Food Rehab
# =======================================================
# inner loop (building df): biz index: 89: Chichen Itza Restaurant
# =======================================================
# inner loop (building df): biz index: 90: Sun Nong Dan
# =======================================================
# inner loop (building df): biz index: 91: Sul & Beans
# =======================================================
# inner loop (building df): biz index: 92: Home Restaurant - Los Feliz
# =======================================================
# inner loop (building df): biz index: 93: Mashti Malone's Ice Cream
# =======================================================
# inner loop (building df): biz index: 94: Rodini Park
# =======================================================
# inner loop (building df): biz index: 95: Roscoe's House of Chicken & Waffles
# =======================================================
# inner loop (building df): biz index: 96: Poppy + Rose
# =======================================================
# inner loop (building df): biz index: 97: Sushi Enya
# =======================================================
# inner loop (building df): biz index: 98: Natural History Museum
# =======================================================
# inner loop (building df): biz index: 99: Shojin Downtown
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:28: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:32: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:34: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:37: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:38: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:40: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:41: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:46: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:47: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# =======================================================
# temp_response: <Response [200]>
# =======================================================
# OUTTER LOOP BEGGINS: URL: https://api.yelp.com/v3/businesses/search?location=los+angeles+ca+united+states&limit=50&radius=40000&offset=100
# =======================================================
# inner loop (building df): biz index: 100: BROKEN MOUTH | Lee's Homestyle
# =======================================================
# inner loop (building df): biz index: 101: Taqueria Los Anaya
# =======================================================
# inner loop (building df): biz index: 102: Ricky's Fish Tacos
# =======================================================
# inner loop (building df): biz index: 103: Water Grill- Los Angeles
# =======================================================
# inner loop (building df): biz index: 104: Corn Man
# =======================================================
# inner loop (building df): biz index: 105: Little Jewel of New Orleans
# =======================================================
# inner loop (building df): biz index: 106: Beer Belly
# =======================================================
# inner loop (building df): biz index: 107: Pa Ord Noodle
# =======================================================
# inner loop (building df): biz index: 108: The Bun Shop
# =======================================================
# inner loop (building df): biz index: 109: Ta-eem Grill
# =======================================================
# inner loop (building df): biz index: 110: Tlayuda La Restaurant
# =======================================================
# inner loop (building df): biz index: 111: Cassell's Hamburgers
# =======================================================
# inner loop (building df): biz index: 112: Salt & Straw
# =======================================================
# inner loop (building df): biz index: 113: Ahgassi Gopchang
# =======================================================
# inner loop (building df): biz index: 114: Mendocino Farms
# =======================================================
# inner loop (building df): biz index: 115: Runyon Canyon Park
# =======================================================
# inner loop (building df): biz index: 116: n/naka
# =======================================================
# inner loop (building df): biz index: 117: Joan's on Third
# =======================================================
# inner loop (building df): biz index: 118: Mex Perú Gipsy
# =======================================================
# inner loop (building df): biz index: 119: Sage Vegan Bistro - Echo Park
# =======================================================
# inner loop (building df): biz index: 120: The Park's Finest
# =======================================================
# inner loop (building df): biz index: 121: Guelaguetza Restaurante
# =======================================================
# inner loop (building df): biz index: 122: Osteria La Buca
# =======================================================
# inner loop (building df): biz index: 123: Kobawoo House
# =======================================================
# inner loop (building df): biz index: 124: California Science Center
# =======================================================
# inner loop (building df): biz index: 125: Cafe Gratitude - Larchmont
# =======================================================
# inner loop (building df): biz index: 126: Hae Ha Heng Thai Bistro
# =======================================================
# inner loop (building df): biz index: 127: Benny's Tacos & Chicken Rotisserie
# =======================================================
# inner loop (building df): biz index: 128: Palms Thai Restaurant
# =======================================================
# inner loop (building df): biz index: 129: Bludso's Bar & Que
# =======================================================
# inner loop (building df): biz index: 130: Beverly Soon Tofu Restaurant
# =======================================================
# inner loop (building df): biz index: 131: Philz Coffee
# =======================================================
# inner loop (building df): biz index: 132: Craft
# =======================================================
# inner loop (building df): biz index: 133: Komasa Sushi
# =======================================================
# inner loop (building df): biz index: 134: Park's BBQ
# =======================================================
# inner loop (building df): biz index: 135: Marmalade Cafe
# =======================================================
# inner loop (building df): biz index: 136: Larchmont Village Wine Spirits & Cheese
# =======================================================
# inner loop (building df): biz index: 137: Carlitos Gardel Argentine Steakhouse
# =======================================================
# inner loop (building df): biz index: 138: Seven Grand
# =======================================================
# inner loop (building df): biz index: 139: Faith & Flower
# =======================================================
# inner loop (building df): biz index: 140: Golden State
# =======================================================
# inner loop (building df): biz index: 141: Bronzed Aussie
# =======================================================
# inner loop (building df): biz index: 142: Birdies
# =======================================================
# inner loop (building df): biz index: 143: Berlins
# =======================================================
# inner loop (building df): biz index: 144: Mikawaya
# =======================================================
# inner loop (building df): biz index: 145: Jacks N Joe
# =======================================================
# inner loop (building df): biz index: 146: Bacari W. Adams
# =======================================================
# inner loop (building df): biz index: 147: Bossa Nova on Sunset
# =======================================================
# inner loop (building df): biz index: 148: Nickel Diner
# =======================================================
# inner loop (building df): biz index: 149: The Oinkster
# =======================================================
# temp_response: <Response [200]>
# =======================================================
# OUTTER LOOP BEGGINS: URL: https://api.yelp.com/v3/businesses/search?location=los+angeles+ca+united+states&limit=50&radius=40000&offset=150
# =======================================================
# inner loop (building df): biz index: 150: Met Her At A Bar
# =======================================================
# inner loop (building df): biz index: 151: Gus's World Famous Fried Chicken
# =======================================================
# inner loop (building df): biz index: 152: Alchemist Coffee Project
# =======================================================
# inner loop (building df): biz index: 153: Jeni's Splendid Ice Creams
# =======================================================
# inner loop (building df): biz index: 154: Grub
# =======================================================
# inner loop (building df): biz index: 155: AOC
# =======================================================
# inner loop (building df): biz index: 156: Chibiscus Asian Cafe
# =======================================================
# inner loop (building df): biz index: 157: Mohawk Bend
# =======================================================
# inner loop (building df): biz index: 158: Mariscos Jalisco
# =======================================================
# inner loop (building df): biz index: 159: The Edison
# =======================================================
# inner loop (building df): biz index: 160: Ruen Pair
# =======================================================
# inner loop (building df): biz index: 161: Eastside Market Italian Deli
# =======================================================
# inner loop (building df): biz index: 162: Wanderlust Creamery
# =======================================================
# inner loop (building df): biz index: 163: Yuchun
# =======================================================
# inner loop (building df): biz index: 164: Gelateria Uli
# =======================================================
# inner loop (building df): biz index: 165: Best Fish Taco In Ensenada
# =======================================================
# inner loop (building df): biz index: 166: The Kitchen
# =======================================================
# inner loop (building df): biz index: 167: Yang Chow
# =======================================================
# inner loop (building df): biz index: 168: Stout Burgers & Beers
# =======================================================
# inner loop (building df): biz index: 169: Tiki-Ti Cocktail Lounge
# =======================================================
# inner loop (building df): biz index: 170: Canter's Deli
# =======================================================
# inner loop (building df): biz index: 171: Andre's Italian Restaurant
# =======================================================
# inner loop (building df): biz index: 172: Bavel
# =======================================================
# inner loop (building df): biz index: 173: Little Next Door
# =======================================================
# inner loop (building df): biz index: 174: The Grain Cafe
# =======================================================
# inner loop (building df): biz index: 175: My Two Cents
# =======================================================
# inner loop (building df): biz index: 176: Big Man Bakes
# =======================================================
# inner loop (building df): biz index: 177: Fat Sal's
# =======================================================
# inner loop (building df): biz index: 178: Undergrind Cafe
# =======================================================
# inner loop (building df): biz index: 179: Colori Kitchen
# =======================================================
# inner loop (building df): biz index: 180: Son of a Gun
# =======================================================
# inner loop (building df): biz index: 181: Ktown Pho
# =======================================================
# inner loop (building df): biz index: 182: Intelligentsia Coffee
# =======================================================
# inner loop (building df): biz index: 183: Sqirl
# =======================================================
# inner loop (building df): biz index: 184: Lala's Argentine Grill
# =======================================================
# inner loop (building df): biz index: 185: Carmela Ice Cream
# =======================================================
# inner loop (building df): biz index: 186: The Griddle Cafe
# =======================================================
# inner loop (building df): biz index: 187: Chosun Galbee
# =======================================================
# inner loop (building df): biz index: 188: Araya's Place - Thai Vegan Restaurant
# =======================================================
# inner loop (building df): biz index: 189: LA Rose Cafe
# =======================================================
# inner loop (building df): biz index: 190: Figueroa Philly Cheese Steak
# =======================================================
# inner loop (building df): biz index: 191: The Black Sheep
# =======================================================
# inner loop (building df): biz index: 192: Boo's Philly Cheesesteaks - Silverlake
# =======================================================
# inner loop (building df): biz index: 193: RockSugar Southeast Asian Kitchen
# =======================================================
# inner loop (building df): biz index: 194: Running Goose
# =======================================================
# inner loop (building df): biz index: 195: Osteria Mamma
# =======================================================
# inner loop (building df): biz index: 196: Eat This Cafe
# =======================================================
# inner loop (building df): biz index: 197: Griffith Park
# =======================================================
# inner loop (building df): biz index: 198: Revolutionario: North African Tacos
# =======================================================
# inner loop (building df): biz index: 199: Otium
# =======================================================
# temp_response: <Response [200]>
# =======================================================
# OUTTER LOOP BEGGINS: URL: https://api.yelp.com/v3/businesses/search?location=los+angeles+ca+united+states&limit=50&radius=40000&offset=200
# =======================================================
# inner loop (building df): biz index: 200: Fisherman's Outlet
# =======================================================
# inner loop (building df): biz index: 201: Powerplant Superfood Cafe
# =======================================================
# inner loop (building df): biz index: 202: Pho 87
# =======================================================
# inner loop (building df): biz index: 203: Mendocino Farms
# =======================================================
# inner loop (building df): biz index: 204: Pazzo Gelato
# =======================================================
# inner loop (building df): biz index: 205: Badmaash - Downtown LA
# =======================================================
# inner loop (building df): biz index: 206: McConnell's Fine Ice Creams
# =======================================================
# inner loop (building df): biz index: 207: La Cevicheria
# =======================================================
# inner loop (building df): biz index: 208: Mo Better Burgers
# =======================================================
# inner loop (building df): biz index: 209: Tacos Tumbras a Tomas
# =======================================================
# inner loop (building df): biz index: 210: Oo-Kook Korean BBQ
# =======================================================
# inner loop (building df): biz index: 211: Spitz - Little Tokyo
# =======================================================
# inner loop (building df): biz index: 212: Cardamom Indian cuisine
# =======================================================
# inner loop (building df): biz index: 213: Hama Sushi
# =======================================================
# inner loop (building df): biz index: 214: Zinc Cafe & Market
# =======================================================
# inner loop (building df): biz index: 215: Pampas Grill
# =======================================================
# inner loop (building df): biz index: 216: Versailles Cuban Food
# =======================================================
# inner loop (building df): biz index: 217: Tommy's Original World Famous Hamburgers
# =======================================================
# inner loop (building df): biz index: 218: JiST Cafe
# =======================================================
# inner loop (building df): biz index: 219: Veggie Grill
# =======================================================
# inner loop (building df): biz index: 220: Crossroads
# =======================================================
# inner loop (building df): biz index: 221: Byul Gobchang
# =======================================================
# inner loop (building df): biz index: 222: Mercado Los Angeles
# =======================================================
# inner loop (building df): biz index: 223: Rutt's Hawaiian Cafe
# =======================================================
# inner loop (building df): biz index: 224: Redbird
# =======================================================
# inner loop (building df): biz index: 225: Simpang Asia
# =======================================================
# inner loop (building df): biz index: 226: Bricks & Scones
# =======================================================
# inner loop (building df): biz index: 227: Palermo Italian Restaurant
# =======================================================
# inner loop (building df): biz index: 228: Sapp Coffee Shop
# =======================================================
# inner loop (building df): biz index: 229: The Apple Pan
# =======================================================
# inner loop (building df): biz index: 230: Maggiano's Little Italy
# =======================================================
# inner loop (building df): biz index: 231: HomeState
# =======================================================
# inner loop (building df): biz index: 232: Original Pantry Cafe
# =======================================================
# inner loop (building df): biz index: 233: The Lobos Truck
# =======================================================
# inner loop (building df): biz index: 234: Buil Samgye Tang
# =======================================================
# inner loop (building df): biz index: 235: Fratelli Cafe
# =======================================================
# inner loop (building df): biz index: 236: 71 Above
# =======================================================
# inner loop (building df): biz index: 237: Panini Kabob Grill
# =======================================================
# inner loop (building df): biz index: 238: Wood Spoon
# =======================================================
# inner loop (building df): biz index: 239: Shabu Shabu House
# =======================================================
# inner loop (building df): biz index: 240: Seongbukdong
# =======================================================
# inner loop (building df): biz index: 241: Square One Dining
# =======================================================
# inner loop (building df): biz index: 242: Fugetsu-Do
# =======================================================
# inner loop (building df): biz index: 243: Sonoratown
# =======================================================
# inner loop (building df): biz index: 244: Toca Madera
# =======================================================
# inner loop (building df): biz index: 245: Sidewalk Grill
# =======================================================
# inner loop (building df): biz index: 246: In-N-Out Burger
# =======================================================
# inner loop (building df): biz index: 247: La Brea Tar Pits & Museum
# =======================================================
# inner loop (building df): biz index: 248: Ramen Hood
# =======================================================
# inner loop (building df): biz index: 249: Concerto
# =======================================================
# temp_response: <Response [200]>
# =======================================================
# OUTTER LOOP BEGGINS: URL: https://api.yelp.com/v3/businesses/search?location=los+angeles+ca+united+states&limit=50&radius=40000&offset=250
# =======================================================
# inner loop (building df): biz index: 250: Doomie's Home Cookin'
# =======================================================
# inner loop (building df): biz index: 251: Bae
# =======================================================
# inner loop (building df): biz index: 252: Sushi Ippo
# =======================================================
# inner loop (building df): biz index: 253: Strada Eateria & Coffee
# =======================================================
# inner loop (building df): biz index: 254: Robata JINYA
# =======================================================
# inner loop (building df): biz index: 255: Pharaoh Karaoke Lounge
# =======================================================
# inner loop (building df): biz index: 256: Gol Tong Chicken
# =======================================================
# inner loop (building df): biz index: 257: Mendocino Farms
# =======================================================
# inner loop (building df): biz index: 258: Plan Check Kitchen & Bar
# =======================================================
# inner loop (building df): biz index: 259: Oi Asian Fusion
# =======================================================
# inner loop (building df): biz index: 260: The Ramen Joint
# =======================================================
# inner loop (building df): biz index: 261: Barton G. The Restaurant Los Angeles
# =======================================================
# inner loop (building df): biz index: 262: Noshi Sushi
# =======================================================
# inner loop (building df): biz index: 263: Gloria's Cafe
# =======================================================
# inner loop (building df): biz index: 264: Sushi Go 55
# =======================================================
# inner loop (building df): biz index: 265: Oakobing
# =======================================================
# inner loop (building df): biz index: 266: Yardbird Southern Table & Bar
# =======================================================
# inner loop (building df): biz index: 267: Hotel Café
# =======================================================
# inner loop (building df): biz index: 268: Biriyani Kabob House
# =======================================================
# inner loop (building df): biz index: 269: Cole's French Dip
# =======================================================
# inner loop (building df): biz index: 270: Ariyoshi Sushi Cafe Izakaya
# =======================================================
# inner loop (building df): biz index: 271: Mike's Deli
# =======================================================
# inner loop (building df): biz index: 272: Catch 56
# =======================================================
# inner loop (building df): biz index: 273: Library Bar
# =======================================================
# inner loop (building df): biz index: 274: Green Table Cafe
# =======================================================
# inner loop (building df): biz index: 275: Spoon By H
# =======================================================
# inner loop (building df): biz index: 276: Mesón Cafe
# =======================================================
# inner loop (building df): biz index: 277: Bagel Broker
# =======================================================
# inner loop (building df): biz index: 278: Hwa Sun Ji Tea & Coffee
# =======================================================
# inner loop (building df): biz index: 279: Next Door Lounge
# =======================================================
# inner loop (building df): biz index: 280: Takami Sushi & Robata Restaurant
# =======================================================
# inner loop (building df): biz index: 281: The Varnish
# =======================================================
# inner loop (building df): biz index: 282: KaGaYa
# =======================================================
# inner loop (building df): biz index: 283: Yuk Dae Jang
# =======================================================
# inner loop (building df): biz index: 284: The Factory Kitchen
# =======================================================
# inner loop (building df): biz index: 285: Stumptown Coffee Roasters
# =======================================================
# inner loop (building df): biz index: 286: COD Restaurant
# =======================================================
# inner loop (building df): biz index: 287: Everson Royce Bar
# =======================================================
# inner loop (building df): biz index: 288: Men Oh Tokushima Ramen
# =======================================================
# inner loop (building df): biz index: 289: Demitasse
# =======================================================
# inner loop (building df): biz index: 290: India's Tandoori
# =======================================================
# inner loop (building df): biz index: 291: Angry Birdz
# =======================================================
# inner loop (building df): biz index: 292: PASTA e PASTA by Allegro
# =======================================================
# inner loop (building df): biz index: 293: Document Coffee Bar
# =======================================================
# inner loop (building df): biz index: 294: My Vegan Gold
# =======================================================
# inner loop (building df): biz index: 295: Myung Dong Kyoja
# =======================================================
# inner loop (building df): biz index: 296: Lawry's The Prime Rib - Beverly Hills
# =======================================================
# inner loop (building df): biz index: 297: Balcony Coffee and Tea
# =======================================================
# inner loop (building df): biz index: 298: Village Pizzeria
# =======================================================
# inner loop (building df): biz index: 299: Drips & Swirls
# =======================================================
# temp_response: <Response [200]>
# =======================================================
# OUTTER LOOP BEGGINS: URL: https://api.yelp.com/v3/businesses/search?location=los+angeles+ca+united+states&limit=50&radius=40000&offset=300
# =======================================================
# inner loop (building df): biz index: 300: Crumbs & Whiskers | A Cat Cafe Experience.
# =======================================================
# inner loop (building df): biz index: 301: Stella Barra Pizzeria
# =======================================================
# inner loop (building df): biz index: 302: Boulevard3
# =======================================================
# inner loop (building df): biz index: 303: Pollo a La Brasa Western
# =======================================================
# inner loop (building df): biz index: 304: Little Pine
# =======================================================
# inner loop (building df): biz index: 305: Bread Lounge
# =======================================================
# inner loop (building df): biz index: 306: Murakami Sushi
# =======================================================
# inner loop (building df): biz index: 307: Red Lion Tavern
# =======================================================
# inner loop (building df): biz index: 308: Urban Light at LACMA
# =======================================================
# inner loop (building df): biz index: 309: Kinjiro
# =======================================================
# inner loop (building df): biz index: 310: Ubatuba Acai - Koreatown
# =======================================================
# inner loop (building df): biz index: 311: The Carving Board
# =======================================================
# inner loop (building df): biz index: 312: Fleming's Prime Steakhouse & Wine Bar
# =======================================================
# inner loop (building df): biz index: 313: Il Capriccio on Vermont
# =======================================================
# inner loop (building df): biz index: 314: Preux & Proper
# =======================================================
# inner loop (building df): biz index: 315: Nick's Cafe
# =======================================================
# inner loop (building df): biz index: 316: Yard House
# =======================================================
# inner loop (building df): biz index: 317: ACA Grill
# =======================================================
# inner loop (building df): biz index: 318: Salt & Straw
# =======================================================
# inner loop (building df): biz index: 319: Jon & Vinny's Fairfax
# =======================================================
# inner loop (building df): biz index: 320: La Pergoletta
# =======================================================
# inner loop (building df): biz index: 321: Meals by Genet
# =======================================================
# inner loop (building df): biz index: 322: 25 Degrees
# =======================================================
# inner loop (building df): biz index: 323: Tara's Himalayan Cuisine
# =======================================================
# inner loop (building df): biz index: 324: Paradocs Coffee and Tea
# =======================================================
# inner loop (building df): biz index: 325: Little Sister
# =======================================================
# inner loop (building df): biz index: 326: Flore Vegan Cuisine
# =======================================================
# inner loop (building df): biz index: 327: Umami Burger - Hollywood
# =======================================================
# inner loop (building df): biz index: 328: Zzamong
# =======================================================
# inner loop (building df): biz index: 329: Cruzer Pizza 100% Vegan
# =======================================================
# inner loop (building df): biz index: 330: DRAGO Centro
# =======================================================
# inner loop (building df): biz index: 331: Carousel Restaurant
# =======================================================
# inner loop (building df): biz index: 332: Yxta Cocina Mexicana
# =======================================================
# inner loop (building df): biz index: 333: KyoChon
# =======================================================
# inner loop (building df): biz index: 334: Aliki's Greek Taverna
# =======================================================
# inner loop (building df): biz index: 335: The Bazaar by José Andrés
# =======================================================
# inner loop (building df): biz index: 336: OB Bear
# =======================================================
# inner loop (building df): biz index: 337: Tire Shop Taqueria
# =======================================================
# inner loop (building df): biz index: 338: Elf Café
# =======================================================
# inner loop (building df): biz index: 339: Blue Cow Kitchen & Bar
# =======================================================
# inner loop (building df): biz index: 340: Shabu Hyang
# =======================================================
# inner loop (building df): biz index: 341: Pann's Restaurant
# =======================================================
# inner loop (building df): biz index: 342: Ayara Thai Cuisine
# =======================================================
# inner loop (building df): biz index: 343: Cliff's Edge
# =======================================================
# inner loop (building df): biz index: 344: Marie's Coffee & Deli
# =======================================================
# inner loop (building df): biz index: 345: Karl Strauss Brewing Company
# =======================================================
# inner loop (building df): biz index: 346: Katsuya Hollywood
# =======================================================
# inner loop (building df): biz index: 347: Vito's Pizza
# =======================================================
# inner loop (building df): biz index: 348: Kogi BBQ Truck - Azul
# =======================================================
# inner loop (building df): biz index: 349: Toast Bakery Cafe
# =======================================================
# temp_response: <Response [200]>
# =======================================================
# OUTTER LOOP BEGGINS: URL: https://api.yelp.com/v3/businesses/search?location=los+angeles+ca+united+states&limit=50&radius=40000&offset=350
# =======================================================
# inner loop (building df): biz index: 350: LA Café
# =======================================================
# inner loop (building df): biz index: 351: Far Bar
# =======================================================
# inner loop (building df): biz index: 352: いざかや おせん- IZAKAYA OSEN
# =======================================================
# inner loop (building df): biz index: 353: Spicy BBQ Restaurant
# =======================================================
# inner loop (building df): biz index: 354: Twinkle Brown Sugar
# =======================================================
# inner loop (building df): biz index: 355: Sushi Zo
# =======================================================
# inner loop (building df): biz index: 356: Dune
# =======================================================
# inner loop (building df): biz index: 357: Au Lac
# =======================================================
# inner loop (building df): biz index: 358: Orochon Ramen
# =======================================================
# inner loop (building df): biz index: 359: I Panini di Ambra
# =======================================================
# inner loop (building df): biz index: 360: Vegan Glory
# =======================================================
# inner loop (building df): biz index: 361: Chunju Han-il Kwan
# =======================================================
# inner loop (building df): biz index: 362: Pearl's Finest Teas
# =======================================================
# inner loop (building df): biz index: 363: Versailles
# =======================================================
# inner loop (building df): biz index: 364: Midori Matcha Cafe
# =======================================================
# inner loop (building df): biz index: 365: EightyTwo
# =======================================================
# inner loop (building df): biz index: 366: Curry House
# =======================================================
# inner loop (building df): biz index: 367: Truxton's American Bistro
# =======================================================
# inner loop (building df): biz index: 368: Cafe Los Feliz
# =======================================================
# inner loop (building df): biz index: 369: Tilt Coffee Bar
# =======================================================
# inner loop (building df): biz index: 370: Ong Ga Nae Korean BBQ
# =======================================================
# inner loop (building df): biz index: 371: The Izaka-Ya by Katsu-Ya West Hollywood
# =======================================================
# inner loop (building df): biz index: 372: Sanamluang Cafe
# =======================================================
# inner loop (building df): biz index: 373: Feng Mao Lamb Kebab
# =======================================================
# inner loop (building df): biz index: 374: Tribal Cafe
# =======================================================
# inner loop (building df): biz index: 375: Tsuri
# =======================================================
# inner loop (building df): biz index: 376: Kali Restaurant
# =======================================================
# inner loop (building df): biz index: 377: Buna Ethiopian Restaurant & Market
# =======================================================
# inner loop (building df): biz index: 378: Suehiro Cafe
# =======================================================
# inner loop (building df): biz index: 379: Luv2Eat Thai Bistro
# =======================================================
# inner loop (building df): biz index: 380: Snow Monster
# =======================================================
# inner loop (building df): biz index: 381: The Stocking Frame
# =======================================================
# inner loop (building df): biz index: 382: Zweet Cafe
# =======================================================
# inner loop (building df): biz index: 383: Honeymee Wilshire
# =======================================================
# inner loop (building df): biz index: 384: Magpies Softserve
# =======================================================
# inner loop (building df): biz index: 385: Nick's Coffee Shop
# =======================================================
# inner loop (building df): biz index: 386: The Coffee Company
# =======================================================
# inner loop (building df): biz index: 387: Empanada's Place
# =======================================================
# inner loop (building df): biz index: 388: Mercado Hollywood
# =======================================================
# inner loop (building df): biz index: 389: Backyard Bowls
# =======================================================
# inner loop (building df): biz index: 390: Alibi Room
# =======================================================
# inner loop (building df): biz index: 391: Wirtshaus German Restaurant & Beer Garden
# =======================================================
# inner loop (building df): biz index: 392: Escala
# =======================================================
# inner loop (building df): biz index: 393: Mexicali Taco & Co
# =======================================================
# inner loop (building df): biz index: 394: Blue Palms Brewhouse
# =======================================================
# inner loop (building df): biz index: 395: Bird's Nest Cafe
# =======================================================
# inner loop (building df): biz index: 396: Cafe Gratitude
# =======================================================
# inner loop (building df): biz index: 397: Gracie's Pizza
# =======================================================
# inner loop (building df): biz index: 398: Verve Coffee Roasters
# =======================================================
# inner loop (building df): biz index: 399: Bumsan Organic Milk Bar
# =======================================================
# temp_response: <Response [200]>
# =======================================================
# OUTTER LOOP BEGGINS: URL: https://api.yelp.com/v3/businesses/search?location=los+angeles+ca+united+states&limit=50&radius=40000&offset=400
# =======================================================
# inner loop (building df): biz index: 400: Taco Zone Truck
# =======================================================
# inner loop (building df): biz index: 401: Casa La Doña
# =======================================================
# inner loop (building df): biz index: 402: Corner Place
# =======================================================
# inner loop (building df): biz index: 403: Anko
# =======================================================
# inner loop (building df): biz index: 404: The Punchbowl
# =======================================================
# inner loop (building df): biz index: 405: Klat
# =======================================================
# inner loop (building df): biz index: 406: Dumpling House
# =======================================================
# inner loop (building df): biz index: 407: The Penthouse at Mastro's
# =======================================================
# inner loop (building df): biz index: 408: Proof Bakery
# =======================================================
# inner loop (building df): biz index: 409: Westside Tavern
# =======================================================
# inner loop (building df): biz index: 410: El Carmen
# =======================================================
# inner loop (building df): biz index: 411: Hollywood Burger
# =======================================================
# inner loop (building df): biz index: 412: Food Fair By Diego
# =======================================================
# inner loop (building df): biz index: 413: Homegirl Cafe
# =======================================================
# inner loop (building df): biz index: 414: Gigi's Bakery & Café
# =======================================================
# inner loop (building df): biz index: 415: El Taurino
# =======================================================
# inner loop (building df): biz index: 416: Cafe Brasil
# =======================================================
# inner loop (building df): biz index: 417: A Simple Bar
# =======================================================
# inner loop (building df): biz index: 418: RioZonas Açaí
# =======================================================
# inner loop (building df): biz index: 419: Earle's On Crenshaw
# =======================================================
# inner loop (building df): biz index: 420: Jinsol Gukbap
# =======================================================
# inner loop (building df): biz index: 421: Scoops Westside
# =======================================================
# inner loop (building df): biz index: 422: El Flamin' Taco
# =======================================================
# ...
# inner loop (building df): biz index: 865: TBLA Catering & Cafe
# =======================================================
# inner loop (building df): biz index: 866: Mezcalero
# =======================================================
# inner loop (building df): biz index: 867: Ray's and Stark Bar
# =======================================================
# inner loop (building df): biz index: 868: Stone Grill
# =======================================================
# inner loop (building df): biz index: 869: Pho Hoa Vietnamese Restaurant
# =======================================================
# inner loop (building df): biz index: 870: Georgetown Cupcake
# =======================================================
# inner loop (building df): biz index: 871: RoRo's Chicken
# =======================================================
# inner loop (building df): biz index: 872: Pepe's Tacos
# =======================================================
# inner loop (building df): biz index: 873: CJ's Cafe
# =======================================================
# inner loop (building df): biz index: 874: Bossa Nova Brazilian Cuisine
# =======================================================
# inner loop (building df): biz index: 875: Hunter & Charlie's
# =======================================================
# inner loop (building df): biz index: 876: Sushi Ye
# =======================================================
# inner loop (building df): biz index: 877: Kung Fu Tea
# =======================================================
# inner loop (building df): biz index: 878: Ostrich Farm
# =======================================================
# inner loop (building df): biz index: 879: Choi Ga Nei Korean BBQ
# =======================================================
# inner loop (building df): biz index: 880: Tropicalia Brazilian Grill
# =======================================================
# inner loop (building df): biz index: 881: Casa Nostra Ristorante & Bar
# =======================================================
# inner loop (building df): biz index: 882: Pho Thai Town
# =======================================================
# inner loop (building df): biz index: 883: Inko Nito
# =======================================================
# inner loop (building df): biz index: 884: Shojin Culver City
# =======================================================
# inner loop (building df): biz index: 885: DAMA
# =======================================================
# inner loop (building df): biz index: 886: Clifton's Republic
# =======================================================
# inner loop (building df): biz index: 887: Chill Rollz
# =======================================================
# inner loop (building df): biz index: 888: Olive Bistro & Catering
# =======================================================
# inner loop (building df): biz index: 889: Gyu-Kaku Japanese BBQ
# =======================================================
# inner loop (building df): biz index: 890: Paris Baguette
# =======================================================
# inner loop (building df): biz index: 891: Fala Bar
# =======================================================
# inner loop (building df): biz index: 892: Olympic Noodle
# =======================================================
# inner loop (building df): biz index: 893: Stuff'd Dumpling Shop
# =======================================================
# inner loop (building df): biz index: 894: Burgerlords
# =======================================================
# inner loop (building df): biz index: 895: All'Acqua
# =======================================================
# inner loop (building df): biz index: 896: Creperie Le Terrace
# =======================================================
# inner loop (building df): biz index: 897: Tacos Villa Corona
# =======================================================
# inner loop (building df): biz index: 898: Southland Beer
# =======================================================
# inner loop (building df): biz index: 899: Public School 213
# =======================================================
# temp_response: <Response [200]>
# =======================================================
# OUTTER LOOP BEGGINS: URL: https://api.yelp.com/v3/businesses/search?location=los+angeles+ca+united+states&limit=50&radius=40000&offset=900
# =======================================================
# inner loop (building df): biz index: 900: Saint Felix
# =======================================================
# inner loop (building df): biz index: 901: Nothing But Coffee
# =======================================================
# inner loop (building df): biz index: 902: Raw Cane Super Juice Bar
# =======================================================
# inner loop (building df): biz index: 903: Shekarchi Restaurant
# =======================================================
# inner loop (building df): biz index: 904: The Rendition Room
# =======================================================
# inner loop (building df): biz index: 905: The Escondite
# =======================================================
# inner loop (building df): biz index: 906: Kiku Sushi
# =======================================================
# inner loop (building df): biz index: 907: Young King
# =======================================================
# inner loop (building df): biz index: 908: Deli-In
# =======================================================
# inner loop (building df): biz index: 909: Thirsty Crow
# =======================================================
# inner loop (building df): biz index: 910: WP24
# =======================================================
# inner loop (building df): biz index: 911: Diablo
# =======================================================
# inner loop (building df): biz index: 912: Tacos Delta
# =======================================================
# inner loop (building df): biz index: 913: Ruam Mitr
# =======================================================
# inner loop (building df): biz index: 914: Pinches Tacos
# =======================================================
# inner loop (building df): biz index: 915: JJ's Sandwich Shop
# =======================================================
# inner loop (building df): biz index: 916: Mr Churro
# =======================================================
# inner loop (building df): biz index: 917: Verdugo Bar
# =======================================================
# inner loop (building df): biz index: 918: Jeff's Gourmet Sausage Factory
# =======================================================
# inner loop (building df): biz index: 919: Deli-cious Deli & Catering
# =======================================================
# inner loop (building df): biz index: 920: Zankou Chicken - Hollywood
# =======================================================
# inner loop (building df): biz index: 921: Señor Fish
# =======================================================
# inner loop (building df): biz index: 922: The Vegan Joint
# =======================================================
# inner loop (building df): biz index: 923: LONO Hollywood
# =======================================================
# inner loop (building df): biz index: 924: Chicas Tacos
# =======================================================
# inner loop (building df): biz index: 925: 101 Coffee Shop
# =======================================================
# inner loop (building df): biz index: 926: TOT / Teishokuya of Tokyo
# =======================================================
# inner loop (building df): biz index: 927: Casa Fina Restaurant & Cantina
# =======================================================
# inner loop (building df): biz index: 928: Tokyo Hamburg
# =======================================================
# inner loop (building df): biz index: 929: RUBIES+DIAMONDS
# =======================================================
# inner loop (building df): biz index: 930: Javista Organic Coffee Bar
# =======================================================
# inner loop (building df): biz index: 931: Tiago Coffee Bar & Kitchen
# =======================================================
# inner loop (building df): biz index: 932: Frolic Room
# =======================================================
# inner loop (building df): biz index: 933: Iki ramen
# =======================================================
# inner loop (building df): biz index: 934: Los Angeles Zoo & Botanical Gardens
# =======================================================
# inner loop (building df): biz index: 935: My Thai
# =======================================================
# inner loop (building df): biz index: 936: Mixto Comida Latina
# =======================================================
# inner loop (building df): biz index: 937: Yang San Bak
# =======================================================
# inner loop (building df): biz index: 938: PokeMotto
# =======================================================
# inner loop (building df): biz index: 939: Calle Tacos
# =======================================================
# inner loop (building df): biz index: 940: Sarita's Pupuseria
# =======================================================
# inner loop (building df): biz index: 941: Lock & Key
# =======================================================
# inner loop (building df): biz index: 942: El Taco Toro
# =======================================================
# inner loop (building df): biz index: 943: Sawyer
# =======================================================
# inner loop (building df): biz index: 944: Little Damage
# =======================================================
# inner loop (building df): biz index: 945: Kotoya Ramen
# =======================================================
# inner loop (building df): biz index: 946: Crawford's
# =======================================================
# inner loop (building df): biz index: 947: Coppelia's Bakery & Cafe
# =======================================================
# inner loop (building df): biz index: 948: Simply Wholesome
# =======================================================
# inner loop (building df): biz index: 949: La Brea Ramen Bar
# =======================================================
# temp_response: <Response [200]>
# =======================================================
# OUTTER LOOP BEGGINS: URL: https://api.yelp.com/v3/businesses/search?location=los+angeles+ca+united+states&limit=50&radius=40000&offset=950
# =======================================================
# inner loop (building df): biz index: 950: Love Baked Wings
# =======================================================
# inner loop (building df): biz index: 951: Las Perlas
# =======================================================
# inner loop (building df): biz index: 952: The 3rd Stop
# =======================================================
# inner loop (building df): biz index: 953: Nabeeya
# =======================================================
# inner loop (building df): biz index: 954: La Noche Buena Restaurant
# =======================================================
# inner loop (building df): biz index: 955: Sea Dragon Chinese Restaurant
# =======================================================
# inner loop (building df): biz index: 956: No Ghost Bears
# =======================================================
# inner loop (building df): biz index: 957: Gusto
# =======================================================
# inner loop (building df): biz index: 958: MOD Pizza
# =======================================================
# inner loop (building df): biz index: 959: Spring Street Smoke House
# =======================================================
# inner loop (building df): biz index: 960: 4100 Bar
# =======================================================
# inner loop (building df): biz index: 961: Bolt
# =======================================================
# inner loop (building df): biz index: 962: Morton's The Steakhouse
# =======================================================
# inner loop (building df): biz index: 963: El Cartel
# =======================================================
# inner loop (building df): biz index: 964: Foodlab
# =======================================================
# inner loop (building df): biz index: 965: H Cafe
# =======================================================
# inner loop (building df): biz index: 966: McConnell's Fine Ice Creams
# =======================================================
# inner loop (building df): biz index: 967: Post & Beam
# =======================================================
# inner loop (building df): biz index: 968: Pollen
# =======================================================
# inner loop (building df): biz index: 969: Crispy Crust Pizza
# =======================================================
# inner loop (building df): biz index: 970: SPL Coffee
# =======================================================
# inner loop (building df): biz index: 971: Aslan Mediterranean Cuisine
# =======================================================
# inner loop (building df): biz index: 972: RiceBar
# =======================================================
# inner loop (building df): biz index: 973: HATCH Yakitori + Bar
# =======================================================
# inner loop (building df): biz index: 974: Ord & Broadway
# =======================================================
# inner loop (building df): biz index: 975: Fantastic Donuts and Croissants
# =======================================================
# inner loop (building df): biz index: 976: Bob's Coffee & Doughnuts
# =======================================================
# inner loop (building df): biz index: 977: U Pick Cafe
# =======================================================
# inner loop (building df): biz index: 978: Frogtowns Gourmet Tacos
# =======================================================
# inner loop (building df): biz index: 979: Vinoteca Farfalla
# =======================================================
# inner loop (building df): biz index: 980: Mari Kimbap Shop
# =======================================================
# inner loop (building df): biz index: 981: Shintaro Sushi
# =======================================================
# inner loop (building df): biz index: 982: Speranza
# =======================================================
# inner loop (building df): biz index: 983: Wokcano
# =======================================================
# inner loop (building df): biz index: 984: La Abeja Restaurant
# =======================================================
# inner loop (building df): biz index: 985: Caveman Kitchen
# =======================================================
# inner loop (building df): biz index: 986: Café Stella
# =======================================================
# inner loop (building df): biz index: 987: Dōnatsu
# =======================================================
# inner loop (building df): biz index: 988: Rocco's Italian Market and Deli
# =======================================================
# inner loop (building df): biz index: 989: Loteria Grill
# =======================================================
# inner loop (building df): biz index: 990: Gwen Butcher Shop
# =======================================================
# inner loop (building df): biz index: 991: Musso & Frank Grill
# =======================================================
# inner loop (building df): biz index: 992: Electric Lotus
# =======================================================
# inner loop (building df): biz index: 993: The Old Zoo
# =======================================================
# inner loop (building df): biz index: 994: TGI Korean BBQ
# =======================================================
# inner loop (building df): biz index: 995: Golden Gopher
# =======================================================
# inner loop (building df): biz index: 996: Dinosaur Coffee
# =======================================================
# inner loop (building df): biz index: 997: Sunny's Sushi Hut
# =======================================================
# inner loop (building df): biz index: 998: Roll Call
# =======================================================
# inner loop (building df): biz index: 999: Rock'N Fish
# Database ready: records entered:1000

# %%
biz_df.head()
# Out:
#                        id                               alias  \
# 0  TkFEKhsCixPWlShULKvMdQ           bottega-louie-los-angeles
# 1  7O1ORGY36A-2aIENyaJWPg           howlin-rays-los-angeles-3
# 2  KQBGm5G8IDkE8LeNY45mbA            wurstküche-los-angeles-2
# 3  iSZpZgVnASwEmlq0DORY2A  daikokuya-little-tokyo-los-angeles
# 4  DJek3FUewBzMc0gS-Gms9w            the-morrison-los-angeles
#
#                      name                                      categories  \
# 0           Bottega Louie           Italian, Bakeries, Breakfast & Brunch
# 1           Howlin' Ray's  Southern, Chicken Shop, American (Traditional)
# 2              Wurstküche                    Hot Dogs, German, Gastropubs
# 3  Daikokuya Little Tokyo                                  Ramen, Noodles
# 4            The Morrison                       Gastropubs, Burgers, Bars
#
#   review_count rating      lat     long  \
# 0        16243      4  34.0469 -118.257
# 1         5037    4.5  34.0615  -118.24
# 2         8058      4  34.0456 -118.236
# 3         8122      4  34.0501  -118.24
# 4         4072    4.5  34.1238 -118.269
#
#                                         address         city zip_code country  \
# 0         700 S Grand Ave Los Angeles, CA 90017  Los Angeles    90017      US
# 1  727 N Broadway Ste 128 Los Angeles, CA 90012  Los Angeles    90012      US
# 2            800 E 3rd St Los Angeles, CA 90013  Los Angeles    90013      US
# 3            327 E 1st St Los Angeles, CA 90012  Los Angeles    90012      US
# 4     3179 Los Feliz Blvd Los Angeles, CA 90039  Los Angeles    90039      US
#
#   state         phone
# 0    CA  +12138021470
# 1    CA  +12139358399
# 2    CA  +12136874444
# 3    CA  +12136261680
# 4    CA  +13236671839

# %%
biz_df.tail()
# Out:
#                          id                                            alias  \
# 995  ohosmz6FXVAeoW5nUkYwng                       pine-and-crane-los-angeles
# 996  H9ZlIqEp930ZRniH6VRp8w                       papa-cristos-los-angeles-2
# 997  1XUzOcwNTfky9hPAhbTkoA  los-angeles-county-museum-of-art-los-angeles-11
# 998  YA3bV7kd3RpWPvrarIgpWQ                     milk-jar-cookies-los-angeles
# 999  sYn3SNQP-j2t2XSwjlCbRg                   montys-good-burger-los-angeles
#
#                                  name                        categories  \
# 995                      Pine & Crane    Taiwanese, Chinese, Bubble Tea
# 996                     Papa Cristo's              Greek, Mediterranean
# 997  Los Angeles County Museum of Art                       Art Museums
# 998                  Milk Jar Cookies  Desserts, Bakeries, Coffee & Tea
# 999               Monty's Good Burger                    Burgers, Vegan
#
#     review_count rating      lat     long  \
# 995         2011    4.5  34.0906 -118.277
# 996         1815    4.5  34.0474   -118.3
# 997         1791    4.5  34.0639 -118.359
# 998         1443    4.5  34.0621 -118.348
# 999         1193    4.5  34.0647 -118.309
#
#                                            address         city zip_code  \
# 995  1521 Griffith Park Blvd Los Angeles, CA 90026  Los Angeles    90026
# 996         2771 W Pico Blvd Los Angeles, CA 90006  Los Angeles    90006
# 997       5905 Wilshire Blvd Los Angeles, CA 90036  Los Angeles    90036
# 998       5466 Wilshire Blvd Los Angeles, CA 90036  Los Angeles    90036
# 999        516 S Western Ave Los Angeles, CA 90020  Los Angeles    90020
#
#     country state         phone
# 995      US    CA  +13236681128
# 996      US    CA  +13237372970
# 997      US    CA  +13238576000
# 998      US    CA  +13236349800
# 999      US    CA  +12139150257

# %% [markdown]
# # L:  load
# -----------------------------------------------
# * Save df to csv format

# %%
biz_df.to_csv(f"Resources/la_yelp_{biz_df['id'].count()}.csv", index=False)

# %% [markdown]
# * load dataframe into mongo

# %%
import pymongo

# %%
# Setup connection to mongodb
conn = "mongodb://localhost:27017"
client = pymongo.MongoClient(conn)

# Select database and collection to use
db = client.la_yelp_businesses
collection = db.biz_profile

# %%
dictData = biz_df.to_dict(orient='records')

# %%
collection.insert_many(dictData)

# %% [markdown]
# ## test query database

# %%
results = collection.find()

# %%
type(results)
# Out:
# pymongo.cursor.Cursor

# %%
for result in results[0:2]:
    print()
    print(result)
# Out:
# {'_id': ObjectId('5cde0ea4a3a7e50e3747039a'), 'id': 'TkFEKhsCixPWlShULKvMdQ', 'alias': 'bottega-louie-los-angeles', 'name': 'Bottega Louie', 'categories': 'Italian, Bakeries, Breakfast & Brunch', 'review_count': 16243, 'rating': 4.0, 'lat': 34.0469300995766, 'long': -118.256601457672, 'address': '700 S Grand Ave Los Angeles, CA 90017', 'city': 'Los Angeles', 'zip_code': '90017', 'country': 'US', 'state': 'CA', 'phone': '+12138021470'}
#
# {'_id': ObjectId('5cde0ea4a3a7e50e3747039b'), 'id': '7O1ORGY36A-2aIENyaJWPg', 'alias': 'howlin-rays-los-angeles-3', 'name': "Howlin' Ray's", 'categories': 'Southern, Chicken Shop, American (Traditional)', 'review_count': 5037, 'rating': 4.5, 'lat': 34.0614861063899, 'long': -118.239554800093, 'address': '727 N Broadway Ste 128 Los Angeles, CA 90012', 'city': 'Los Angeles', 'zip_code': '90012', 'country': 'US', 'state': 'CA', 'phone': '+12139358399'}

# %% [markdown]
# * First document in the collection

# %%
collection.find()[0]
# Out:
# {'_id': ObjectId('5cde0ea4a3a7e50e3747039a'),
#  'id': 'TkFEKhsCixPWlShULKvMdQ',
#  'alias': 'bottega-louie-los-angeles',
#  'name': 'Bottega Louie',
#  'categories': 'Italian, Bakeries, Breakfast & Brunch',
#  'review_count': 16243,
#  'rating': 4.0,
#  'lat': 34.0469300995766,
#  'long': -118.256601457672,
#  'address': '700 S Grand Ave Los Angeles, CA 90017',
#  'city': 'Los Angeles',
#  'zip_code': '90017',
#  'country': 'US',
#  'state': 'CA',
#  'phone': '+12138021470'}

# %% [markdown]
# # Create SQL database from  Dataframe

# %%
from sqlalchemy import create_engine

# %%
database_path = "Resources/la_biz.sqlite"

# %%
engine = create_engine(f"sqlite:///{database_path}")

# %%
engine.table_names()
# Out:
# ['biz_profile']

# %%
biz_df.to_sql(name='biz_profile', con=engine, if_exists='append', index=False)

# %%
engine.table_names()
# Out:
# ['biz_profile']

# %% [markdown]
# ### Test Query the biz_profile table

# %%
# pd.read_sql_query('select * from customer_name', con=engine).head()
pd.read_sql_query('select * from biz_profile', con=engine).head()
# Out:
#                        id                               alias  \
# 0  TkFEKhsCixPWlShULKvMdQ           bottega-louie-los-angeles
# 1  7O1ORGY36A-2aIENyaJWPg           howlin-rays-los-angeles-3
# 2  KQBGm5G8IDkE8LeNY45mbA            wurstküche-los-angeles-2
# 3  iSZpZgVnASwEmlq0DORY2A  daikokuya-little-tokyo-los-angeles
# 4  DJek3FUewBzMc0gS-Gms9w            the-morrison-los-angeles
#
#                      name                                      categories  \
# 0           Bottega Louie           Italian, Bakeries, Breakfast & Brunch
# 1           Howlin' Ray's  Southern, Chicken Shop, American (Traditional)
# 2              Wurstküche                    Hot Dogs, German, Gastropubs
# 3  Daikokuya Little Tokyo                                  Ramen, Noodles
# 4            The Morrison                       Gastropubs, Burgers, Bars
#
#    review_count  rating        lat        long  \
# 0         16243     4.0  34.046930 -118.256601
# 1          5037     4.5  34.061486 -118.239555
# 2          8058     4.0  34.045605 -118.236061
# 3          8122     4.0  34.050081 -118.240180
# 4          4072     4.5  34.123840 -118.268680
#
#                                         address         city zip_code country  \
# 0         700 S Grand Ave Los Angeles, CA 90017  Los Angeles    90017      US
# 1  727 N Broadway Ste 128 Los Angeles, CA 90012  Los Angeles    90012      US
# 2            800 E 3rd St Los Angeles, CA 90013  Los Angeles    90013      US
# 3            327 E 1st St Los Angeles, CA 90012  Los Angeles    90012      US
# 4     3179 Los Feliz Blvd Los Angeles, CA 90039  Los Angeles    90039      US
#
#   state         phone
# 0    CA  +12138021470
# 1    CA  +12139358399
# 2    CA  +12136874444
# 3    CA  +12136261680
# 4    CA  +13236671839
